# %% [markdown]
# <a href="https://colab.research.google.com/github/MostafaElgafry/Tensor-Flow-Object-Detection/blob/main/Model%20Training_and_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 0. Setup Paths

# %%
import os

# %%
CUSTOM_MODEL_NAME = 'my_ssd_mobnet' 
PRETRAINED_MODEL_NAME = 'ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8'
PRETRAINED_MODEL_URL = 'http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz'
TF_RECORD_SCRIPT_NAME = 'generate_tfrecord.py'
LABEL_MAP_NAME = 'label_map.pbtxt'

# %%
paths = {
    'WORKSPACE_PATH': os.path.join('Tensorflow', 'workspace'),
    'SCRIPTS_PATH': os.path.join('Tensorflow','scripts'),
    'APIMODEL_PATH': os.path.join('Tensorflow','models'),
    'ANNOTATION_PATH': os.path.join('Tensorflow', 'workspace','annotations'),
    'IMAGE_PATH': os.path.join('Tensorflow', 'workspace','images'),
    'MODEL_PATH': os.path.join('Tensorflow', 'workspace','models'),
    'PRETRAINED_MODEL_PATH': os.path.join('Tensorflow', 'workspace','pre-trained-models'),
    'CHECKPOINT_PATH': os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME), 
    'OUTPUT_PATH': os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME, 'export'), 
    'TFJS_PATH':os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME, 'tfjsexport'), 
    'TFLITE_PATH':os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME, 'tfliteexport'), 
    'PROTOC_PATH':os.path.join('Tensorflow','protoc')
 }

# %%
files = {
    'PIPELINE_CONFIG':os.path.join('Tensorflow', 'workspace','models', CUSTOM_MODEL_NAME, 'pipeline.config'),
    'TF_RECORD_SCRIPT': os.path.join(paths['SCRIPTS_PATH'], TF_RECORD_SCRIPT_NAME), 
    'LABELMAP': os.path.join(paths['ANNOTATION_PATH'], LABEL_MAP_NAME)
}

# %%
for path in paths.values():
    if not os.path.exists(path):
        if os.name == 'posix':
            # !mkdir -p {path}
        if os.name == 'nt':
            # !mkdir {path}

# %% [markdown]
# # 1. Download TF Models Pretrained Models from Tensorflow Model Zoo and Install TFOD

# %%
# https://www.tensorflow.org/install/source_windows

# %%
if os.name=='nt':
    # !pip install wget
    import wget

# %%
if not os.path.exists(os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection')):
    # !git clone https://github.com/tensorflow/models {paths['APIMODEL_PATH']}
# Out:
# Cloning into 'Tensorflow/models'...
# remote: Enumerating objects: 75999, done.
# remote: Counting objects: 100% (461/461), done.
# remote: Compressing objects: 100% (251/251), done.
# remote: Total 75999 (delta 251), reused 397 (delta 207), pack-reused 75538
# Receiving objects: 100% (75999/75999), 589.46 MiB | 36.38 MiB/s, done.
# Resolving deltas: 100% (53862/53862), done.

# %%
# Install Tensorflow Object Detection 
if os.name=='posix':  
    # !apt-get install protobuf-compiler
    # !cd Tensorflow/models/research && protoc object_detection/protos/*.proto --python_out=. && cp object_detection/packages/tf2/setup.py . && python -m pip install . 
    
if os.name=='nt':
    url="https://github.com/protocolbuffers/protobuf/releases/download/v3.15.6/protoc-3.15.6-win64.zip"
    wget.download(url)
    # !move protoc-3.15.6-win64.zip {paths['PROTOC_PATH']}
    # !cd {paths['PROTOC_PATH']} && tar -xf protoc-3.15.6-win64.zip
    os.environ['PATH'] += os.pathsep + os.path.abspath(os.path.join(paths['PROTOC_PATH'], 'bin'))   
    # !cd Tensorflow/models/research && protoc object_detection/protos/*.proto --python_out=. && copy object_detection\\packages\\tf2\\setup.py setup.py && python setup.py build && python setup.py install
    # !cd Tensorflow/models/research/slim && pip install -e .
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# protobuf-compiler is already the newest version (3.0.0-9.1ubuntu1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 19 not upgraded.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Processing /content/Tensorflow/models/research
#   DEPRECATION: A future pip version will change local packages to be built in-place without first copying to a temporary directory. We recommend you use --use-feature=in-tree-build to test your packages with this new behavior before it becomes the default.
#    pip 21.3 will remove support for this functionality. You can find discussion regarding this at https://github.com/pypa/pip/issues/7555.
# Collecting avro-python3
#   Downloading avro-python3-1.10.2.tar.gz (38 kB)
# Collecting apache-beam
#   Downloading apache_beam-2.40.0-cp37-cp37m-manylinux2010_x86_64.whl (10.9 MB)
#      |████████████████████████████████| 10.9 MB 8.0 MB/s
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (7.1.2)
# Requirement already satisfied: lxml in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (4.9.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (3.2.2)
# Requirement already satisfied: Cython in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (0.29.32)
# Requirement already satisfied: contextlib2 in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (0.5.5)
# Collecting tf-slim
#   Downloading tf_slim-1.1.0-py2.py3-none-any.whl (352 kB)
#      |████████████████████████████████| 352 kB 71.3 MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (1.15.0)
# Requirement already satisfied: pycocotools in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (2.0.4)
# Collecting lvis
#   Downloading lvis-0.5.3-py3-none-any.whl (14 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (1.7.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (1.3.5)
# Collecting tf-models-official>=2.5.1
#   Downloading tf_models_official-2.9.2-py2.py3-none-any.whl (2.1 MB)
#      |████████████████████████████████| 2.1 MB 44.5 MB/s
# Collecting tensorflow_io
#   Downloading tensorflow_io-0.26.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (25.9 MB)
#      |████████████████████████████████| 25.9 MB 83.8 MB/s
# Requirement already satisfied: keras in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (2.8.0)
# Collecting pyparsing==2.4.7
#   Downloading pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
#      |████████████████████████████████| 67 kB 5.8 MB/s
# Requirement already satisfied: kaggle>=1.3.9 in /usr/local/lib/python3.7/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (1.5.12)
# Collecting sacrebleu
#   Downloading sacrebleu-2.2.0-py3-none-any.whl (116 kB)
#      |████████████████████████████████| 116 kB 69.8 MB/s
# Requirement already satisfied: psutil>=5.4.3 in /usr/local/lib/python3.7/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (5.4.8)
# Collecting py-cpuinfo>=3.3.0
#   Downloading py-cpuinfo-8.0.0.tar.gz (99 kB)
#      |████████████████████████████████| 99 kB 10.0 MB/s
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 59.4 MB/s
# Collecting seqeval
#   Downloading seqeval-1.2.2.tar.gz (43 kB)
#      |████████████████████████████████| 43 kB 1.9 MB/s
# Collecting pyyaml<6.0,>=5.1
#   Downloading PyYAML-5.4.1-cp37-cp37m-manylinux1_x86_64.whl (636 kB)
#      |████████████████████████████████| 636 kB 65.6 MB/s
# Requirement already satisfied: google-api-python-client>=1.6.7 in /usr/local/lib/python3.7/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (1.12.11)
# Collecting tensorflow-text~=2.9.0
#   Downloading tensorflow_text-2.9.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.6 MB)
#      |████████████████████████████████| 4.6 MB 41.2 MB/s
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.7/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (1.21.6)
# Collecting tensorflow~=2.9.0
#   Downloading tensorflow-2.9.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (511.7 MB)
#      |████████████████████████████████| 511.7 MB 6.2 kB/s
# Requirement already satisfied: tensorflow-hub>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (0.12.0)
# Collecting tensorflow-addons
#   Downloading tensorflow_addons-0.17.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 71.9 MB/s
# Requirement already satisfied: gin-config in /usr/local/lib/python3.7/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (0.5.0)
# Collecting tensorflow-model-optimization>=0.4.1
#   Downloading tensorflow_model_optimization-0.7.3-py2.py3-none-any.whl (238 kB)
#      |████████████████████████████████| 238 kB 74.2 MB/s
# Requirement already satisfied: oauth2client in /usr/local/lib/python3.7/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (4.1.3)
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.7/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (4.6.0.66)
# Requirement already satisfied: tensorflow-datasets in /usr/local/lib/python3.7/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (4.6.0)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (0.0.4)
# Requirement already satisfied: google-api-core<3dev,>=1.21.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (1.31.6)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (3.0.1)
# Requirement already satisfied: httplib2<1dev,>=0.15.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (0.17.4)
# Requirement already satisfied: google-auth<3dev,>=1.16.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (1.35.0)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (2.23.0)
# Requirement already satisfied: protobuf<4.0.0dev,>=3.12.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (3.17.3)
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (2022.1)
# Requirement already satisfied: setuptools>=40.3.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (57.4.0)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (1.56.4)
# Requirement already satisfied: packaging>=14.3 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (21.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3dev,>=1.16.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3dev,>=1.16.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3dev,>=1.16.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (4.9)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.7/dist-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (6.1.2)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (2.8.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (2022.6.15)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (4.64.0)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (1.24.3)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3dev,>=1.16.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (0.4.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<3dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<3dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (3.0.4)
# Collecting tensorflow-estimator<2.10.0,>=2.9.0rc0
#   Downloading tensorflow_estimator-2.9.0-py2.py3-none-any.whl (438 kB)
#      |████████████████████████████████| 438 kB 72.0 MB/s
# Collecting tensorboard<2.10,>=2.9
#   Downloading tensorboard-2.9.1-py3-none-any.whl (5.8 MB)
#      |████████████████████████████████| 5.8 MB 49.5 MB/s
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.9.0->tf-models-official>=2.5.1->object-detection==0.1) (4.1.1)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.9.0->tf-models-official>=2.5.1->object-detection==0.1) (3.1.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.9.0->tf-models-official>=2.5.1->object-detection==0.1) (0.26.0)
# Collecting keras
#   Downloading keras-2.9.0-py2.py3-none-any.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 46.8 MB/s
# Collecting flatbuffers<2,>=1.12
#   Downloading flatbuffers-1.12-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.9.0->tf-models-official>=2.5.1->object-detection==0.1) (1.6.3)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.9.0->tf-models-official>=2.5.1->object-detection==0.1) (14.0.6)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.9.0->tf-models-official>=2.5.1->object-detection==0.1) (1.47.0)
# Collecting gast<=0.4.0,>=0.2.1
#   Downloading gast-0.4.0-py3-none-any.whl (9.8 kB)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.9.0->tf-models-official>=2.5.1->object-detection==0.1) (1.1.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.9.0->tf-models-official>=2.5.1->object-detection==0.1) (1.2.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.9.0->tf-models-official>=2.5.1->object-detection==0.1) (0.2.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.9.0->tf-models-official>=2.5.1->object-detection==0.1) (1.14.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.9.0->tf-models-official>=2.5.1->object-detection==0.1) (3.3.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.9.0->tf-models-official>=2.5.1->object-detection==0.1) (1.1.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.7/dist-packages (from astunparse>=1.6.0->tensorflow~=2.9.0->tf-models-official>=2.5.1->object-detection==0.1) (0.37.1)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py>=2.9.0->tensorflow~=2.9.0->tf-models-official>=2.5.1->object-detection==0.1) (1.5.2)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.10,>=2.9->tensorflow~=2.9.0->tf-models-official>=2.5.1->object-detection==0.1) (1.8.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.10,>=2.9->tensorflow~=2.9.0->tf-models-official>=2.5.1->object-detection==0.1) (3.4.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.10,>=2.9->tensorflow~=2.9.0->tf-models-official>=2.5.1->object-detection==0.1) (1.0.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.10,>=2.9->tensorflow~=2.9.0->tf-models-official>=2.5.1->object-detection==0.1) (0.6.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.10,>=2.9->tensorflow~=2.9.0->tf-models-official>=2.5.1->object-detection==0.1) (0.4.6)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow~=2.9.0->tf-models-official>=2.5.1->object-detection==0.1) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow~=2.9.0->tf-models-official>=2.5.1->object-detection==0.1) (4.12.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow~=2.9.0->tf-models-official>=2.5.1->object-detection==0.1) (3.8.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow~=2.9.0->tf-models-official>=2.5.1->object-detection==0.1) (3.2.0)
# Requirement already satisfied: dm-tree~=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow-model-optimization>=0.4.1->tf-models-official>=2.5.1->object-detection==0.1) (0.1.7)
# Requirement already satisfied: crcmod<2.0,>=1.7 in /usr/local/lib/python3.7/dist-packages (from apache-beam->object-detection==0.1) (1.7)
# Collecting pymongo<4.0.0,>=3.8.0
#   Downloading pymongo-3.12.3-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (508 kB)
#      |████████████████████████████████| 508 kB 65.1 MB/s
# Collecting proto-plus<2,>=1.7.1
#   Downloading proto_plus-1.20.6-py3-none-any.whl (46 kB)
#      |████████████████████████████████| 46 kB 4.0 MB/s
# Requirement already satisfied: pyarrow<8.0.0,>=0.15.1 in /usr/local/lib/python3.7/dist-packages (from apache-beam->object-detection==0.1) (6.0.1)
# Collecting requests<3.0.0dev,>=2.18.0
#   Downloading requests-2.28.1-py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 1.3 MB/s
# Collecting dill<0.3.2,>=0.3.1.1
#   Downloading dill-0.3.1.1.tar.gz (151 kB)
#      |████████████████████████████████| 151 kB 68.6 MB/s
# Collecting cloudpickle<3,>=2.1.0
#   Downloading cloudpickle-2.1.0-py3-none-any.whl (25 kB)
# Collecting hdfs<3.0.0,>=2.1.0
#   Downloading hdfs-2.7.0-py3-none-any.whl (34 kB)
# Requirement already satisfied: pydot<2,>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from apache-beam->object-detection==0.1) (1.3.0)
# Collecting fastavro<2,>=0.23.6
#   Downloading fastavro-1.5.4-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.4 MB)
#      |████████████████████████████████| 2.4 MB 49.1 MB/s
# Collecting orjson<4.0
#   Downloading orjson-3.7.11-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (275 kB)
#      |████████████████████████████████| 275 kB 70.9 MB/s
# Collecting docopt
#   Downloading docopt-0.6.2.tar.gz (25 kB)
# Collecting protobuf<4.0.0dev,>=3.12.0
#   Downloading protobuf-3.19.4-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 61.1 MB/s
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<3dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (2.1.0)
# Requirement already satisfied: cycler>=0.10.0 in /usr/local/lib/python3.7/dist-packages (from lvis->object-detection==0.1) (0.11.0)
# Requirement already satisfied: opencv-python>=4.1.0.25 in /usr/local/lib/python3.7/dist-packages (from lvis->object-detection==0.1) (4.6.0.66)
# Requirement already satisfied: kiwisolver>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from lvis->object-detection==0.1) (1.4.4)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.7/dist-packages (from python-slugify->kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (1.3)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.7/dist-packages (from sacrebleu->tf-models-official>=2.5.1->object-detection==0.1) (0.8.10)
# Collecting colorama
#   Downloading colorama-0.4.5-py2.py3-none-any.whl (16 kB)
# Collecting portalocker
#   Downloading portalocker-2.5.1-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from sacrebleu->tf-models-official>=2.5.1->object-detection==0.1) (2022.6.2)
# Requirement already satisfied: scikit-learn>=0.21.3 in /usr/local/lib/python3.7/dist-packages (from seqeval->tf-models-official>=2.5.1->object-detection==0.1) (1.0.2)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.21.3->seqeval->tf-models-official>=2.5.1->object-detection==0.1) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.21.3->seqeval->tf-models-official>=2.5.1->object-detection==0.1) (3.1.0)
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.7/dist-packages (from tensorflow-addons->tf-models-official>=2.5.1->object-detection==0.1) (2.7.1)
# Requirement already satisfied: toml in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (0.10.2)
# Requirement already satisfied: tensorflow-metadata in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (1.9.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (5.9.0)
# Requirement already satisfied: etils[epath] in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (0.6.0)
# Requirement already satisfied: promise in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (2.3)
# Building wheels for collected packages: object-detection, py-cpuinfo, dill, avro-python3, docopt, seqeval
#   Building wheel for object-detection (setup.py) ... done
#   Created wheel for object-detection: filename=object_detection-0.1-py3-none-any.whl size=1694955 sha256=4ba6b59aa3e75629ccdaad71c7a13d719a0819dc67abf1899127b6e89333e5fc
#   Stored in directory: /tmp/pip-ephem-wheel-cache-v6wc6wtg/wheels/a9/26/bf/1cb2313ed4855917889b97658bf0a19999e3588e47867bdaee
#   Building wheel for py-cpuinfo (setup.py) ... done
#   Created wheel for py-cpuinfo: filename=py_cpuinfo-8.0.0-py3-none-any.whl size=22257 sha256=d7c7ec5d89f1eedc0f8cb07b09497e947bc34f414c15da277b989118012fd828
#   Stored in directory: /root/.cache/pip/wheels/d2/f1/1f/041add21dc9c4220157f1bd2bd6afe1f1a49524c3396b94401
#   Building wheel for dill (setup.py) ... done
#   Created wheel for dill: filename=dill-0.3.1.1-py3-none-any.whl size=78544 sha256=7b3967bc927ac794766df63d0ff9190844fc773ba41dfcd87594f4c27ebf573a
#   Stored in directory: /root/.cache/pip/wheels/a4/61/fd/c57e374e580aa78a45ed78d5859b3a44436af17e22ca53284f
#   Building wheel for avro-python3 (setup.py) ... done
#   Created wheel for avro-python3: filename=avro_python3-1.10.2-py3-none-any.whl size=44010 sha256=44d1b952fdeea0da46b83cd453d2e64d20eeac55c86ceaa2f365b81606d79759
#   Stored in directory: /root/.cache/pip/wheels/d6/e5/b1/6b151d9b535ee50aaa6ab27d145a0104b6df02e5636f0376da
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13723 sha256=438e5e35363b30a721419c8bf1188b02d28f827a21eca11904186c43ad7978f2
#   Stored in directory: /root/.cache/pip/wheels/72/b0/3f/1d95f96ff986c7dfffe46ce2be4062f38ebd04b506c77c81b9
#   Building wheel for seqeval (setup.py) ... done
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16180 sha256=3219e6bd69d894c842141756d0f85051a50f3c3bf5e256701428359a30bdbe78
#   Stored in directory: /root/.cache/pip/wheels/05/96/ee/7cac4e74f3b19e3158dce26a20a1c86b3533c43ec72a549fd7
# Successfully built object-detection py-cpuinfo dill avro-python3 docopt seqeval
# Installing collected packages: requests, pyparsing, protobuf, tensorflow-estimator, tensorboard, keras, gast, flatbuffers, tensorflow, portalocker, docopt, dill, colorama, tf-slim, tensorflow-text, tensorflow-model-optimization, tensorflow-addons, seqeval, sentencepiece, sacrebleu, pyyaml, pymongo, py-cpuinfo, proto-plus, orjson, hdfs, fastavro, cloudpickle, tf-models-official, tensorflow-io, lvis, avro-python3, apache-beam, object-detection
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.0.9
#     Uninstalling pyparsing-3.0.9:
#       Successfully uninstalled pyparsing-3.0.9
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.17.3
#     Uninstalling protobuf-3.17.3:
#       Successfully uninstalled protobuf-3.17.3
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.8.0
#     Uninstalling tensorflow-estimator-2.8.0:
#       Successfully uninstalled tensorflow-estimator-2.8.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.8.0
#     Uninstalling tensorboard-2.8.0:
#       Successfully uninstalled tensorboard-2.8.0
#   Attempting uninstall: keras
#     Found existing installation: keras 2.8.0
#     Uninstalling keras-2.8.0:
#       Successfully uninstalled keras-2.8.0
#   Attempting uninstall: gast
#     Found existing installation: gast 0.5.3
#     Uninstalling gast-0.5.3:
#       Successfully uninstalled gast-0.5.3
#   Attempting uninstall: flatbuffers
#     Found existing installation: flatbuffers 2.0
#     Uninstalling flatbuffers-2.0:
#       Successfully uninstalled flatbuffers-2.0
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.8.2+zzzcolab20220719082949
#     Uninstalling tensorflow-2.8.2+zzzcolab20220719082949:
#       Successfully uninstalled tensorflow-2.8.2+zzzcolab20220719082949
#   Attempting uninstall: dill
#     Found existing installation: dill 0.3.5.1
#     Uninstalling dill-0.3.5.1:
#       Successfully uninstalled dill-0.3.5.1
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
#   Attempting uninstall: pymongo
#     Found existing installation: pymongo 4.2.0
#     Uninstalling pymongo-4.2.0:
#       Successfully uninstalled pymongo-4.2.0
#   Attempting uninstall: cloudpickle
#     Found existing installation: cloudpickle 1.3.0
#     Uninstalling cloudpickle-1.3.0:
#       Successfully uninstalled cloudpickle-1.3.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gym 0.17.3 requires cloudpickle<1.7.0,>=1.2.0, but you have cloudpickle 2.1.0 which is incompatible.
# Successfully installed apache-beam-2.40.0 avro-python3-1.10.2 cloudpickle-2.1.0 colorama-0.4.5 dill-0.3.1.1 docopt-0.6.2 fastavro-1.5.4 flatbuffers-1.12 gast-0.4.0 hdfs-2.7.0 keras-2.9.0 lvis-0.5.3 object-detection-0.1 orjson-3.7.11 portalocker-2.5.1 proto-plus-1.20.6 protobuf-3.19.4 py-cpuinfo-8.0.0 pymongo-3.12.3 pyparsing-2.4.7 pyyaml-5.4.1 requests-2.28.1 sacrebleu-2.2.0 sentencepiece-0.1.96 seqeval-1.2.2 tensorboard-2.9.1 tensorflow-2.9.1 tensorflow-addons-0.17.1 tensorflow-estimator-2.9.0 tensorflow-io-0.26.0 tensorflow-model-optimization-0.7.3 tensorflow-text-2.9.0 tf-models-official-2.9.2 tf-slim-1.1.0

# %%
VERIFICATION_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'builders', 'model_builder_tf2_test.py')
# Verify Installation
# !python {VERIFICATION_SCRIPT}
# Out:
# Running tests under Python 3.7.13: /usr/bin/python3
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_deepmac
# 2022-08-05 18:57:18.687543: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# W0805 18:57:19.035777 140407809644416 model_builder.py:1102] Building experimental DeepMAC meta-arch. Some features may be omitted.
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_deepmac): 1.56s
# I0805 18:57:19.301187 140407809644416 test_util.py:2459] time(__main__.ModelBuilderTF2Test.test_create_center_net_deepmac): 1.56s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_deepmac
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)): 0.54s
# I0805 18:57:19.836982 140407809644416 test_util.py:2459] time(__main__.ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)): 0.54s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)): 0.27s
# I0805 18:57:20.110352 140407809644416 test_util.py:2459] time(__main__.ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)): 0.27s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model_from_keypoints
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model_from_keypoints): 0.25s
# I0805 18:57:20.359637 140407809644416 test_util.py:2459] time(__main__.ModelBuilderTF2Test.test_create_center_net_model_from_keypoints): 0.25s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model_from_keypoints
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model_mobilenet
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model_mobilenet): 1.88s
# I0805 18:57:22.235906 140407809644416 test_util.py:2459] time(__main__.ModelBuilderTF2Test.test_create_center_net_model_mobilenet): 1.88s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model_mobilenet
# [ RUN      ] ModelBuilderTF2Test.test_create_experimental_model
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_experimental_model): 0.0s
# I0805 18:57:22.236863 140407809644416 test_util.py:2459] time(__main__.ModelBuilderTF2Test.test_create_experimental_model): 0.0s
# [       OK ] ModelBuilderTF2Test.test_create_experimental_model
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)): 0.02s
# I0805 18:57:22.260189 140407809644416 test_util.py:2459] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)): 0.02s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)): 0.02s
# I0805 18:57:22.275641 140407809644416 test_util.py:2459] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)): 0.02s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner): 0.02s
# I0805 18:57:22.291266 140407809644416 test_util.py:2459] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner): 0.02s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul): 0.1s
# I0805 18:57:22.390004 140407809644416 test_util.py:2459] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul): 0.1s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul): 0.1s
# I0805 18:57:22.487388 140407809644416 test_util.py:2459] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul): 0.1s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul): 0.11s
# I0805 18:57:22.593794 140407809644416 test_util.py:2459] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul): 0.11s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul): 0.1s
# I0805 18:57:22.690322 140407809644416 test_util.py:2459] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul): 0.1s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_rfcn_model_from_config
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_rfcn_model_from_config): 0.09s
# I0805 18:57:22.783437 140407809644416 test_util.py:2459] time(__main__.ModelBuilderTF2Test.test_create_rfcn_model_from_config): 0.09s
# [       OK ] ModelBuilderTF2Test.test_create_rfcn_model_from_config
# [ RUN      ] ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config): 0.03s
# I0805 18:57:22.816023 140407809644416 test_util.py:2459] time(__main__.ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config): 0.03s
# [       OK ] ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config
# [ RUN      ] ModelBuilderTF2Test.test_create_ssd_models_from_config
# I0805 18:57:22.992963 140407809644416 ssd_efficientnet_bifpn_feature_extractor.py:146] EfficientDet EfficientNet backbone version: efficientnet-b0
# I0805 18:57:22.993117 140407809644416 ssd_efficientnet_bifpn_feature_extractor.py:147] EfficientDet BiFPN num filters: 64
# I0805 18:57:22.993195 140407809644416 ssd_efficientnet_bifpn_feature_extractor.py:149] EfficientDet BiFPN num iterations: 3
# I0805 18:57:22.995316 140407809644416 efficientnet_model.py:143] round_filter input=32 output=32
# I0805 18:57:23.012487 140407809644416 efficientnet_model.py:143] round_filter input=32 output=32
# I0805 18:57:23.012618 140407809644416 efficientnet_model.py:143] round_filter input=16 output=16
# I0805 18:57:23.076868 140407809644416 efficientnet_model.py:143] round_filter input=16 output=16
# I0805 18:57:23.077003 140407809644416 efficientnet_model.py:143] round_filter input=24 output=24
# I0805 18:57:23.235756 140407809644416 efficientnet_model.py:143] round_filter input=24 output=24
# I0805 18:57:23.235939 140407809644416 efficientnet_model.py:143] round_filter input=40 output=40
# I0805 18:57:23.390179 140407809644416 efficientnet_model.py:143] round_filter input=40 output=40
# I0805 18:57:23.390335 140407809644416 efficientnet_model.py:143] round_filter input=80 output=80
# I0805 18:57:23.629423 140407809644416 efficientnet_model.py:143] round_filter input=80 output=80
# I0805 18:57:23.629591 140407809644416 efficientnet_model.py:143] round_filter input=112 output=112
# I0805 18:57:24.010974 140407809644416 efficientnet_model.py:143] round_filter input=112 output=112
# I0805 18:57:24.011152 140407809644416 efficientnet_model.py:143] round_filter input=192 output=192
# I0805 18:57:24.346644 140407809644416 efficientnet_model.py:143] round_filter input=192 output=192
# I0805 18:57:24.346826 140407809644416 efficientnet_model.py:143] round_filter input=320 output=320
# I0805 18:57:24.426307 140407809644416 efficientnet_model.py:143] round_filter input=1280 output=1280
# I0805 18:57:24.459259 140407809644416 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.0, depth_coefficient=1.0, resolution=224, dropout_rate=0.2, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0805 18:57:24.512132 140407809644416 ssd_efficientnet_bifpn_feature_extractor.py:146] EfficientDet EfficientNet backbone version: efficientnet-b1
# I0805 18:57:24.512276 140407809644416 ssd_efficientnet_bifpn_feature_extractor.py:147] EfficientDet BiFPN num filters: 88
# I0805 18:57:24.512353 140407809644416 ssd_efficientnet_bifpn_feature_extractor.py:149] EfficientDet BiFPN num iterations: 4
# I0805 18:57:24.513985 140407809644416 efficientnet_model.py:143] round_filter input=32 output=32
# I0805 18:57:24.530286 140407809644416 efficientnet_model.py:143] round_filter input=32 output=32
# I0805 18:57:24.530425 140407809644416 efficientnet_model.py:143] round_filter input=16 output=16
# I0805 18:57:24.673256 140407809644416 efficientnet_model.py:143] round_filter input=16 output=16
# I0805 18:57:24.673416 140407809644416 efficientnet_model.py:143] round_filter input=24 output=24
# I0805 18:57:24.906446 140407809644416 efficientnet_model.py:143] round_filter input=24 output=24
# I0805 18:57:24.906611 140407809644416 efficientnet_model.py:143] round_filter input=40 output=40
# I0805 18:57:25.144703 140407809644416 efficientnet_model.py:143] round_filter input=40 output=40
# I0805 18:57:25.144888 140407809644416 efficientnet_model.py:143] round_filter input=80 output=80
# I0805 18:57:25.460344 140407809644416 efficientnet_model.py:143] round_filter input=80 output=80
# I0805 18:57:25.460549 140407809644416 efficientnet_model.py:143] round_filter input=112 output=112
# I0805 18:57:25.777894 140407809644416 efficientnet_model.py:143] round_filter input=112 output=112
# I0805 18:57:25.778074 140407809644416 efficientnet_model.py:143] round_filter input=192 output=192
# I0805 18:57:26.190027 140407809644416 efficientnet_model.py:143] round_filter input=192 output=192
# I0805 18:57:26.190199 140407809644416 efficientnet_model.py:143] round_filter input=320 output=320
# I0805 18:57:26.343974 140407809644416 efficientnet_model.py:143] round_filter input=1280 output=1280
# I0805 18:57:26.374337 140407809644416 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.0, depth_coefficient=1.1, resolution=240, dropout_rate=0.2, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0805 18:57:26.434175 140407809644416 ssd_efficientnet_bifpn_feature_extractor.py:146] EfficientDet EfficientNet backbone version: efficientnet-b2
# I0805 18:57:26.434302 140407809644416 ssd_efficientnet_bifpn_feature_extractor.py:147] EfficientDet BiFPN num filters: 112
# I0805 18:57:26.434375 140407809644416 ssd_efficientnet_bifpn_feature_extractor.py:149] EfficientDet BiFPN num iterations: 5
# I0805 18:57:26.435877 140407809644416 efficientnet_model.py:143] round_filter input=32 output=32
# I0805 18:57:26.451196 140407809644416 efficientnet_model.py:143] round_filter input=32 output=32
# I0805 18:57:26.451304 140407809644416 efficientnet_model.py:143] round_filter input=16 output=16
# I0805 18:57:26.584563 140407809644416 efficientnet_model.py:143] round_filter input=16 output=16
# I0805 18:57:26.584716 140407809644416 efficientnet_model.py:143] round_filter input=24 output=24
# I0805 18:57:26.822533 140407809644416 efficientnet_model.py:143] round_filter input=24 output=24
# I0805 18:57:26.822710 140407809644416 efficientnet_model.py:143] round_filter input=40 output=48
# I0805 18:57:27.061809 140407809644416 efficientnet_model.py:143] round_filter input=40 output=48
# I0805 18:57:27.061987 140407809644416 efficientnet_model.py:143] round_filter input=80 output=88
# I0805 18:57:27.381134 140407809644416 efficientnet_model.py:143] round_filter input=80 output=88
# I0805 18:57:27.381312 140407809644416 efficientnet_model.py:143] round_filter input=112 output=120
# I0805 18:57:27.709440 140407809644416 efficientnet_model.py:143] round_filter input=112 output=120
# I0805 18:57:27.709624 140407809644416 efficientnet_model.py:143] round_filter input=192 output=208
# I0805 18:57:28.113592 140407809644416 efficientnet_model.py:143] round_filter input=192 output=208
# I0805 18:57:28.113768 140407809644416 efficientnet_model.py:143] round_filter input=320 output=352
# I0805 18:57:28.276138 140407809644416 efficientnet_model.py:143] round_filter input=1280 output=1408
# I0805 18:57:28.308462 140407809644416 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.1, depth_coefficient=1.2, resolution=260, dropout_rate=0.3, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0805 18:57:28.375470 140407809644416 ssd_efficientnet_bifpn_feature_extractor.py:146] EfficientDet EfficientNet backbone version: efficientnet-b3
# I0805 18:57:28.375635 140407809644416 ssd_efficientnet_bifpn_feature_extractor.py:147] EfficientDet BiFPN num filters: 160
# I0805 18:57:28.375720 140407809644416 ssd_efficientnet_bifpn_feature_extractor.py:149] EfficientDet BiFPN num iterations: 6
# I0805 18:57:28.377408 140407809644416 efficientnet_model.py:143] round_filter input=32 output=40
# I0805 18:57:28.395034 140407809644416 efficientnet_model.py:143] round_filter input=32 output=40
# I0805 18:57:28.395190 140407809644416 efficientnet_model.py:143] round_filter input=16 output=24
# I0805 18:57:28.529564 140407809644416 efficientnet_model.py:143] round_filter input=16 output=24
# I0805 18:57:28.529739 140407809644416 efficientnet_model.py:143] round_filter input=24 output=32
# I0805 18:57:28.972482 140407809644416 efficientnet_model.py:143] round_filter input=24 output=32
# I0805 18:57:28.972665 140407809644416 efficientnet_model.py:143] round_filter input=40 output=48
# I0805 18:57:29.224225 140407809644416 efficientnet_model.py:143] round_filter input=40 output=48
# I0805 18:57:29.224404 140407809644416 efficientnet_model.py:143] round_filter input=80 output=96
# I0805 18:57:29.643079 140407809644416 efficientnet_model.py:143] round_filter input=80 output=96
# I0805 18:57:29.643324 140407809644416 efficientnet_model.py:143] round_filter input=112 output=136
# I0805 18:57:30.051197 140407809644416 efficientnet_model.py:143] round_filter input=112 output=136
# I0805 18:57:30.051376 140407809644416 efficientnet_model.py:143] round_filter input=192 output=232
# I0805 18:57:30.534880 140407809644416 efficientnet_model.py:143] round_filter input=192 output=232
# I0805 18:57:30.535051 140407809644416 efficientnet_model.py:143] round_filter input=320 output=384
# I0805 18:57:30.700551 140407809644416 efficientnet_model.py:143] round_filter input=1280 output=1536
# I0805 18:57:30.731362 140407809644416 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.2, depth_coefficient=1.4, resolution=300, dropout_rate=0.3, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0805 18:57:30.795857 140407809644416 ssd_efficientnet_bifpn_feature_extractor.py:146] EfficientDet EfficientNet backbone version: efficientnet-b4
# I0805 18:57:30.796015 140407809644416 ssd_efficientnet_bifpn_feature_extractor.py:147] EfficientDet BiFPN num filters: 224
# I0805 18:57:30.796096 140407809644416 ssd_efficientnet_bifpn_feature_extractor.py:149] EfficientDet BiFPN num iterations: 7
# I0805 18:57:30.797654 140407809644416 efficientnet_model.py:143] round_filter input=32 output=48
# I0805 18:57:30.817293 140407809644416 efficientnet_model.py:143] round_filter input=32 output=48
# I0805 18:57:30.817413 140407809644416 efficientnet_model.py:143] round_filter input=16 output=24
# I0805 18:57:30.942354 140407809644416 efficientnet_model.py:143] round_filter input=16 output=24
# I0805 18:57:30.942533 140407809644416 efficientnet_model.py:143] round_filter input=24 output=32
# I0805 18:57:31.263231 140407809644416 efficientnet_model.py:143] round_filter input=24 output=32
# I0805 18:57:31.263411 140407809644416 efficientnet_model.py:143] round_filter input=40 output=56
# I0805 18:57:31.576016 140407809644416 efficientnet_model.py:143] round_filter input=40 output=56
# I0805 18:57:31.576203 140407809644416 efficientnet_model.py:143] round_filter input=80 output=112
# I0805 18:57:32.057610 140407809644416 efficientnet_model.py:143] round_filter input=80 output=112
# I0805 18:57:32.057790 140407809644416 efficientnet_model.py:143] round_filter input=112 output=160
# I0805 18:57:32.528675 140407809644416 efficientnet_model.py:143] round_filter input=112 output=160
# I0805 18:57:32.528866 140407809644416 efficientnet_model.py:143] round_filter input=192 output=272
# I0805 18:57:33.165405 140407809644416 efficientnet_model.py:143] round_filter input=192 output=272
# I0805 18:57:33.165585 140407809644416 efficientnet_model.py:143] round_filter input=320 output=448
# I0805 18:57:33.321252 140407809644416 efficientnet_model.py:143] round_filter input=1280 output=1792
# I0805 18:57:33.350630 140407809644416 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.4, depth_coefficient=1.8, resolution=380, dropout_rate=0.4, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0805 18:57:33.428235 140407809644416 ssd_efficientnet_bifpn_feature_extractor.py:146] EfficientDet EfficientNet backbone version: efficientnet-b5
# I0805 18:57:33.428389 140407809644416 ssd_efficientnet_bifpn_feature_extractor.py:147] EfficientDet BiFPN num filters: 288
# I0805 18:57:33.428465 140407809644416 ssd_efficientnet_bifpn_feature_extractor.py:149] EfficientDet BiFPN num iterations: 7
# I0805 18:57:33.430026 140407809644416 efficientnet_model.py:143] round_filter input=32 output=48
# I0805 18:57:33.446066 140407809644416 efficientnet_model.py:143] round_filter input=32 output=48
# I0805 18:57:33.446192 140407809644416 efficientnet_model.py:143] round_filter input=16 output=24
# I0805 18:57:33.632390 140407809644416 efficientnet_model.py:143] round_filter input=16 output=24
# I0805 18:57:33.632588 140407809644416 efficientnet_model.py:143] round_filter input=24 output=40
# I0805 18:57:34.037279 140407809644416 efficientnet_model.py:143] round_filter input=24 output=40
# I0805 18:57:34.037474 140407809644416 efficientnet_model.py:143] round_filter input=40 output=64
# I0805 18:57:34.646385 140407809644416 efficientnet_model.py:143] round_filter input=40 output=64
# I0805 18:57:34.646562 140407809644416 efficientnet_model.py:143] round_filter input=80 output=128
# I0805 18:57:35.219667 140407809644416 efficientnet_model.py:143] round_filter input=80 output=128
# I0805 18:57:35.219858 140407809644416 efficientnet_model.py:143] round_filter input=112 output=176
# I0805 18:57:35.778708 140407809644416 efficientnet_model.py:143] round_filter input=112 output=176
# I0805 18:57:35.778894 140407809644416 efficientnet_model.py:143] round_filter input=192 output=304
# I0805 18:57:36.490551 140407809644416 efficientnet_model.py:143] round_filter input=192 output=304
# I0805 18:57:36.490736 140407809644416 efficientnet_model.py:143] round_filter input=320 output=512
# I0805 18:57:36.730966 140407809644416 efficientnet_model.py:143] round_filter input=1280 output=2048
# I0805 18:57:36.764380 140407809644416 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.6, depth_coefficient=2.2, resolution=456, dropout_rate=0.4, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0805 18:57:36.852450 140407809644416 ssd_efficientnet_bifpn_feature_extractor.py:146] EfficientDet EfficientNet backbone version: efficientnet-b6
# I0805 18:57:36.852615 140407809644416 ssd_efficientnet_bifpn_feature_extractor.py:147] EfficientDet BiFPN num filters: 384
# I0805 18:57:36.852701 140407809644416 ssd_efficientnet_bifpn_feature_extractor.py:149] EfficientDet BiFPN num iterations: 8
# I0805 18:57:36.854276 140407809644416 efficientnet_model.py:143] round_filter input=32 output=56
# I0805 18:57:36.870034 140407809644416 efficientnet_model.py:143] round_filter input=32 output=56
# I0805 18:57:36.870139 140407809644416 efficientnet_model.py:143] round_filter input=16 output=32
# I0805 18:57:37.061256 140407809644416 efficientnet_model.py:143] round_filter input=16 output=32
# I0805 18:57:37.061428 140407809644416 efficientnet_model.py:143] round_filter input=24 output=40
# I0805 18:57:37.531337 140407809644416 efficientnet_model.py:143] round_filter input=24 output=40
# I0805 18:57:37.531515 140407809644416 efficientnet_model.py:143] round_filter input=40 output=72
# I0805 18:57:38.019296 140407809644416 efficientnet_model.py:143] round_filter input=40 output=72
# I0805 18:57:38.019478 140407809644416 efficientnet_model.py:143] round_filter input=80 output=144
# I0805 18:57:38.681513 140407809644416 efficientnet_model.py:143] round_filter input=80 output=144
# I0805 18:57:38.681695 140407809644416 efficientnet_model.py:143] round_filter input=112 output=200
# I0805 18:57:39.337439 140407809644416 efficientnet_model.py:143] round_filter input=112 output=200
# I0805 18:57:39.337617 140407809644416 efficientnet_model.py:143] round_filter input=192 output=344
# I0805 18:57:40.238184 140407809644416 efficientnet_model.py:143] round_filter input=192 output=344
# I0805 18:57:40.238368 140407809644416 efficientnet_model.py:143] round_filter input=320 output=576
# I0805 18:57:40.478705 140407809644416 efficientnet_model.py:143] round_filter input=1280 output=2304
# I0805 18:57:40.507950 140407809644416 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.8, depth_coefficient=2.6, resolution=528, dropout_rate=0.5, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0805 18:57:40.818848 140407809644416 ssd_efficientnet_bifpn_feature_extractor.py:146] EfficientDet EfficientNet backbone version: efficientnet-b7
# I0805 18:57:40.819017 140407809644416 ssd_efficientnet_bifpn_feature_extractor.py:147] EfficientDet BiFPN num filters: 384
# I0805 18:57:40.819101 140407809644416 ssd_efficientnet_bifpn_feature_extractor.py:149] EfficientDet BiFPN num iterations: 8
# I0805 18:57:40.820691 140407809644416 efficientnet_model.py:143] round_filter input=32 output=64
# I0805 18:57:40.843772 140407809644416 efficientnet_model.py:143] round_filter input=32 output=64
# I0805 18:57:40.843921 140407809644416 efficientnet_model.py:143] round_filter input=16 output=32
# I0805 18:57:41.104034 140407809644416 efficientnet_model.py:143] round_filter input=16 output=32
# I0805 18:57:41.104214 140407809644416 efficientnet_model.py:143] round_filter input=24 output=48
# I0805 18:57:41.655284 140407809644416 efficientnet_model.py:143] round_filter input=24 output=48
# I0805 18:57:41.655459 140407809644416 efficientnet_model.py:143] round_filter input=40 output=80
# I0805 18:57:42.226685 140407809644416 efficientnet_model.py:143] round_filter input=40 output=80
# I0805 18:57:42.226877 140407809644416 efficientnet_model.py:143] round_filter input=80 output=160
# I0805 18:57:43.020232 140407809644416 efficientnet_model.py:143] round_filter input=80 output=160
# I0805 18:57:43.020416 140407809644416 efficientnet_model.py:143] round_filter input=112 output=224
# I0805 18:57:43.819544 140407809644416 efficientnet_model.py:143] round_filter input=112 output=224
# I0805 18:57:43.819729 140407809644416 efficientnet_model.py:143] round_filter input=192 output=384
# I0805 18:57:44.861784 140407809644416 efficientnet_model.py:143] round_filter input=192 output=384
# I0805 18:57:44.861976 140407809644416 efficientnet_model.py:143] round_filter input=320 output=640
# I0805 18:57:45.205462 140407809644416 efficientnet_model.py:143] round_filter input=1280 output=2560
# I0805 18:57:45.234982 140407809644416 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=2.0, depth_coefficient=3.1, resolution=600, dropout_rate=0.5, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_ssd_models_from_config): 22.54s
# I0805 18:57:45.353813 140407809644416 test_util.py:2459] time(__main__.ModelBuilderTF2Test.test_create_ssd_models_from_config): 22.54s
# [       OK ] ModelBuilderTF2Test.test_create_ssd_models_from_config
# [ RUN      ] ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update): 0.0s
# I0805 18:57:45.359598 140407809644416 test_util.py:2459] time(__main__.ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update
# [ RUN      ] ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold): 0.0s
# I0805 18:57:45.361399 140407809644416 test_util.py:2459] time(__main__.ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold
# [ RUN      ] ModelBuilderTF2Test.test_invalid_model_config_proto
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_model_config_proto): 0.0s
# I0805 18:57:45.361903 140407809644416 test_util.py:2459] time(__main__.ModelBuilderTF2Test.test_invalid_model_config_proto): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_model_config_proto
# [ RUN      ] ModelBuilderTF2Test.test_invalid_second_stage_batch_size
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_second_stage_batch_size): 0.0s
# I0805 18:57:45.363377 140407809644416 test_util.py:2459] time(__main__.ModelBuilderTF2Test.test_invalid_second_stage_batch_size): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_second_stage_batch_size
# [ RUN      ] ModelBuilderTF2Test.test_session
# [  SKIPPED ] ModelBuilderTF2Test.test_session
# [ RUN      ] ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor): 0.0s
# I0805 18:57:45.364730 140407809644416 test_util.py:2459] time(__main__.ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor
# [ RUN      ] ModelBuilderTF2Test.test_unknown_meta_architecture
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_meta_architecture): 0.0s
# I0805 18:57:45.365228 140407809644416 test_util.py:2459] time(__main__.ModelBuilderTF2Test.test_unknown_meta_architecture): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_meta_architecture
# [ RUN      ] ModelBuilderTF2Test.test_unknown_ssd_feature_extractor
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_ssd_feature_extractor): 0.0s
# I0805 18:57:45.366276 140407809644416 test_util.py:2459] time(__main__.ModelBuilderTF2Test.test_unknown_ssd_feature_extractor): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_ssd_feature_extractor
# ----------------------------------------------------------------------
# Ran 24 tests in 27.633s
#
# OK (skipped=1)

# %%
import object_detection

# %%
if os.name =='posix':
    # !wget {PRETRAINED_MODEL_URL}
    # !mv {PRETRAINED_MODEL_NAME+'.tar.gz'} {paths['PRETRAINED_MODEL_PATH']}
    # !cd {paths['PRETRAINED_MODEL_PATH']} && tar -zxvf {PRETRAINED_MODEL_NAME+'.tar.gz'}
if os.name == 'nt':
    wget.download(PRETRAINED_MODEL_URL)
    # !move {PRETRAINED_MODEL_NAME+'.tar.gz'} {paths['PRETRAINED_MODEL_PATH']}
    # !cd {paths['PRETRAINED_MODEL_PATH']} && tar -zxvf {PRETRAINED_MODEL_NAME+'.tar.gz'}
# Out:
# --2022-08-05 19:02:37--  http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz
# Resolving download.tensorflow.org (download.tensorflow.org)... 142.250.125.128, 2607:f8b0:4001:c2f::80
# Connecting to download.tensorflow.org (download.tensorflow.org)|142.250.125.128|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 20515344 (20M) [application/x-tar]
# Saving to: ‘ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz’
#
# ssd_mobilenet_v2_fp 100%[===================>]  19.56M  --.-KB/s    in 0.1s
#
# 2022-08-05 19:02:37 (144 MB/s) - ‘ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz’ saved [20515344/20515344]
#
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/ckpt-0.data-00000-of-00001
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/checkpoint
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/ckpt-0.index
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/pipeline.config
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/saved_model.pb
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/variables/
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/variables/variables.data-00000-of-00001
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/variables/variables.index

# %% [markdown]
# # 2. Create Label Map

# %%
labels = [{'name':'pollinated', 'id':1}, {'name':'ready', 'id':2}, {'name':'notready', 'id':3}]

with open(files['LABELMAP'], 'w') as f:
    for label in labels:
        f.write('item { \n')
        f.write('\tname:\'{}\'\n'.format(label['name']))
        f.write('\tid:{}\n'.format(label['id']))
        f.write('}\n')

# %% [markdown]
# # 3. Create TF records

# %%
# !apt-get install rar
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# The following NEW packages will be installed:
#   rar
# 0 upgraded, 1 newly installed, 0 to remove and 19 not upgraded.
# Need to get 295 kB of archives.
# After this operation, 799 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/multiverse amd64 rar amd64 2:5.5.0-1 [295 kB]
# Fetched 295 kB in 0s (790 kB/s)
# Selecting previously unselected package rar.
# (Reading database ... 155680 files and directories currently installed.)
# Preparing to unpack .../rar_2%3a5.5.0-1_amd64.deb ...
# Unpacking rar (2:5.5.0-1) ...
# Setting up rar (2:5.5.0-1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unrar x -Y "/content/drive/MyDrive/dataset/images3.rar" "/content/Tensorflow/workspace/images/"
# Out:
# UNRAR 5.50 freeware      Copyright (c) 1993-2017 Alexander Roshal
#
#
# Extracting from /content/drive/MyDrive/dataset/images3.rar
#
# Creating    /content/Tensorflow/workspace/images/test                 OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    /content/Tensorflow/workspace/images/train                OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# All OK

# %%
if not os.path.exists(files['TF_RECORD_SCRIPT']):
    # !git clone https://github.com/nicknochnack/GenerateTFRecord {paths['SCRIPTS_PATH']}
# Out:
# Cloning into 'Tensorflow/scripts'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 3 (delta 0), reused 1 (delta 0), pack-reused 0
# Unpacking objects: 100% (3/3), done.

# %%
# !python {files['TF_RECORD_SCRIPT']} -x {os.path.join(paths['IMAGE_PATH'], 'train')} -l {files['LABELMAP']} -o {os.path.join(paths['ANNOTATION_PATH'], 'train.record')} 
# !python {files['TF_RECORD_SCRIPT']} -x {os.path.join(paths['IMAGE_PATH'], 'test')} -l {files['LABELMAP']} -o {os.path.join(paths['ANNOTATION_PATH'], 'test.record')}
# Out:
# Successfully created the TFRecord file: Tensorflow/workspace/annotations/train.record
# Successfully created the TFRecord file: Tensorflow/workspace/annotations/test.record

# %% [markdown]
# # 4. Copy Model Config to Training Folder

# %%
if os.name =='posix':
    # !cp {os.path.join(paths['PRETRAINED_MODEL_PATH'], PRETRAINED_MODEL_NAME, 'pipeline.config')} {os.path.join(paths['CHECKPOINT_PATH'])}
if os.name == 'nt':
    # !copy {os.path.join(paths['PRETRAINED_MODEL_PATH'], PRETRAINED_MODEL_NAME, 'pipeline.config')} {os.path.join(paths['CHECKPOINT_PATH'])}

# %% [markdown]
# # 5. Update Config For Transfer Learning

# %%
import tensorflow as tf
from object_detection.utils import config_util
from object_detection.protos import pipeline_pb2
from google.protobuf import text_format

# %%
config = config_util.get_configs_from_pipeline_file(files['PIPELINE_CONFIG'])

# %%
config
# Out:
# {'eval_config': metrics_set: "coco_detection_metrics"
#  use_moving_averages: false,
#  'eval_input_config': label_map_path: "PATH_TO_BE_CONFIGURED"
#  shuffle: false
#  num_epochs: 1
#  tf_record_input_reader {
#    input_path: "PATH_TO_BE_CONFIGURED"
#  },
#  'eval_input_configs': [label_map_path: "PATH_TO_BE_CONFIGURED"
#  shuffle: false
#  num_epochs: 1
#  tf_record_input_reader {
#    input_path: "PATH_TO_BE_CONFIGURED"
#  }
#  ],
#  'model': ssd {
#    num_classes: 90
#    image_resizer {
#      fixed_shape_resizer {
#        height: 320
#        width: 320
#      }
#    }
#    feature_extractor {
#      type: "ssd_mobilenet_v2_fpn_keras"
#      depth_multiplier: 1.0
#      min_depth: 16
#      conv_hyperparams {
#        regularizer {
#          l2_regularizer {
#            weight: 3.9999998989515007e-05
#          }
#        }
#        initializer {
#          random_normal_initializer {
#            mean: 0.0
#            stddev: 0.009999999776482582
#          }
#        }
#        activation: RELU_6
#        batch_norm {
#          decay: 0.996999979019165
#          scale: true
#          epsilon: 0.0010000000474974513
#        }
#      }
#      use_depthwise: true
#      override_base_feature_extractor_hyperparams: true
#      fpn {
#        min_level: 3
#        max_level: 7
#        additional_layer_depth: 128
#      }
#    }
#    box_coder {
#      faster_rcnn_box_coder {
#        y_scale: 10.0
#        x_scale: 10.0
#        height_scale: 5.0
#        width_scale: 5.0
#      }
#    }
#    matcher {
#      argmax_matcher {
#        matched_threshold: 0.5
#        unmatched_threshold: 0.5
#        ignore_thresholds: false
#        negatives_lower_than_unmatched: true
#        force_match_for_each_row: true
#        use_matmul_gather: true
#      }
#    }
#    similarity_calculator {
#      iou_similarity {
#      }
#    }
#    box_predictor {
#      weight_shared_convolutional_box_predictor {
#        conv_hyperparams {
#          regularizer {
#            l2_regularizer {
#              weight: 3.9999998989515007e-05
#            }
#          }
#          initializer {
#            random_normal_initializer {
#              mean: 0.0
#              stddev: 0.009999999776482582
#            }
#          }
#          activation: RELU_6
#          batch_norm {
#            decay: 0.996999979019165
#            scale: true
#            epsilon: 0.0010000000474974513
#          }
#        }
#        depth: 128
#        num_layers_before_predictor: 4
#        kernel_size: 3
#        class_prediction_bias_init: -4.599999904632568
#        share_prediction_tower: true
#        use_depthwise: true
#      }
#    }
#    anchor_generator {
#      multiscale_anchor_generator {
#        min_level: 3
#        max_level: 7
#        anchor_scale: 4.0
#        aspect_ratios: 1.0
#        aspect_ratios: 2.0
#        aspect_ratios: 0.5
#        scales_per_octave: 2
#      }
#    }
#    post_processing {
#      batch_non_max_suppression {
#        score_threshold: 9.99999993922529e-09
#        iou_threshold: 0.6000000238418579
#        max_detections_per_class: 100
#        max_total_detections: 100
#        use_static_shapes: false
#      }
#      score_converter: SIGMOID
#    }
#    normalize_loss_by_num_matches: true
#    loss {
#      localization_loss {
#        weighted_smooth_l1 {
#        }
#      }
#      classification_loss {
#        weighted_sigmoid_focal {
#          gamma: 2.0
#          alpha: 0.25
#        }
#      }
#      classification_weight: 1.0
#      localization_weight: 1.0
#    }
#    encode_background_as_zeros: true
#    normalize_loc_loss_by_codesize: true
#    inplace_batchnorm_update: true
#    freeze_batchnorm: false
#  },
#  'train_config': batch_size: 128
#  data_augmentation_options {
#    random_horizontal_flip {
#    }
#  }
#  data_augmentation_options {
#    random_crop_image {
#      min_object_covered: 0.0
#      min_aspect_ratio: 0.75
#      max_aspect_ratio: 3.0
#      min_area: 0.75
#      max_area: 1.0
#      overlap_thresh: 0.0
#    }
#  }
#  sync_replicas: true
#  optimizer {
#    momentum_optimizer {
#      learning_rate {
#        cosine_decay_learning_rate {
#          learning_rate_base: 0.07999999821186066
#          total_steps: 50000
#          warmup_learning_rate: 0.026666000485420227
#          warmup_steps: 1000
#        }
#      }
#      momentum_optimizer_value: 0.8999999761581421
#    }
#    use_moving_average: false
#  }
#  fine_tune_checkpoint: "PATH_TO_BE_CONFIGURED"
#  num_steps: 50000
#  startup_delay_steps: 0.0
#  replicas_to_aggregate: 8
#  max_number_of_boxes: 100
#  unpad_groundtruth_tensors: false
#  fine_tune_checkpoint_type: "classification"
#  fine_tune_checkpoint_version: V2,
#  'train_input_config': label_map_path: "PATH_TO_BE_CONFIGURED"
#  tf_record_input_reader {
#    input_path: "PATH_TO_BE_CONFIGURED"
#  }}

# %%
pipeline_config = pipeline_pb2.TrainEvalPipelineConfig()
with tf.io.gfile.GFile(files['PIPELINE_CONFIG'], "r") as f:                                                                                                                                                                                                                     
    proto_str = f.read()                                                                                                                                                                                                                                          
    text_format.Merge(proto_str, pipeline_config)

# %%
pipeline_config.model.ssd.num_classes = len(labels)
pipeline_config.train_config.batch_size = 4
pipeline_config.train_config.fine_tune_checkpoint = os.path.join(paths['PRETRAINED_MODEL_PATH'], PRETRAINED_MODEL_NAME, 'checkpoint', 'ckpt-0')
pipeline_config.train_config.fine_tune_checkpoint_type = "detection"
pipeline_config.train_input_reader.label_map_path= files['LABELMAP']
pipeline_config.train_input_reader.tf_record_input_reader.input_path[:] = [os.path.join(paths['ANNOTATION_PATH'], 'train.record')]
pipeline_config.eval_input_reader[0].label_map_path = files['LABELMAP']
pipeline_config.eval_input_reader[0].tf_record_input_reader.input_path[:] = [os.path.join(paths['ANNOTATION_PATH'], 'test.record')]

# %%
config_text = text_format.MessageToString(pipeline_config)                                                                                                                                                                                                        
with tf.io.gfile.GFile(files['PIPELINE_CONFIG'], "wb") as f:                                                                                                                                                                                                                     
    f.write(config_text)

# %% [markdown]
# # 6. Train the model

# %%
# !apt install --allow-change-held-packages libcudnn8=8.1.0.77-1+cuda11.2
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# The following packages will be REMOVED:
#   libcudnn8-dev
# The following held packages will be changed:
#   libcudnn8
# The following packages will be upgraded:
#   libcudnn8
# 1 upgraded, 0 newly installed, 1 to remove and 17 not upgraded.
# Need to get 430 MB of archives.
# After this operation, 3,139 MB disk space will be freed.
# Get:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  libcudnn8 8.1.0.77-1+cuda11.2 [430 MB]
# Fetched 430 MB in 7s (60.3 MB/s)
# (Reading database ... 155694 files and directories currently installed.)
# Removing libcudnn8-dev (8.0.5.39-1+cuda11.1) ...
# (Reading database ... 155672 files and directories currently installed.)
# Preparing to unpack .../libcudnn8_8.1.0.77-1+cuda11.2_amd64.deb ...
# Unpacking libcudnn8 (8.1.0.77-1+cuda11.2) over (8.0.5.39-1+cuda11.1) ...
# Setting up libcudnn8 (8.1.0.77-1+cuda11.2) ...

# %%
pip install "opencv-python-headless<4.3"
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting opencv-python-headless<4.3
#   Downloading opencv_python_headless-4.2.0.34-cp37-cp37m-manylinux1_x86_64.whl (21.6 MB)
#      |████████████████████████████████| 21.6 MB 1.2 MB/s
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from opencv-python-headless<4.3) (1.21.6)
# Installing collected packages: opencv-python-headless
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.6.0.66
#     Uninstalling opencv-python-headless-4.6.0.66:
#       Successfully uninstalled opencv-python-headless-4.6.0.66
# Successfully installed opencv-python-headless-4.2.0.34

# %%
TRAINING_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'model_main_tf2.py')

# %%
command = "python {} --model_dir={} --pipeline_config_path={} --num_train_steps=40000".format(TRAINING_SCRIPT, paths['CHECKPOINT_PATH'],files['PIPELINE_CONFIG'])

# %%
print(command)
# Out:
# python Tensorflow/models/research/object_detection/model_main_tf2.py --model_dir=Tensorflow/workspace/models/my_ssd_mobnet --pipeline_config_path=Tensorflow/workspace/models/my_ssd_mobnet/pipeline.config --num_train_steps=40000

# %%
# !{command}
# Out:
# 2022-08-05 19:07:27.691462: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# I0805 19:07:27.699479 140025591211904 mirrored_strategy.py:374] Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# INFO:tensorflow:Maybe overwriting train_steps: 40000
# I0805 19:07:27.705093 140025591211904 config_util.py:552] Maybe overwriting train_steps: 40000
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I0805 19:07:27.705294 140025591211904 config_util.py:552] Maybe overwriting use_bfloat16: False
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/object_detection/model_lib_v2.py:564: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# W0805 19:07:27.735928 140025591211904 deprecation.py:356] From /usr/local/lib/python3.7/dist-packages/object_detection/model_lib_v2.py:564: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# INFO:tensorflow:Reading unweighted datasets: ['Tensorflow/workspace/annotations/train.record']
# I0805 19:07:27.740020 140025591211904 dataset_builder.py:162] Reading unweighted datasets: ['Tensorflow/workspace/annotations/train.record']
# INFO:tensorflow:Reading record datasets for input file: ['Tensorflow/workspace/annotations/train.record']
# I0805 19:07:27.740206 140025591211904 dataset_builder.py:79] Reading record datasets for input file: ['Tensorflow/workspace/annotations/train.record']
# INFO:tensorflow:Number of filenames to read: 1
# I0805 19:07:27.740295 140025591211904 dataset_builder.py:80] Number of filenames to read: 1
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.
# W0805 19:07:27.740371 140025591211904 dataset_builder.py:87] num_readers has been reduced to 1 to match input file shards.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/object_detection/builders/dataset_builder.py:104: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# W0805 19:07:27.742553 140025591211904 deprecation.py:356] From /usr/local/lib/python3.7/dist-packages/object_detection/builders/dataset_builder.py:104: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/object_detection/builders/dataset_builder.py:236: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# W0805 19:07:27.761615 140025591211904 deprecation.py:356] From /usr/local/lib/python3.7/dist-packages/object_detection/builders/dataset_builder.py:236: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# W0805 19:07:34.763268 140025591211904 deprecation.py:356] From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# W0805 19:07:37.773314 140025591211904 deprecation.py:356] From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0805 19:07:39.452875 140025591211904 deprecation.py:356] From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# 2022-08-05 19:07:42.828184: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 16027200 exceeds 10% of free system memory.
# 2022-08-05 19:07:42.931592: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 17798433 exceeds 10% of free system memory.
# 2022-08-05 19:07:42.956789: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 17798433 exceeds 10% of free system memory.
# 2022-08-05 19:07:43.063930: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 18735876 exceeds 10% of free system memory.
# 2022-08-05 19:07:43.065863: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 14926068 exceeds 10% of free system memory.
# /usr/local/lib/python3.7/dist-packages/keras/backend.py:450: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn('`tf.keras.backend.set_learning_phase` is deprecated and '
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0805 19:08:07.786254 140025591211904 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0805 19:08:07.787665 140025591211904 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0805 19:08:07.791180 140025591211904 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0805 19:08:07.792144 140025591211904 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0805 19:08:07.794200 140025591211904 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0805 19:08:07.795114 140025591211904 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0805 19:08:07.797264 140025591211904 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0805 19:08:07.798195 140025591211904 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0805 19:08:07.800328 140025591211904 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0805 19:08:07.801233 140025591211904 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/deprecation.py:629: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# W0805 19:08:08.576673 140020705044224 deprecation.py:560] From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/deprecation.py:629: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# INFO:tensorflow:Step 100 per-step time 0.540s
# I0805 19:09:02.086893 140025591211904 model_lib_v2.py:707] Step 100 per-step time 0.540s
# INFO:tensorflow:{'Loss/classification_loss': 0.28141442,
#  'Loss/localization_loss': 0.22738245,
#  'Loss/regularization_loss': 0.15409665,
#  'Loss/total_loss': 0.66289353,
#  'learning_rate': 0.0319994}
# I0805 19:09:02.087293 140025591211904 model_lib_v2.py:708] {'Loss/classification_loss': 0.28141442,
#  'Loss/localization_loss': 0.22738245,
#  'Loss/regularization_loss': 0.15409665,
#  'Loss/total_loss': 0.66289353,
#  'learning_rate': 0.0319994}
# INFO:tensorflow:Step 200 per-step time 0.165s
# I0805 19:09:18.533107 140025591211904 model_lib_v2.py:707] Step 200 per-step time 0.165s
# INFO:tensorflow:{'Loss/classification_loss': 0.17109296,
#  'Loss/localization_loss': 0.13561806,
#  'Loss/regularization_loss': 0.15433782,
#  'Loss/total_loss': 0.46104884,
#  'learning_rate': 0.0373328}
# I0805 19:09:18.533549 140025591211904 model_lib_v2.py:708] {'Loss/classification_loss': 0.17109296,
#  'Loss/localization_loss': 0.13561806,
#  'Loss/regularization_loss': 0.15433782,
#  'Loss/total_loss': 0.46104884,
#  'learning_rate': 0.0373328}
# INFO:tensorflow:Step 300 per-step time 0.170s
# I0805 19:09:35.593021 140025591211904 model_lib_v2.py:707] Step 300 per-step time 0.170s
# INFO:tensorflow:{'Loss/classification_loss': 0.13207151,
#  'Loss/localization_loss': 0.11546309,
#  'Loss/regularization_loss': 0.15407443,
#  'Loss/total_loss': 0.40160903,
#  'learning_rate': 0.0426662}
# I0805 19:09:35.593439 140025591211904 model_lib_v2.py:708] {'Loss/classification_loss': 0.13207151,
#  'Loss/localization_loss': 0.11546309,
#  'Loss/regularization_loss': 0.15407443,
#  'Loss/total_loss': 0.40160903,
#  'learning_rate': 0.0426662}
# INFO:tensorflow:Step 400 per-step time 0.182s
# I0805 19:09:53.835978 140025591211904 model_lib_v2.py:707] Step 400 per-step time 0.182s
# INFO:tensorflow:{'Loss/classification_loss': 0.1339395,
#  'Loss/localization_loss': 0.08025031,
#  'Loss/regularization_loss': 0.15372819,
#  'Loss/total_loss': 0.367918,
#  'learning_rate': 0.047999598}
# I0805 19:09:53.836374 140025591211904 model_lib_v2.py:708] {'Loss/classification_loss': 0.1339395,
#  'Loss/localization_loss': 0.08025031,
#  'Loss/regularization_loss': 0.15372819,
#  'Loss/total_loss': 0.367918,
#  'learning_rate': 0.047999598}
# INFO:tensorflow:Step 500 per-step time 0.162s
# I0805 19:10:10.062457 140025591211904 model_lib_v2.py:707] Step 500 per-step time 0.162s
# INFO:tensorflow:{'Loss/classification_loss': 0.11386973,
#  'Loss/localization_loss': 0.10080018,
#  'Loss/regularization_loss': 0.15334064,
#  'Loss/total_loss': 0.36801055,
#  'learning_rate': 0.053333}
# I0805 19:10:10.062807 140025591211904 model_lib_v2.py:708] {'Loss/classification_loss': 0.11386973,
#  'Loss/localization_loss': 0.10080018,
#  'Loss/regularization_loss': 0.15334064,
#  'Loss/total_loss': 0.36801055,
#  'learning_rate': 0.053333}
# INFO:tensorflow:Step 600 per-step time 0.165s
# I0805 19:10:26.550873 140025591211904 model_lib_v2.py:707] Step 600 per-step time 0.165s
# INFO:tensorflow:{'Loss/classification_loss': 0.10403513,
#  'Loss/localization_loss': 0.06711014,
#  'Loss/regularization_loss': 0.15287998,
#  'Loss/total_loss': 0.32402527,
#  'learning_rate': 0.0586664}
# I0805 19:10:26.551242 140025591211904 model_lib_v2.py:708] {'Loss/classification_loss': 0.10403513,
#  'Loss/localization_loss': 0.06711014,
#  'Loss/regularization_loss': 0.15287998,
#  'Loss/total_loss': 0.32402527,
#  'learning_rate': 0.0586664}
# INFO:tensorflow:Step 700 per-step time 0.170s
# I0805 19:10:43.515319 140025591211904 model_lib_v2.py:707] Step 700 per-step time 0.170s
# INFO:tensorflow:{'Loss/classification_loss': 0.07913568,
#  'Loss/localization_loss': 0.043601017,
#  'Loss/regularization_loss': 0.15237142,
#  'Loss/total_loss': 0.2751081,
#  'learning_rate': 0.0639998}
# I0805 19:10:43.515701 140025591211904 model_lib_v2.py:708] {'Loss/classification_loss': 0.07913568,
#  'Loss/localization_loss': 0.043601017,
#  'Loss/regularization_loss': 0.15237142,
#  'Loss/total_loss': 0.2751081,
#  'learning_rate': 0.0639998}
# INFO:tensorflow:Step 800 per-step time 0.167s
# I0805 19:11:00.254935 140025591211904 model_lib_v2.py:707] Step 800 per-step time 0.167s
# INFO:tensorflow:{'Loss/classification_loss': 0.106702834,
#  'Loss/localization_loss': 0.06900168,
#  'Loss/regularization_loss': 0.15180014,
#  'Loss/total_loss': 0.32750463,
#  'learning_rate': 0.069333196}
# I0805 19:11:00.255295 140025591211904 model_lib_v2.py:708] {'Loss/classification_loss': 0.106702834,
#  'Loss/localization_loss': 0.06900168,
#  'Loss/regularization_loss': 0.15180014,
#  'Loss/total_loss': 0.32750463,
#  'learning_rate': 0.069333196}
# INFO:tensorflow:Step 900 per-step time 0.168s
# I0805 19:11:17.017762 140025591211904 model_lib_v2.py:707] Step 900 per-step time 0.168s
# INFO:tensorflow:{'Loss/classification_loss': 0.114556186,
#  'Loss/localization_loss': 0.069977015,
#  'Loss/regularization_loss': 0.15190995,
#  'Loss/total_loss': 0.33644316,
#  'learning_rate': 0.074666604}
# I0805 19:11:17.018145 140025591211904 model_lib_v2.py:708] {'Loss/classification_loss': 0.114556186,
#  'Loss/localization_loss': 0.069977015,
#  'Loss/regularization_loss': 0.15190995,
#  'Loss/total_loss': 0.33644316,
#  'learning_rate': 0.074666604}
# INFO:tensorflow:Step 1000 per-step time 0.193s
# I0805 19:11:36.338711 140025591211904 model_lib_v2.py:707] Step 1000 per-step time 0.193s
# INFO:tensorflow:{'Loss/classification_loss': 0.07568451,
#  'Loss/localization_loss': 0.05685626,
#  'Loss/regularization_loss': 0.15142667,
#  'Loss/total_loss': 0.28396744,
#  'learning_rate': 0.08}
# I0805 19:11:36.339134 140025591211904 model_lib_v2.py:708] {'Loss/classification_loss': 0.07568451,
#  'Loss/localization_loss': 0.05685626,
#  'Loss/regularization_loss': 0.15142667,
#  'Loss/total_loss': 0.28396744,
#  'learning_rate': 0.08}
# INFO:tensorflow:Step 1100 per-step time 0.170s
# I0805 19:11:53.369901 140025591211904 model_lib_v2.py:707] Step 1100 per-step time 0.170s
# INFO:tensorflow:{'Loss/classification_loss': 0.07492783,
#  'Loss/localization_loss': 0.034204304,
#  'Loss/regularization_loss': 0.15073064,
#  'Loss/total_loss': 0.25986278,
#  'learning_rate': 0.07999918}
# I0805 19:11:53.370279 140025591211904 model_lib_v2.py:708] {'Loss/classification_loss': 0.07492783,
#  'Loss/localization_loss': 0.034204304,
#  'Loss/regularization_loss': 0.15073064,
#  'Loss/total_loss': 0.25986278,
#  'learning_rate': 0.07999918}
# INFO:tensorflow:Step 1200 per-step time 0.154s
# I0805 19:12:08.784480 140025591211904 model_lib_v2.py:707] Step 1200 per-step time 0.154s
# INFO:tensorflow:{'Loss/classification_loss': 0.08708386,
#  'Loss/localization_loss': 0.03392602,
#  'Loss/regularization_loss': 0.14996368,
#  'Loss/total_loss': 0.27097356,
#  'learning_rate': 0.079996705}
# I0805 19:12:08.784918 140025591211904 model_lib_v2.py:708] {'Loss/classification_loss': 0.08708386,
#  'Loss/localization_loss': 0.03392602,
#  'Loss/regularization_loss': 0.14996368,
#  'Loss/total_loss': 0.27097356,
#  'learning_rate': 0.079996705}
# INFO:tensorflow:Step 1300 per-step time 0.157s
# I0805 19:12:24.509214 140025591211904 model_lib_v2.py:707] Step 1300 per-step time 0.157s
# INFO:tensorflow:{'Loss/classification_loss': 0.06537392,
#  'Loss/localization_loss': 0.021613305,
#  'Loss/regularization_loss': 0.14917773,
#  'Loss/total_loss': 0.23616496,
#  'learning_rate': 0.0799926}
# I0805 19:12:24.509572 140025591211904 model_lib_v2.py:708] {'Loss/classification_loss': 0.06537392,
#  'Loss/localization_loss': 0.021613305,
#  'Loss/regularization_loss': 0.14917773,
#  'Loss/total_loss': 0.23616496,
#  'learning_rate': 0.0799926}
# INFO:tensorflow:Step 1400 per-step time 0.174s
# I0805 19:12:41.891131 140025591211904 model_lib_v2.py:707] Step 1400 per-step time 0.174s
# INFO:tensorflow:{'Loss/classification_loss': 0.059333242,
#  'Loss/localization_loss': 0.026149035,
#  'Loss/regularization_loss': 0.14836243,
#  'Loss/total_loss': 0.2338447,
#  'learning_rate': 0.07998685}
# I0805 19:12:41.891500 140025591211904 model_lib_v2.py:708] {'Loss/classification_loss': 0.059333242,
#  'Loss/localization_loss': 0.026149035,
#  'Loss/regularization_loss': 0.14836243,
#  'Loss/total_loss': 0.2338447,
#  'learning_rate': 0.07998685}
# INFO:tensorflow:Step 1500 per-step time 0.166s
# I0805 19:12:58.524851 140025591211904 model_lib_v2.py:707] Step 1500 per-step time 0.166s
# INFO:tensorflow:{'Loss/classification_loss': 0.07701641,
#  'Loss/localization_loss': 0.030792745,
#  'Loss/regularization_loss': 0.14756978,
#  'Loss/total_loss': 0.25537893,
#  'learning_rate': 0.07997945}
# I0805 19:12:58.525249 140025591211904 model_lib_v2.py:708] {'Loss/classification_loss': 0.07701641,
#  'Loss/localization_loss': 0.030792745,
#  'Loss/regularization_loss': 0.14756978,
#  'Loss/total_loss': 0.25537893,
#  'learning_rate': 0.07997945}
# INFO:tensorflow:Step 1600 per-step time 0.185s
# I0805 19:13:17.035135 140025591211904 model_lib_v2.py:707] Step 1600 per-step time 0.185s
# INFO:tensorflow:{'Loss/classification_loss': 0.068321794,
#  'Loss/localization_loss': 0.023995735,
#  'Loss/regularization_loss': 0.14677112,
#  'Loss/total_loss': 0.23908865,
#  'learning_rate': 0.079970405}
# I0805 19:13:17.035505 140025591211904 model_lib_v2.py:708] {'Loss/classification_loss': 0.068321794,
#  'Loss/localization_loss': 0.023995735,
#  'Loss/regularization_loss': 0.14677112,
#  'Loss/total_loss': 0.23908865,
#  'learning_rate': 0.079970405}
# INFO:tensorflow:Step 1700 per-step time 0.164s
# I0805 19:13:33.460901 140025591211904 model_lib_v2.py:707] Step 1700 per-step time 0.164s
# INFO:tensorflow:{'Loss/classification_loss': 0.06094725,
#  'Loss/localization_loss': 0.024632283,
#  'Loss/regularization_loss': 0.14602336,
#  'Loss/total_loss': 0.23160289,
#  'learning_rate': 0.07995972}
# I0805 19:13:33.461272 140025591211904 model_lib_v2.py:708] {'Loss/classification_loss': 0.06094725,
#  'Loss/localization_loss': 0.024632283,
#  'Loss/regularization_loss': 0.14602336,
#  'Loss/total_loss': 0.23160289,
#  'learning_rate': 0.07995972}
# INFO:tensorflow:Step 1800 per-step time 0.170s
# I0805 19:13:50.494446 140025591211904 model_lib_v2.py:707] Step 1800 per-step time 0.170s
# INFO:tensorflow:{'Loss/classification_loss': 0.07307868,
#  'Loss/localization_loss': 0.026890242,
#  'Loss/regularization_loss': 0.14522871,
#  'Loss/total_loss': 0.24519762,
#  'learning_rate': 0.0799474}
# I0805 19:13:50.494939 140025591211904 model_lib_v2.py:708] {'Loss/classification_loss': 0.07307868,
#  'Loss/localization_loss': 0.026890242,
#  'Loss/regularization_loss': 0.14522871,
#  'Loss/total_loss': 0.24519762,
#  'learning_rate': 0.0799474}
# INFO:tensorflow:Step 1900 per-step time 0.158s
# I0805 19:14:06.241924 140025591211904 model_lib_v2.py:707] Step 1900 per-step time 0.158s
# INFO:tensorflow:{'Loss/classification_loss': 0.05720632,
#  'Loss/localization_loss': 0.024706522,
#  'Loss/regularization_loss': 0.14442873,
#  'Loss/total_loss': 0.22634158,
#  'learning_rate': 0.07993342}
# I0805 19:14:06.242296 140025591211904 model_lib_v2.py:708] {'Loss/classification_loss': 0.05720632,
#  'Loss/localization_loss': 0.024706522,
#  'Loss/regularization_loss': 0.14442873,
#  'Loss/total_loss': 0.22634158,
#  'learning_rate': 0.07993342}
# INFO:tensorflow:Step 2000 per-step time 0.167s
# I0805 19:14:22.889528 140025591211904 model_lib_v2.py:707] Step 2000 per-step time 0.167s
# INFO:tensorflow:{'Loss/classification_loss': 0.05071716,
#  'Loss/localization_loss': 0.017996525,
#  'Loss/regularization_loss': 0.14363587,
#  'Loss/total_loss': 0.21234956,
#  'learning_rate': 0.07991781}
# I0805 19:14:22.889934 140025591211904 model_lib_v2.py:708] {'Loss/classification_loss': 0.05071716,
#  'Loss/localization_loss': 0.017996525,
#  'Loss/regularization_loss': 0.14363587,
#  'Loss/total_loss': 0.21234956,
#  'learning_rate': 0.07991781}
# INFO:tensorflow:Step 2100 per-step time 0.192s
# I0805 19:14:42.119825 140025591211904 model_lib_v2.py:707] Step 2100 per-step time 0.192s
# INFO:tensorflow:{'Loss/classification_loss': 0.05902733,
#  'Loss/localization_loss': 0.0185135,
#  'Loss/regularization_loss': 0.14284138,
#  'Loss/total_loss': 0.22038221,
#  'learning_rate': 0.07990056}
# I0805 19:14:42.120208 140025591211904 model_lib_v2.py:708] {'Loss/classification_loss': 0.05902733,
#  'Loss/localization_loss': 0.0185135,
#  'Loss/regularization_loss': 0.14284138,
#  'Loss/total_loss': 0.22038221,
#  'learning_rate': 0.07990056}
# INFO:tensorflow:Step 2200 per-step time 0.186s
# I0805 19:15:00.741107 140025591211904 model_lib_v2.py:707] Step 2200 per-step time 0.186s
# INFO:tensorflow:{'Loss/classification_loss': 0.036800038,
#  'Loss/localization_loss': 0.011968907,
#  'Loss/regularization_loss': 0.14207555,
#  'Loss/total_loss': 0.1908445,
#  'learning_rate': 0.07988167}
# I0805 19:15:00.743743 140025591211904 model_lib_v2.py:708] {'Loss/classification_loss': 0.036800038,
#  'Loss/localization_loss': 0.011968907,
#  'Loss/regularization_loss': 0.14207555,
#  'Loss/total_loss': 0.1908445,
#  'learning_rate': 0.07988167}
# INFO:tensorflow:Step 2300 per-step time 0.160s
# I0805 19:15:16.682205 140025591211904 model_lib_v2.py:707] Step 2300 per-step time 0.160s
# INFO:tensorflow:{'Loss/classification_loss': 0.043260787,
#  'Loss/localization_loss': 0.012575427,
#  'Loss/regularization_loss': 0.1412801,
#  'Loss/total_loss': 0.19711632,
#  'learning_rate': 0.07986114}
# I0805 19:15:16.682662 140025591211904 model_lib_v2.py:708] {'Loss/classification_loss': 0.043260787,
#  'Loss/localization_loss': 0.012575427,
#  'Loss/regularization_loss': 0.1412801,
#  'Loss/total_loss': 0.19711632,
#  'learning_rate': 0.07986114}
# INFO:tensorflow:Step 2400 per-step time 0.173s
# I0805 19:15:33.949329 140025591211904 model_lib_v2.py:707] Step 2400 per-step time 0.173s
# INFO:tensorflow:{'Loss/classification_loss': 0.03686987,
#  'Loss/localization_loss': 0.012492951,
#  'Loss/regularization_loss': 0.14051346,
#  'Loss/total_loss': 0.18987629,
#  'learning_rate': 0.07983897}
# I0805 19:15:33.952767 140025591211904 model_lib_v2.py:708] {'Loss/classification_loss': 0.03686987,
#  'Loss/localization_loss': 0.012492951,
#  'Loss/regularization_loss': 0.14051346,
#  'Loss/total_loss': 0.18987629,
#  'learning_rate': 0.07983897}
# INFO:tensorflow:Step 2500 per-step time 0.172s
# I0805 19:15:51.163098 140025591211904 model_lib_v2.py:707] Step 2500 per-step time 0.172s
# INFO:tensorflow:{'Loss/classification_loss': 0.0557087,
#  'Loss/localization_loss': 0.021688022,
#  'Loss/regularization_loss': 0.13974977,
#  'Loss/total_loss': 0.21714649,
#  'learning_rate': 0.079815164}
# I0805 19:15:51.163521 140025591211904 model_lib_v2.py:708] {'Loss/classification_loss': 0.0557087,
#  'Loss/localization_loss': 0.021688022,
#  'Loss/regularization_loss': 0.13974977,
#  'Loss/total_loss': 0.21714649,
#  'learning_rate': 0.079815164}
# INFO:tensorflow:Step 2600 per-step time 0.166s
# I0805 19:16:07.749969 140025591211904 model_lib_v2.py:707] Step 2600 per-step time 0.166s
# INFO:tensorflow:{'Loss/classification_loss': 0.048485834,
#  'Loss/localization_loss': 0.01956805,
#  'Loss/regularization_loss': 0.13897228,
#  'Loss/total_loss': 0.20702617,
#  'learning_rate': 0.07978972}
# I0805 19:16:07.750380 140025591211904 model_lib_v2.py:708] {'Loss/classification_loss': 0.048485834,
#  'Loss/localization_loss': 0.01956805,
#  'Loss/regularization_loss': 0.13897228,
#  'Loss/total_loss': 0.20702617,
#  'learning_rate': 0.07978972}
# INFO:tensorflow:Step 2700 per-step time 0.194s
# I0805 19:16:27.184772 140025591211904 model_lib_v2.py:707] Step 2700 per-step time 0.194s
# INFO:tensorflow:{'Loss/classification_loss': 0.059702367,
#  'Loss/localization_loss': 0.04403292,
#  'Loss/regularization_loss': 0.13821188,
#  'Loss/total_loss': 0.24194716,
#  'learning_rate': 0.07976264}
# I0805 19:16:27.185175 140025591211904 model_lib_v2.py:708] {'Loss/classification_loss': 0.059702367,
#  'Loss/localization_loss': 0.04403292,
#  'Loss/regularization_loss': 0.13821188,
#  'Loss/total_loss': 0.24194716,
#  'learning_rate': 0.07976264}
# INFO:tensorflow:Step 2800 per-step time 0.172s
# I0805 19:16:44.360383 140025591211904 model_lib_v2.py:707] Step 2800 per-step time 0.172s
# INFO:tensorflow:{'Loss/classification_loss': 0.049251545,
#  'Loss/localization_loss': 0.020573366,
#  'Loss/regularization_loss': 0.13744126,
#  'Loss/total_loss': 0.20726618,
#  'learning_rate': 0.07973392}
# I0805 19:16:44.360873 140025591211904 model_lib_v2.py:708] {'Loss/classification_loss': 0.049251545,
#  'Loss/localization_loss': 0.020573366,
#  'Loss/regularization_loss': 0.13744126,
#  'Loss/total_loss': 0.20726618,
#  'learning_rate': 0.07973392}
# INFO:tensorflow:Step 2900 per-step time 0.176s
# I0805 19:17:01.913366 140025591211904 model_lib_v2.py:707] Step 2900 per-step time 0.176s
# INFO:tensorflow:{'Loss/classification_loss': 0.040267467,
#  'Loss/localization_loss': 0.012725364,
#  'Loss/regularization_loss': 0.13668156,
#  'Loss/total_loss': 0.18967439,
#  'learning_rate': 0.07970358}
# I0805 19:17:01.913734 140025591211904 model_lib_v2.py:708] {'Loss/classification_loss': 0.040267467,
#  'Loss/localization_loss': 0.012725364,
#  'Loss/regularization_loss': 0.13668156,
#  'Loss/total_loss': 0.18967439,
#  'learning_rate': 0.07970358}
# INFO:tensorflow:Step 3000 per-step time 0.157s
# I0805 19:17:17.633768 140025591211904 model_lib_v2.py:707] Step 3000 per-step time 0.157s
# INFO:tensorflow:{'Loss/classification_loss': 0.036714133,
#  'Loss/localization_loss': 0.022321785,
#  'Loss/regularization_loss': 0.1359145,
#  'Loss/total_loss': 0.19495043,
#  'learning_rate': 0.0796716}
# I0805 19:17:17.634178 140025591211904 model_lib_v2.py:708] {'Loss/classification_loss': 0.036714133,
#  'Loss/localization_loss': 0.022321785,
#  'Loss/regularization_loss': 0.1359145,
#  'Loss/total_loss': 0.19495043,
#  'learning_rate': 0.0796716}
# INFO:tensorflow:Step 3100 per-step time 0.171s
# I0805 19:17:34.712095 140025591211904 model_lib_v2.py:707] Step 3100 per-step time 0.171s
# INFO:tensorflow:{'Loss/classification_loss': 0.053637393,
#  'Loss/localization_loss': 0.015531684,
#  'Loss/regularization_loss': 0.13515256,
#  'Loss/total_loss': 0.20432164,
#  'learning_rate': 0.07963799}
# I0805 19:17:34.712855 140025591211904 model_lib_v2.py:708] {'Loss/classification_loss': 0.053637393,
#  'Loss/localization_loss': 0.015531684,
#  'Loss/regularization_loss': 0.13515256,
#  'Loss/total_loss': 0.20432164,
#  'learning_rate': 0.07963799}
# INFO:tensorflow:Step 3200 per-step time 0.184s
# I0805 19:17:53.091961 140025591211904 model_lib_v2.py:707] Step 3200 per-step time 0.184s
# INFO:tensorflow:{'Loss/classification_loss': 0.06686375,
#  'Loss/localization_loss': 0.027551152,
#  'Loss/regularization_loss': 0.1344077,
#  'Loss/total_loss': 0.2288226,
#  'learning_rate': 0.07960275}
# I0805 19:17:53.092331 140025591211904 model_lib_v2.py:708] {'Loss/classification_loss': 0.06686375,
#  'Loss/localization_loss': 0.027551152,
#  'Loss/regularization_loss': 0.1344077,
#  'Loss/total_loss': 0.2288226,
#  'learning_rate': 0.07960275}
# INFO:tensorflow:Step 3300 per-step time 0.173s
# I0805 19:18:10.380217 140025591211904 model_lib_v2.py:707] Step 3300 per-step time 0.173s
# INFO:tensorflow:{'Loss/classification_loss': 0.030518755,
#  'Loss/localization_loss': 0.009151704,
#  'Loss/regularization_loss': 0.13368946,
#  'Loss/total_loss': 0.17335993,
#  'learning_rate': 0.07956588}
# I0805 19:18:10.380619 140025591211904 model_lib_v2.py:708] {'Loss/classification_loss': 0.030518755,
#  'Loss/localization_loss': 0.009151704,
#  'Loss/regularization_loss': 0.13368946,
#  'Loss/total_loss': 0.17335993,
#  'learning_rate': 0.07956588}
# INFO:tensorflow:Step 3400 per-step time 0.162s
# I0805 19:18:26.540950 140025591211904 model_lib_v2.py:707] Step 3400 per-step time 0.162s
# INFO:tensorflow:{'Loss/classification_loss': 0.058478255,
#  'Loss/localization_loss': 0.03154524,
#  'Loss/regularization_loss': 0.13296248,
#  'Loss/total_loss': 0.22298598,
#  'learning_rate': 0.079527386}
# I0805 19:18:26.541349 140025591211904 model_lib_v2.py:708] {'Loss/classification_loss': 0.058478255,
#  'Loss/localization_loss': 0.03154524,
#  'Loss/regularization_loss': 0.13296248,
#  'Loss/total_loss': 0.22298598,
#  'learning_rate': 0.079527386}
# INFO:tensorflow:Step 3500 per-step time 0.174s
# I0805 19:18:43.917492 140025591211904 model_lib_v2.py:707] Step 3500 per-step time 0.174s
# INFO:tensorflow:{'Loss/classification_loss': 0.044958197,
#  'Loss/localization_loss': 0.014979014,
#  'Loss/regularization_loss': 0.13222021,
#  'Loss/total_loss': 0.19215742,
#  'learning_rate': 0.07948727}
# I0805 19:18:43.917883 140025591211904 model_lib_v2.py:708] {'Loss/classification_loss': 0.044958197,
#  'Loss/localization_loss': 0.014979014,
#  'Loss/regularization_loss': 0.13222021,
#  'Loss/total_loss': 0.19215742,
#  'learning_rate': 0.07948727}
# INFO:tensorflow:Step 3600 per-step time 0.174s
# I0805 19:19:01.327720 140025591211904 model_lib_v2.py:707] Step 3600 per-step time 0.174s
# INFO:tensorflow:{'Loss/classification_loss': 0.046967726,
#  'Loss/localization_loss': 0.014753609,
#  'Loss/regularization_loss': 0.13147089,
#  'Loss/total_loss': 0.19319223,
#  'learning_rate': 0.079445526}
# I0805 19:19:01.328113 140025591211904 model_lib_v2.py:708] {'Loss/classification_loss': 0.046967726,
#  'Loss/localization_loss': 0.014753609,
#  'Loss/regularization_loss': 0.13147089,
#  'Loss/total_loss': 0.19319223,
#  'learning_rate': 0.079445526}
# INFO:tensorflow:Step 3700 per-step time 0.175s
# I0805 19:19:18.860072 140025591211904 model_lib_v2.py:707] Step 3700 per-step time 0.175s
# INFO:tensorflow:{'Loss/classification_loss': 0.035496075,
#  'Loss/localization_loss': 0.008815162,
#  'Loss/regularization_loss': 0.13074227,
#  'Loss/total_loss': 0.1750535,
#  'learning_rate': 0.07940216}
# I0805 19:19:18.860433 140025591211904 model_lib_v2.py:708] {'Loss/classification_loss': 0.035496075,
#  'Loss/localization_loss': 0.008815162,
#  'Loss/regularization_loss': 0.13074227,
#  'Loss/total_loss': 0.1750535,
#  'learning_rate': 0.07940216}
# INFO:tensorflow:Step 3800 per-step time 0.188s
# I0805 19:19:37.625870 140025591211904 model_lib_v2.py:707] Step 3800 per-step time 0.188s
# INFO:tensorflow:{'Loss/classification_loss': 0.041308988,
#  'Loss/localization_loss': 0.015085995,
#  'Loss/regularization_loss': 0.13000177,
#  'Loss/total_loss': 0.18639675,
#  'learning_rate': 0.079357184}
# I0805 19:19:37.626257 140025591211904 model_lib_v2.py:708] {'Loss/classification_loss': 0.041308988,
#  'Loss/localization_loss': 0.015085995,
#  'Loss/regularization_loss': 0.13000177,
#  'Loss/total_loss': 0.18639675,
#  'learning_rate': 0.079357184}
# INFO:tensorflow:Step 3900 per-step time 0.171s
# I0805 19:19:54.705228 140025591211904 model_lib_v2.py:707] Step 3900 per-step time 0.171s
# INFO:tensorflow:{'Loss/classification_loss': 0.034748275,
#  'Loss/localization_loss': 0.009964645,
#  'Loss/regularization_loss': 0.1292839,
#  'Loss/total_loss': 0.17399682,
#  'learning_rate': 0.07931058}
# I0805 19:19:54.705606 140025591211904 model_lib_v2.py:708] {'Loss/classification_loss': 0.034748275,
#  'Loss/localization_loss': 0.009964645,
#  'Loss/regularization_loss': 0.1292839,
#  'Loss/total_loss': 0.17399682,
#  'learning_rate': 0.07931058}
# INFO:tensorflow:Step 4000 per-step time 0.168s
# I0805 19:20:11.515821 140025591211904 model_lib_v2.py:707] Step 4000 per-step time 0.168s
# INFO:tensorflow:{'Loss/classification_loss': 0.044779707,
#  'Loss/localization_loss': 0.012231458,
#  'Loss/regularization_loss': 0.1285731,
#  'Loss/total_loss': 0.18558428,
#  'learning_rate': 0.07926236}
# I0805 19:20:11.516210 140025591211904 model_lib_v2.py:708] {'Loss/classification_loss': 0.044779707,
#  'Loss/localization_loss': 0.012231458,
#  'Loss/regularization_loss': 0.1285731,
#  'Loss/total_loss': 0.18558428,
#  'learning_rate': 0.07926236}
# INFO:tensorflow:Step 4100 per-step time 0.171s
# I0805 19:20:28.587777 140025591211904 model_lib_v2.py:707] Step 4100 per-step time 0.171s
# INFO:tensorflow:{'Loss/classification_loss': 0.04132947,
#  'Loss/localization_loss': 0.010257599,
#  'Loss/regularization_loss': 0.12785958,
#  'Loss/total_loss': 0.17944664,
#  'learning_rate': 0.07921253}
# I0805 19:20:28.588157 140025591211904 model_lib_v2.py:708] {'Loss/classification_loss': 0.04132947,
#  'Loss/localization_loss': 0.010257599,
#  'Loss/regularization_loss': 0.12785958,
#  'Loss/total_loss': 0.17944664,
#  'learning_rate': 0.07921253}
# INFO:tensorflow:Step 4200 per-step time 0.175s
# I0805 19:20:46.063272 140025591211904 model_lib_v2.py:707] Step 4200 per-step time 0.175s
# INFO:tensorflow:{'Loss/classification_loss': 0.0398342,
#  'Loss/localization_loss': 0.007956732,
#  'Loss/regularization_loss': 0.12715025,
#  'Loss/total_loss': 0.17494118,
#  'learning_rate': 0.07916109}
# I0805 19:20:46.063655 140025591211904 model_lib_v2.py:708] {'Loss/classification_loss': 0.0398342,
#  'Loss/localization_loss': 0.007956732,
#  'Loss/regularization_loss': 0.12715025,
#  'Loss/total_loss': 0.17494118,
#  'learning_rate': 0.07916109}
# INFO:tensorflow:Step 4300 per-step time 0.186s
# I0805 19:21:04.659331 140025591211904 model_lib_v2.py:707] Step 4300 per-step time 0.186s
# INFO:tensorflow:{'Loss/classification_loss': 0.038144704,
#  'Loss/localization_loss': 0.017187309,
#  'Loss/regularization_loss': 0.12644286,
#  'Loss/total_loss': 0.18177488,
#  'learning_rate': 0.07910804}
# I0805 19:21:04.659858 140025591211904 model_lib_v2.py:708] {'Loss/classification_loss': 0.038144704,
#  'Loss/localization_loss': 0.017187309,
#  'Loss/regularization_loss': 0.12644286,
#  'Loss/total_loss': 0.18177488,
#  'learning_rate': 0.07910804}
# INFO:tensorflow:Step 4400 per-step time 0.178s
# I0805 19:21:22.461720 140025591211904 model_lib_v2.py:707] Step 4400 per-step time 0.178s
# INFO:tensorflow:{'Loss/classification_loss': 0.055192314,
#  'Loss/localization_loss': 0.017387647,
#  'Loss/regularization_loss': 0.12573838,
#  'Loss/total_loss': 0.19831835,
#  'learning_rate': 0.07905338}
# I0805 19:21:22.462228 140025591211904 model_lib_v2.py:708] {'Loss/classification_loss': 0.055192314,
#  'Loss/localization_loss': 0.017387647,
#  'Loss/regularization_loss': 0.12573838,
#  'Loss/total_loss': 0.19831835,
#  'learning_rate': 0.07905338}
# INFO:tensorflow:Step 4500 per-step time 0.171s
# I0805 19:21:39.530572 140025591211904 model_lib_v2.py:707] Step 4500 per-step time 0.171s
# INFO:tensorflow:{'Loss/classification_loss': 0.028230755,
#  'Loss/localization_loss': 0.014288709,
#  'Loss/regularization_loss': 0.12505,
#  'Loss/total_loss': 0.16756946,
#  'learning_rate': 0.07899711}
# I0805 19:21:39.530991 140025591211904 model_lib_v2.py:708] {'Loss/classification_loss': 0.028230755,
#  'Loss/localization_loss': 0.014288709,
#  'Loss/regularization_loss': 0.12505,
#  'Loss/total_loss': 0.16756946,
#  'learning_rate': 0.07899711}
# INFO:tensorflow:Step 4600 per-step time 0.178s
# I0805 19:21:57.286011 140025591211904 model_lib_v2.py:707] Step 4600 per-step time 0.178s
# INFO:tensorflow:{'Loss/classification_loss': 0.063825235,
#  'Loss/localization_loss': 0.017911838,
#  'Loss/regularization_loss': 0.12434237,
#  'Loss/total_loss': 0.20607944,
#  'learning_rate': 0.078939244}
# I0805 19:21:57.286444 140025591211904 model_lib_v2.py:708] {'Loss/classification_loss': 0.063825235,
#  'Loss/localization_loss': 0.017911838,
#  'Loss/regularization_loss': 0.12434237,
#  'Loss/total_loss': 0.20607944,
#  'learning_rate': 0.078939244}
# INFO:tensorflow:Step 4700 per-step time 0.176s
# I0805 19:22:14.836817 140025591211904 model_lib_v2.py:707] Step 4700 per-step time 0.176s
# INFO:tensorflow:{'Loss/classification_loss': 0.02863726,
#  'Loss/localization_loss': 0.008696246,
#  'Loss/regularization_loss': 0.12365705,
#  'Loss/total_loss': 0.16099055,
#  'learning_rate': 0.07887978}
# I0805 19:22:14.837259 140025591211904 model_lib_v2.py:708] {'Loss/classification_loss': 0.02863726,
#  'Loss/localization_loss': 0.008696246,
#  'Loss/regularization_loss': 0.12365705,
#  'Loss/total_loss': 0.16099055,
#  'learning_rate': 0.07887978}
# INFO:tensorflow:Step 4800 per-step time 0.192s
# I0805 19:22:34.070606 140025591211904 model_lib_v2.py:707] Step 4800 per-step time 0.192s
# INFO:tensorflow:{'Loss/classification_loss': 0.033293713,
#  'Loss/localization_loss': 0.012868496,
#  'Loss/regularization_loss': 0.12302178,
#  'Loss/total_loss': 0.169184,
#  'learning_rate': 0.07881871}
# I0805 19:22:34.070985 140025591211904 model_lib_v2.py:708] {'Loss/classification_loss': 0.033293713,
#  'Loss/localization_loss': 0.012868496,
#  'Loss/regularization_loss': 0.12302178,
#  'Loss/total_loss': 0.169184,
#  'learning_rate': 0.07881871}
# INFO:tensorflow:Step 4900 per-step time 0.180s
# I0805 19:22:52.077130 140025591211904 model_lib_v2.py:707] Step 4900 per-step time 0.180s
# INFO:tensorflow:{'Loss/classification_loss': 0.036723875,
#  'Loss/localization_loss': 0.014776891,
#  'Loss/regularization_loss': 0.122373335,
#  'Loss/total_loss': 0.17387411,
#  'learning_rate': 0.07875605}
# I0805 19:22:52.077572 140025591211904 model_lib_v2.py:708] {'Loss/classification_loss': 0.036723875,
#  'Loss/localization_loss': 0.014776891,
#  'Loss/regularization_loss': 0.122373335,
#  'Loss/total_loss': 0.17387411,
#  'learning_rate': 0.07875605}
# INFO:tensorflow:Step 5000 per-step time 0.176s
# I0805 19:23:09.629238 140025591211904 model_lib_v2.py:707] Step 5000 per-step time 0.176s
# INFO:tensorflow:{'Loss/classification_loss': 0.039474268,
#  'Loss/localization_loss': 0.017164923,
#  'Loss/regularization_loss': 0.12169749,
#  'Loss/total_loss': 0.17833668,
#  'learning_rate': 0.078691795}
# I0805 19:23:09.629653 140025591211904 model_lib_v2.py:708] {'Loss/classification_loss': 0.039474268,
#  'Loss/localization_loss': 0.017164923,
#  'Loss/regularization_loss': 0.12169749,
#  'Loss/total_loss': 0.17833668,
#  'learning_rate': 0.078691795}
# INFO:tensorflow:Step 5100 per-step time 0.185s
# I0805 19:23:28.165909 140025591211904 model_lib_v2.py:707] Step 5100 per-step time 0.185s
# INFO:tensorflow:{'Loss/classification_loss': 0.041893046,
#  'Loss/localization_loss': 0.010432141,
#  'Loss/regularization_loss': 0.12102072,
#  'Loss/total_loss': 0.17334591,
#  'learning_rate': 0.07862595}
# I0805 19:23:28.166357 140025591211904 model_lib_v2.py:708] {'Loss/classification_loss': 0.041893046,
#  'Loss/localization_loss': 0.010432141,
#  'Loss/regularization_loss': 0.12102072,
#  'Loss/total_loss': 0.17334591,
#  'learning_rate': 0.07862595}
# INFO:tensorflow:Step 5200 per-step time 0.179s
# I0805 19:23:46.099512 140025591211904 model_lib_v2.py:707] Step 5200 per-step time 0.179s
# INFO:tensorflow:{'Loss/classification_loss': 0.041918322,
#  'Loss/localization_loss': 0.01529375,
#  'Loss/regularization_loss': 0.12035698,
#  'Loss/total_loss': 0.17756905,
#  'learning_rate': 0.07855851}
# I0805 19:23:46.099953 140025591211904 model_lib_v2.py:708] {'Loss/classification_loss': 0.041918322,
#  'Loss/localization_loss': 0.01529375,
#  'Loss/regularization_loss': 0.12035698,
#  'Loss/total_loss': 0.17756905,
#  'learning_rate': 0.07855851}
# INFO:tensorflow:Step 5300 per-step time 0.189s
# I0805 19:24:05.042077 140025591211904 model_lib_v2.py:707] Step 5300 per-step time 0.189s
# INFO:tensorflow:{'Loss/classification_loss': 0.043189406,
#  'Loss/localization_loss': 0.013523264,
#  'Loss/regularization_loss': 0.11968499,
#  'Loss/total_loss': 0.17639765,
#  'learning_rate': 0.07848949}
# I0805 19:24:05.042467 140025591211904 model_lib_v2.py:708] {'Loss/classification_loss': 0.043189406,
#  'Loss/localization_loss': 0.013523264,
#  'Loss/regularization_loss': 0.11968499,
#  'Loss/total_loss': 0.17639765,
#  'learning_rate': 0.07848949}
# INFO:tensorflow:Step 5400 per-step time 0.173s
# I0805 19:24:22.306407 140025591211904 model_lib_v2.py:707] Step 5400 per-step time 0.173s
# INFO:tensorflow:{'Loss/classification_loss': 0.027435044,
#  'Loss/localization_loss': 0.008657964,
#  'Loss/regularization_loss': 0.119016945,
#  'Loss/total_loss': 0.15510996,
#  'learning_rate': 0.078418896}
# I0805 19:24:22.306815 140025591211904 model_lib_v2.py:708] {'Loss/classification_loss': 0.027435044,
#  'Loss/localization_loss': 0.008657964,
#  'Loss/regularization_loss': 0.119016945,
#  'Loss/total_loss': 0.15510996,
#  'learning_rate': 0.078418896}
# INFO:tensorflow:Step 5500 per-step time 0.174s
# I0805 19:24:39.691229 140025591211904 model_lib_v2.py:707] Step 5500 per-step time 0.174s
# INFO:tensorflow:{'Loss/classification_loss': 0.06323454,
#  'Loss/localization_loss': 0.015949173,
#  'Loss/regularization_loss': 0.11838208,
#  'Loss/total_loss': 0.1975658,
#  'learning_rate': 0.078346714}
# I0805 19:24:39.691732 140025591211904 model_lib_v2.py:708] {'Loss/classification_loss': 0.06323454,
#  'Loss/localization_loss': 0.015949173,
#  'Loss/regularization_loss': 0.11838208,
#  'Loss/total_loss': 0.1975658,
#  'learning_rate': 0.078346714}
# INFO:tensorflow:Step 5600 per-step time 0.181s
# I0805 19:24:57.754436 140025591211904 model_lib_v2.py:707] Step 5600 per-step time 0.181s
# INFO:tensorflow:{'Loss/classification_loss': 0.028666828,
#  'Loss/localization_loss': 0.007833373,
#  'Loss/regularization_loss': 0.11774911,
#  'Loss/total_loss': 0.15424931,
#  'learning_rate': 0.07827295}
# I0805 19:24:57.754855 140025591211904 model_lib_v2.py:708] {'Loss/classification_loss': 0.028666828,
#  'Loss/localization_loss': 0.007833373,
#  'Loss/regularization_loss': 0.11774911,
#  'Loss/total_loss': 0.15424931,
#  'learning_rate': 0.07827295}
# INFO:tensorflow:Step 5700 per-step time 0.175s
# I0805 19:25:15.225193 140025591211904 model_lib_v2.py:707] Step 5700 per-step time 0.175s
# INFO:tensorflow:{'Loss/classification_loss': 0.032310005,
#  'Loss/localization_loss': 0.015025308,
#  'Loss/regularization_loss': 0.11708726,
#  'Loss/total_loss': 0.16442257,
#  'learning_rate': 0.07819763}
# I0805 19:25:15.225645 140025591211904 model_lib_v2.py:708] {'Loss/classification_loss': 0.032310005,
#  'Loss/localization_loss': 0.015025308,
#  'Loss/regularization_loss': 0.11708726,
#  'Loss/total_loss': 0.16442257,
#  'learning_rate': 0.07819763}
# INFO:tensorflow:Step 5800 per-step time 0.174s
# I0805 19:25:32.652338 140025591211904 model_lib_v2.py:707] Step 5800 per-step time 0.174s
# INFO:tensorflow:{'Loss/classification_loss': 0.041739747,
#  'Loss/localization_loss': 0.019832179,
#  'Loss/regularization_loss': 0.116436005,
#  'Loss/total_loss': 0.17800793,
#  'learning_rate': 0.07812072}
# I0805 19:25:32.652769 140025591211904 model_lib_v2.py:708] {'Loss/classification_loss': 0.041739747,
#  'Loss/localization_loss': 0.019832179,
#  'Loss/regularization_loss': 0.116436005,
#  'Loss/total_loss': 0.17800793,
#  'learning_rate': 0.07812072}
# INFO:tensorflow:Step 5900 per-step time 0.179s
# I0805 19:25:50.501495 140025591211904 model_lib_v2.py:707] Step 5900 per-step time 0.179s
# INFO:tensorflow:{'Loss/classification_loss': 0.04398898,
#  'Loss/localization_loss': 0.014550166,
#  'Loss/regularization_loss': 0.11578593,
#  'Loss/total_loss': 0.17432508,
#  'learning_rate': 0.078042254}
# I0805 19:25:50.501904 140025591211904 model_lib_v2.py:708] {'Loss/classification_loss': 0.04398898,
#  'Loss/localization_loss': 0.014550166,
#  'Loss/regularization_loss': 0.11578593,
#  'Loss/total_loss': 0.17432508,
#  'learning_rate': 0.078042254}
# INFO:tensorflow:Step 6000 per-step time 0.179s
# I0805 19:26:08.416671 140025591211904 model_lib_v2.py:707] Step 6000 per-step time 0.179s
# INFO:tensorflow:{'Loss/classification_loss': 0.045368195,
#  'Loss/localization_loss': 0.034006283,
#  'Loss/regularization_loss': 0.115156576,
#  'Loss/total_loss': 0.19453105,
#  'learning_rate': 0.07796223}
# I0805 19:26:08.417096 140025591211904 model_lib_v2.py:708] {'Loss/classification_loss': 0.045368195,
#  'Loss/localization_loss': 0.034006283,
#  'Loss/regularization_loss': 0.115156576,
#  'Loss/total_loss': 0.19453105,
#  'learning_rate': 0.07796223}
# INFO:tensorflow:Step 6100 per-step time 0.187s
# I0805 19:26:27.080423 140025591211904 model_lib_v2.py:707] Step 6100 per-step time 0.187s
# INFO:tensorflow:{'Loss/classification_loss': 0.04458537,
#  'Loss/localization_loss': 0.014622742,
#  'Loss/regularization_loss': 0.11453619,
#  'Loss/total_loss': 0.17374429,
#  'learning_rate': 0.077880636}
# I0805 19:26:27.080944 140025591211904 model_lib_v2.py:708] {'Loss/classification_loss': 0.04458537,
#  'Loss/localization_loss': 0.014622742,
#  'Loss/regularization_loss': 0.11453619,
#  'Loss/total_loss': 0.17374429,
#  'learning_rate': 0.077880636}
# INFO:tensorflow:Step 6200 per-step time 0.175s
# I0805 19:26:44.543679 140025591211904 model_lib_v2.py:707] Step 6200 per-step time 0.175s
# INFO:tensorflow:{'Loss/classification_loss': 0.033553835,
#  'Loss/localization_loss': 0.00727582,
#  'Loss/regularization_loss': 0.113911405,
#  'Loss/total_loss': 0.15474106,
#  'learning_rate': 0.07779749}
# I0805 19:26:44.544139 140025591211904 model_lib_v2.py:708] {'Loss/classification_loss': 0.033553835,
#  'Loss/localization_loss': 0.00727582,
#  'Loss/regularization_loss': 0.113911405,
#  'Loss/total_loss': 0.15474106,
#  'learning_rate': 0.07779749}
# INFO:tensorflow:Step 6300 per-step time 0.180s
# I0805 19:27:02.588934 140025591211904 model_lib_v2.py:707] Step 6300 per-step time 0.180s
# INFO:tensorflow:{'Loss/classification_loss': 0.03595203,
#  'Loss/localization_loss': 0.008676218,
#  'Loss/regularization_loss': 0.11328843,
#  'Loss/total_loss': 0.15791668,
#  'learning_rate': 0.07771279}
# I0805 19:27:02.589367 140025591211904 model_lib_v2.py:708] {'Loss/classification_loss': 0.03595203,
#  'Loss/localization_loss': 0.008676218,
#  'Loss/regularization_loss': 0.11328843,
#  'Loss/total_loss': 0.15791668,
#  'learning_rate': 0.07771279}
# INFO:tensorflow:Step 6400 per-step time 0.193s
# I0805 19:27:21.868654 140025591211904 model_lib_v2.py:707] Step 6400 per-step time 0.193s
# INFO:tensorflow:{'Loss/classification_loss': 0.026872167,
#  'Loss/localization_loss': 0.008767151,
#  'Loss/regularization_loss': 0.11268275,
#  'Loss/total_loss': 0.14832208,
#  'learning_rate': 0.077626534}
# I0805 19:27:21.869045 140025591211904 model_lib_v2.py:708] {'Loss/classification_loss': 0.026872167,
#  'Loss/localization_loss': 0.008767151,
#  'Loss/regularization_loss': 0.11268275,
#  'Loss/total_loss': 0.14832208,
#  'learning_rate': 0.077626534}
# INFO:tensorflow:Step 6500 per-step time 0.179s
# ...
#  'Loss/total_loss': 0.0585016,
#  'learning_rate': 0.012543423}
# INFO:tensorflow:Step 37400 per-step time 0.156s
# I0805 20:52:02.373640 140025591211904 model_lib_v2.py:707] Step 37400 per-step time 0.156s
# INFO:tensorflow:{'Loss/classification_loss': 0.016208436,
#  'Loss/localization_loss': 0.0023859092,
#  'Loss/regularization_loss': 0.040727034,
#  'Loss/total_loss': 0.05932138,
#  'learning_rate': 0.012357492}
# I0805 20:52:02.374220 140025591211904 model_lib_v2.py:708] {'Loss/classification_loss': 0.016208436,
#  'Loss/localization_loss': 0.0023859092,
#  'Loss/regularization_loss': 0.040727034,
#  'Loss/total_loss': 0.05932138,
#  'learning_rate': 0.012357492}
# INFO:tensorflow:Step 37500 per-step time 0.166s
# I0805 20:52:18.954209 140025591211904 model_lib_v2.py:707] Step 37500 per-step time 0.166s
# INFO:tensorflow:{'Loss/classification_loss': 0.01687047,
#  'Loss/localization_loss': 0.0054494566,
#  'Loss/regularization_loss': 0.040689293,
#  'Loss/total_loss': 0.06300922,
#  'learning_rate': 0.012172694}
# I0805 20:52:18.954598 140025591211904 model_lib_v2.py:708] {'Loss/classification_loss': 0.01687047,
#  'Loss/localization_loss': 0.0054494566,
#  'Loss/regularization_loss': 0.040689293,
#  'Loss/total_loss': 0.06300922,
#  'learning_rate': 0.012172694}
# INFO:tensorflow:Step 37600 per-step time 0.162s
# I0805 20:52:35.186415 140025591211904 model_lib_v2.py:707] Step 37600 per-step time 0.162s
# INFO:tensorflow:{'Loss/classification_loss': 0.019084185,
#  'Loss/localization_loss': 0.0021951715,
#  'Loss/regularization_loss': 0.040652532,
#  'Loss/total_loss': 0.06193189,
#  'learning_rate': 0.011989042}
# I0805 20:52:35.186885 140025591211904 model_lib_v2.py:708] {'Loss/classification_loss': 0.019084185,
#  'Loss/localization_loss': 0.0021951715,
#  'Loss/regularization_loss': 0.040652532,
#  'Loss/total_loss': 0.06193189,
#  'learning_rate': 0.011989042}
# INFO:tensorflow:Step 37700 per-step time 0.166s
# I0805 20:52:51.743908 140025591211904 model_lib_v2.py:707] Step 37700 per-step time 0.166s
# INFO:tensorflow:{'Loss/classification_loss': 0.011609259,
#  'Loss/localization_loss': 0.0013566519,
#  'Loss/regularization_loss': 0.040616184,
#  'Loss/total_loss': 0.053582095,
#  'learning_rate': 0.011806537}
# I0805 20:52:51.744332 140025591211904 model_lib_v2.py:708] {'Loss/classification_loss': 0.011609259,
#  'Loss/localization_loss': 0.0013566519,
#  'Loss/regularization_loss': 0.040616184,
#  'Loss/total_loss': 0.053582095,
#  'learning_rate': 0.011806537}
# INFO:tensorflow:Step 37800 per-step time 0.161s
# I0805 20:53:07.810165 140025591211904 model_lib_v2.py:707] Step 37800 per-step time 0.161s
# INFO:tensorflow:{'Loss/classification_loss': 0.010801166,
#  'Loss/localization_loss': 0.0020265873,
#  'Loss/regularization_loss': 0.04058007,
#  'Loss/total_loss': 0.053407826,
#  'learning_rate': 0.011625201}
# I0805 20:53:07.810536 140025591211904 model_lib_v2.py:708] {'Loss/classification_loss': 0.010801166,
#  'Loss/localization_loss': 0.0020265873,
#  'Loss/regularization_loss': 0.04058007,
#  'Loss/total_loss': 0.053407826,
#  'learning_rate': 0.011625201}
# INFO:tensorflow:Step 37900 per-step time 0.167s
# I0805 20:53:24.528186 140025591211904 model_lib_v2.py:707] Step 37900 per-step time 0.167s
# INFO:tensorflow:{'Loss/classification_loss': 0.011081922,
#  'Loss/localization_loss': 0.0011281116,
#  'Loss/regularization_loss': 0.040544562,
#  'Loss/total_loss': 0.052754596,
#  'learning_rate': 0.011445029}
# I0805 20:53:24.528640 140025591211904 model_lib_v2.py:708] {'Loss/classification_loss': 0.011081922,
#  'Loss/localization_loss': 0.0011281116,
#  'Loss/regularization_loss': 0.040544562,
#  'Loss/total_loss': 0.052754596,
#  'learning_rate': 0.011445029}
# INFO:tensorflow:Step 38000 per-step time 0.159s
# I0805 20:53:40.466527 140025591211904 model_lib_v2.py:707] Step 38000 per-step time 0.159s
# INFO:tensorflow:{'Loss/classification_loss': 0.016232198,
#  'Loss/localization_loss': 0.0017608395,
#  'Loss/regularization_loss': 0.040509738,
#  'Loss/total_loss': 0.058502775,
#  'learning_rate': 0.011266021}
# I0805 20:53:40.473533 140025591211904 model_lib_v2.py:708] {'Loss/classification_loss': 0.016232198,
#  'Loss/localization_loss': 0.0017608395,
#  'Loss/regularization_loss': 0.040509738,
#  'Loss/total_loss': 0.058502775,
#  'learning_rate': 0.011266021}
# INFO:tensorflow:Step 38100 per-step time 0.161s
# I0805 20:53:56.575569 140025591211904 model_lib_v2.py:707] Step 38100 per-step time 0.161s
# INFO:tensorflow:{'Loss/classification_loss': 0.010582074,
#  'Loss/localization_loss': 0.0016497102,
#  'Loss/regularization_loss': 0.0404755,
#  'Loss/total_loss': 0.052707285,
#  'learning_rate': 0.011088205}
# I0805 20:53:56.575957 140025591211904 model_lib_v2.py:708] {'Loss/classification_loss': 0.010582074,
#  'Loss/localization_loss': 0.0016497102,
#  'Loss/regularization_loss': 0.0404755,
#  'Loss/total_loss': 0.052707285,
#  'learning_rate': 0.011088205}
# INFO:tensorflow:Step 38200 per-step time 0.170s
# I0805 20:54:13.577909 140025591211904 model_lib_v2.py:707] Step 38200 per-step time 0.170s
# INFO:tensorflow:{'Loss/classification_loss': 0.021763038,
#  'Loss/localization_loss': 0.0029016454,
#  'Loss/regularization_loss': 0.040441837,
#  'Loss/total_loss': 0.06510652,
#  'learning_rate': 0.010911569}
# I0805 20:54:13.578445 140025591211904 model_lib_v2.py:708] {'Loss/classification_loss': 0.021763038,
#  'Loss/localization_loss': 0.0029016454,
#  'Loss/regularization_loss': 0.040441837,
#  'Loss/total_loss': 0.06510652,
#  'learning_rate': 0.010911569}
# INFO:tensorflow:Step 38300 per-step time 0.170s
# I0805 20:54:30.547739 140025591211904 model_lib_v2.py:707] Step 38300 per-step time 0.170s
# INFO:tensorflow:{'Loss/classification_loss': 0.011786801,
#  'Loss/localization_loss': 0.002496507,
#  'Loss/regularization_loss': 0.04040863,
#  'Loss/total_loss': 0.054691937,
#  'learning_rate': 0.010736136}
# I0805 20:54:30.548098 140025591211904 model_lib_v2.py:708] {'Loss/classification_loss': 0.011786801,
#  'Loss/localization_loss': 0.002496507,
#  'Loss/regularization_loss': 0.04040863,
#  'Loss/total_loss': 0.054691937,
#  'learning_rate': 0.010736136}
# INFO:tensorflow:Step 38400 per-step time 0.163s
# I0805 20:54:46.887068 140025591211904 model_lib_v2.py:707] Step 38400 per-step time 0.163s
# INFO:tensorflow:{'Loss/classification_loss': 0.015589027,
#  'Loss/localization_loss': 0.0028614644,
#  'Loss/regularization_loss': 0.040375855,
#  'Loss/total_loss': 0.058826346,
#  'learning_rate': 0.010561897}
# I0805 20:54:46.887509 140025591211904 model_lib_v2.py:708] {'Loss/classification_loss': 0.015589027,
#  'Loss/localization_loss': 0.0028614644,
#  'Loss/regularization_loss': 0.040375855,
#  'Loss/total_loss': 0.058826346,
#  'learning_rate': 0.010561897}
# INFO:tensorflow:Step 38500 per-step time 0.158s
# I0805 20:55:02.670960 140025591211904 model_lib_v2.py:707] Step 38500 per-step time 0.158s
# INFO:tensorflow:{'Loss/classification_loss': 0.014977508,
#  'Loss/localization_loss': 0.0027973356,
#  'Loss/regularization_loss': 0.040343564,
#  'Loss/total_loss': 0.05811841,
#  'learning_rate': 0.010388877}
# I0805 20:55:02.671399 140025591211904 model_lib_v2.py:708] {'Loss/classification_loss': 0.014977508,
#  'Loss/localization_loss': 0.0027973356,
#  'Loss/regularization_loss': 0.040343564,
#  'Loss/total_loss': 0.05811841,
#  'learning_rate': 0.010388877}
# INFO:tensorflow:Step 38600 per-step time 0.157s
# I0805 20:55:18.359941 140025591211904 model_lib_v2.py:707] Step 38600 per-step time 0.157s
# INFO:tensorflow:{'Loss/classification_loss': 0.014788391,
#  'Loss/localization_loss': 0.0037657472,
#  'Loss/regularization_loss': 0.04031189,
#  'Loss/total_loss': 0.05886603,
#  'learning_rate': 0.010217068}
# I0805 20:55:18.360313 140025591211904 model_lib_v2.py:708] {'Loss/classification_loss': 0.014788391,
#  'Loss/localization_loss': 0.0037657472,
#  'Loss/regularization_loss': 0.04031189,
#  'Loss/total_loss': 0.05886603,
#  'learning_rate': 0.010217068}
# INFO:tensorflow:Step 38700 per-step time 0.159s
# I0805 20:55:34.246312 140025591211904 model_lib_v2.py:707] Step 38700 per-step time 0.159s
# INFO:tensorflow:{'Loss/classification_loss': 0.013134327,
#  'Loss/localization_loss': 0.0015179637,
#  'Loss/regularization_loss': 0.040280677,
#  'Loss/total_loss': 0.054932967,
#  'learning_rate': 0.010046489}
# I0805 20:55:34.246665 140025591211904 model_lib_v2.py:708] {'Loss/classification_loss': 0.013134327,
#  'Loss/localization_loss': 0.0015179637,
#  'Loss/regularization_loss': 0.040280677,
#  'Loss/total_loss': 0.054932967,
#  'learning_rate': 0.010046489}
# INFO:tensorflow:Step 38800 per-step time 0.174s
# I0805 20:55:51.620960 140025591211904 model_lib_v2.py:707] Step 38800 per-step time 0.174s
# INFO:tensorflow:{'Loss/classification_loss': 0.012540321,
#  'Loss/localization_loss': 0.0011911015,
#  'Loss/regularization_loss': 0.0402502,
#  'Loss/total_loss': 0.053981625,
#  'learning_rate': 0.009877141}
# I0805 20:55:51.621306 140025591211904 model_lib_v2.py:708] {'Loss/classification_loss': 0.012540321,
#  'Loss/localization_loss': 0.0011911015,
#  'Loss/regularization_loss': 0.0402502,
#  'Loss/total_loss': 0.053981625,
#  'learning_rate': 0.009877141}
# INFO:tensorflow:Step 38900 per-step time 0.163s
# I0805 20:56:07.930575 140025591211904 model_lib_v2.py:707] Step 38900 per-step time 0.163s
# INFO:tensorflow:{'Loss/classification_loss': 0.010655946,
#  'Loss/localization_loss': 0.0011883974,
#  'Loss/regularization_loss': 0.04022119,
#  'Loss/total_loss': 0.052065533,
#  'learning_rate': 0.009709024}
# I0805 20:56:07.931041 140025591211904 model_lib_v2.py:708] {'Loss/classification_loss': 0.010655946,
#  'Loss/localization_loss': 0.0011883974,
#  'Loss/regularization_loss': 0.04022119,
#  'Loss/total_loss': 0.052065533,
#  'learning_rate': 0.009709024}
# INFO:tensorflow:Step 39000 per-step time 0.158s
# I0805 20:56:23.748999 140025591211904 model_lib_v2.py:707] Step 39000 per-step time 0.158s
# INFO:tensorflow:{'Loss/classification_loss': 0.011463696,
#  'Loss/localization_loss': 0.0020610671,
#  'Loss/regularization_loss': 0.040195193,
#  'Loss/total_loss': 0.053719956,
#  'learning_rate': 0.00954216}
# I0805 20:56:23.749399 140025591211904 model_lib_v2.py:708] {'Loss/classification_loss': 0.011463696,
#  'Loss/localization_loss': 0.0020610671,
#  'Loss/regularization_loss': 0.040195193,
#  'Loss/total_loss': 0.053719956,
#  'learning_rate': 0.00954216}
# INFO:tensorflow:Step 39100 per-step time 0.166s
# I0805 20:56:40.332658 140025591211904 model_lib_v2.py:707] Step 39100 per-step time 0.166s
# INFO:tensorflow:{'Loss/classification_loss': 0.013032081,
#  'Loss/localization_loss': 0.0020619214,
#  'Loss/regularization_loss': 0.040165998,
#  'Loss/total_loss': 0.05526,
#  'learning_rate': 0.009376547}
# I0805 20:56:40.333033 140025591211904 model_lib_v2.py:708] {'Loss/classification_loss': 0.013032081,
#  'Loss/localization_loss': 0.0020619214,
#  'Loss/regularization_loss': 0.040165998,
#  'Loss/total_loss': 0.05526,
#  'learning_rate': 0.009376547}
# INFO:tensorflow:Step 39200 per-step time 0.162s
# I0805 20:56:56.491231 140025591211904 model_lib_v2.py:707] Step 39200 per-step time 0.162s
# INFO:tensorflow:{'Loss/classification_loss': 0.012705356,
#  'Loss/localization_loss': 0.0014261028,
#  'Loss/regularization_loss': 0.040137347,
#  'Loss/total_loss': 0.054268807,
#  'learning_rate': 0.009212187}
# I0805 20:56:56.491633 140025591211904 model_lib_v2.py:708] {'Loss/classification_loss': 0.012705356,
#  'Loss/localization_loss': 0.0014261028,
#  'Loss/regularization_loss': 0.040137347,
#  'Loss/total_loss': 0.054268807,
#  'learning_rate': 0.009212187}
# INFO:tensorflow:Step 39300 per-step time 0.176s
# I0805 20:57:14.126739 140025591211904 model_lib_v2.py:707] Step 39300 per-step time 0.176s
# INFO:tensorflow:{'Loss/classification_loss': 0.01710585,
#  'Loss/localization_loss': 0.0025720268,
#  'Loss/regularization_loss': 0.040110044,
#  'Loss/total_loss': 0.05978792,
#  'learning_rate': 0.009049098}
# I0805 20:57:14.127097 140025591211904 model_lib_v2.py:708] {'Loss/classification_loss': 0.01710585,
#  'Loss/localization_loss': 0.0025720268,
#  'Loss/regularization_loss': 0.040110044,
#  'Loss/total_loss': 0.05978792,
#  'learning_rate': 0.009049098}
# INFO:tensorflow:Step 39400 per-step time 0.158s
# I0805 20:57:29.890588 140025591211904 model_lib_v2.py:707] Step 39400 per-step time 0.158s
# INFO:tensorflow:{'Loss/classification_loss': 0.01623632,
#  'Loss/localization_loss': 0.0015520046,
#  'Loss/regularization_loss': 0.040082257,
#  'Loss/total_loss': 0.05787058,
#  'learning_rate': 0.008887276}
# I0805 20:57:29.890942 140025591211904 model_lib_v2.py:708] {'Loss/classification_loss': 0.01623632,
#  'Loss/localization_loss': 0.0015520046,
#  'Loss/regularization_loss': 0.040082257,
#  'Loss/total_loss': 0.05787058,
#  'learning_rate': 0.008887276}
# INFO:tensorflow:Step 39500 per-step time 0.159s
# I0805 20:57:45.764521 140025591211904 model_lib_v2.py:707] Step 39500 per-step time 0.159s
# INFO:tensorflow:{'Loss/classification_loss': 0.018087054,
#  'Loss/localization_loss': 0.0027250606,
#  'Loss/regularization_loss': 0.04005516,
#  'Loss/total_loss': 0.060867272,
#  'learning_rate': 0.008726739}
# I0805 20:57:45.764898 140025591211904 model_lib_v2.py:708] {'Loss/classification_loss': 0.018087054,
#  'Loss/localization_loss': 0.0027250606,
#  'Loss/regularization_loss': 0.04005516,
#  'Loss/total_loss': 0.060867272,
#  'learning_rate': 0.008726739}
# INFO:tensorflow:Step 39600 per-step time 0.160s
# I0805 20:58:01.756972 140025591211904 model_lib_v2.py:707] Step 39600 per-step time 0.160s
# INFO:tensorflow:{'Loss/classification_loss': 0.017706875,
#  'Loss/localization_loss': 0.0020534564,
#  'Loss/regularization_loss': 0.0400286,
#  'Loss/total_loss': 0.059788927,
#  'learning_rate': 0.008567488}
# I0805 20:58:01.757361 140025591211904 model_lib_v2.py:708] {'Loss/classification_loss': 0.017706875,
#  'Loss/localization_loss': 0.0020534564,
#  'Loss/regularization_loss': 0.0400286,
#  'Loss/total_loss': 0.059788927,
#  'learning_rate': 0.008567488}
# INFO:tensorflow:Step 39700 per-step time 0.160s
# I0805 20:58:17.773209 140025591211904 model_lib_v2.py:707] Step 39700 per-step time 0.160s
# INFO:tensorflow:{'Loss/classification_loss': 0.019562844,
#  'Loss/localization_loss': 0.0049485355,
#  'Loss/regularization_loss': 0.04000258,
#  'Loss/total_loss': 0.06451396,
#  'learning_rate': 0.008409522}
# I0805 20:58:17.773612 140025591211904 model_lib_v2.py:708] {'Loss/classification_loss': 0.019562844,
#  'Loss/localization_loss': 0.0049485355,
#  'Loss/regularization_loss': 0.04000258,
#  'Loss/total_loss': 0.06451396,
#  'learning_rate': 0.008409522}
# INFO:tensorflow:Step 39800 per-step time 0.189s
# I0805 20:58:36.644829 140025591211904 model_lib_v2.py:707] Step 39800 per-step time 0.189s
# INFO:tensorflow:{'Loss/classification_loss': 0.0074494006,
#  'Loss/localization_loss': 0.0015854101,
#  'Loss/regularization_loss': 0.039977014,
#  'Loss/total_loss': 0.049011827,
#  'learning_rate': 0.008252861}
# I0805 20:58:36.645232 140025591211904 model_lib_v2.py:708] {'Loss/classification_loss': 0.0074494006,
#  'Loss/localization_loss': 0.0015854101,
#  'Loss/regularization_loss': 0.039977014,
#  'Loss/total_loss': 0.049011827,
#  'learning_rate': 0.008252861}
# INFO:tensorflow:Step 39900 per-step time 0.159s
# I0805 20:58:52.505939 140025591211904 model_lib_v2.py:707] Step 39900 per-step time 0.159s
# INFO:tensorflow:{'Loss/classification_loss': 0.021580484,
#  'Loss/localization_loss': 0.0014531582,
#  'Loss/regularization_loss': 0.039952002,
#  'Loss/total_loss': 0.062985644,
#  'learning_rate': 0.008097499}
# I0805 20:58:52.506444 140025591211904 model_lib_v2.py:708] {'Loss/classification_loss': 0.021580484,
#  'Loss/localization_loss': 0.0014531582,
#  'Loss/regularization_loss': 0.039952002,
#  'Loss/total_loss': 0.062985644,
#  'learning_rate': 0.008097499}
# INFO:tensorflow:Step 40000 per-step time 0.164s
# I0805 20:59:08.874384 140025591211904 model_lib_v2.py:707] Step 40000 per-step time 0.164s
# INFO:tensorflow:{'Loss/classification_loss': 0.012303719,
#  'Loss/localization_loss': 0.0021531226,
#  'Loss/regularization_loss': 0.03992722,
#  'Loss/total_loss': 0.054384064,
#  'learning_rate': 0.007943453}
# I0805 20:59:08.874763 140025591211904 model_lib_v2.py:708] {'Loss/classification_loss': 0.012303719,
#  'Loss/localization_loss': 0.0021531226,
#  'Loss/regularization_loss': 0.03992722,
#  'Loss/total_loss': 0.054384064,
#  'learning_rate': 0.007943453}

# %% [markdown]
# # 7. Evaluate the Model

# %%
command = "python {} --model_dir={} --pipeline_config_path={} --checkpoint_dir={}".format(TRAINING_SCRIPT, paths['CHECKPOINT_PATH'],files['PIPELINE_CONFIG'], paths['CHECKPOINT_PATH'])

# %%
print(command)
# Out:
# python Tensorflow/models/research/object_detection/model_main_tf2.py --model_dir=Tensorflow/workspace/models/my_ssd_mobnet --pipeline_config_path=Tensorflow/workspace/models/my_ssd_mobnet/pipeline.config --checkpoint_dir=Tensorflow/workspace/models/my_ssd_mobnet

# %%
pip install opencv-python==4.5.5.64
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting opencv-python==4.5.5.64
#   Downloading opencv_python-4.5.5.64-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (60.5 MB)
#      |████████████████████████████████| 60.5 MB 1.2 MB/s
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from opencv-python==4.5.5.64) (1.21.6)
# Installing collected packages: opencv-python
#   Attempting uninstall: opencv-python
#     Found existing installation: opencv-python 4.6.0.66
#     Uninstalling opencv-python-4.6.0.66:
#       Successfully uninstalled opencv-python-4.6.0.66
# Successfully installed opencv-python-4.5.5.64

# %%
pip install opencv-python-headless==4.5.2.52
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting opencv-python-headless==4.5.2.52
#   Downloading opencv_python_headless-4.5.2.52-cp37-cp37m-manylinux2014_x86_64.whl (38.2 MB)
#      |████████████████████████████████| 38.2 MB 115 kB/s
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from opencv-python-headless==4.5.2.52) (1.21.6)
# Installing collected packages: opencv-python-headless
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.2.0.34
#     Uninstalling opencv-python-headless-4.2.0.34:
#       Successfully uninstalled opencv-python-headless-4.2.0.34
# Successfully installed opencv-python-headless-4.5.2.52

# %%
# !{command}

# %%
# !pwd
# Out:
# /content

# %%
# !cd Tensorflow/workspace/models/my_ssd_mobnet && cd eval

# %%
# %load_ext tensorboard
# %tensorboard --logdir=.

# %% [markdown]
# # 8. Load Train Model From Checkpoint

# %%
import os
import tensorflow as tf
from object_detection.utils import label_map_util
from object_detection.utils import visualization_utils as viz_utils
from object_detection.builders import model_builder
from object_detection.utils import config_util

# %%
# Load pipeline config and build a detection model
configs = config_util.get_configs_from_pipeline_file(files['PIPELINE_CONFIG'])
detection_model = model_builder.build(model_config=configs['model'], is_training=False)

# Restore checkpoint
ckpt = tf.compat.v2.train.Checkpoint(model=detection_model)
ckpt.restore(os.path.join(paths['CHECKPOINT_PATH'], 'ckpt-3')).expect_partial()

@tf.function
def detect_fn(image):
    image, shapes = detection_model.preprocess(image)
    prediction_dict = detection_model.predict(image, shapes)
    detections = detection_model.postprocess(prediction_dict, shapes)
    return detections

# %% [markdown]
# # 9. Detect from an Image

# %%
import cv2 
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
category_index = label_map_util.create_category_index_from_labelmap(files['LABELMAP'])

# %%
IMAGE_PATH = os.path.join(paths['IMAGE_PATH'], 'test', 'IMG_5110.jpg')

# %%
img = cv2.imread(IMAGE_PATH)
image_np = np.array(img)

input_tensor = tf.convert_to_tensor(np.expand_dims(image_np, 0), dtype=tf.float32)
detections = detect_fn(input_tensor)

num_detections = int(detections.pop('num_detections'))
detections = {key: value[0, :num_detections].numpy()
              for key, value in detections.items()}
detections['num_detections'] = num_detections

# detection_classes should be ints.
detections['detection_classes'] = detections['detection_classes'].astype(np.int64)

label_id_offset = 1
image_np_with_detections = image_np.copy()

viz_utils.visualize_boxes_and_labels_on_image_array(
            image_np_with_detections,
            detections['detection_boxes'],
            detections['detection_classes']+label_id_offset,
            detections['detection_scores'],
            category_index,
            use_normalized_coordinates=True,
            max_boxes_to_draw=100,
            min_score_thresh=.6,
            agnostic_mode=False)

plt.imshow(cv2.cvtColor(image_np_with_detections, cv2.COLOR_BGR2RGB))
f = plt.figure()
f.set_figwidth(150)
f.set_figheight(150)
plt.show()

# %% [markdown]
# # 10. Freezing the Graph

# %%
FREEZE_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'exporter_main_v2.py ')

# %%
command = "python {} --input_type=image_tensor --pipeline_config_path={} --trained_checkpoint_dir={} --output_directory={}".format(FREEZE_SCRIPT ,files['PIPELINE_CONFIG'], paths['CHECKPOINT_PATH'], paths['OUTPUT_PATH'])

# %%
print(command)
# Out:
# python Tensorflow/models/research/object_detection/exporter_main_v2.py  --input_type=image_tensor --pipeline_config_path=Tensorflow/workspace/models/my_ssd_mobnet/pipeline.config --trained_checkpoint_dir=Tensorflow/workspace/models/my_ssd_mobnet --output_directory=Tensorflow/workspace/models/my_ssd_mobnet/export

# %%
# !{command}
# Out:
# 2022-08-05 21:46:06.982433: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/autograph/impl/api.py:458: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with back_prop=False is deprecated and will be removed in a future version.
# Instructions for updating:
# back_prop=False is deprecated. Consider using tf.stop_gradient instead.
# Instead of:
# results = tf.map_fn(fn, elems, back_prop=False)
# Use:
# results = tf.nest.map_structure(tf.stop_gradient, tf.map_fn(fn, elems))
# W0805 21:46:07.138707 139694638663552 deprecation.py:628] From /usr/local/lib/python3.7/dist-packages/tensorflow/python/autograph/impl/api.py:458: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with back_prop=False is deprecated and will be removed in a future version.
# Instructions for updating:
# back_prop=False is deprecated. Consider using tf.stop_gradient instead.
# Instead of:
# results = tf.map_fn(fn, elems, back_prop=False)
# Use:
# results = tf.nest.map_structure(tf.stop_gradient, tf.map_fn(fn, elems))
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x7f0ca0102f90>, because it is not built.
# W0805 21:46:27.368417 139694638663552 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x7f0ca0102f90>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7f0c36497990>, because it is not built.
# W0805 21:46:27.815339 139694638663552 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7f0c36497990>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f0c20c45ed0>, because it is not built.
# W0805 21:46:27.815566 139694638663552 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f0c20c45ed0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f0c20da2850>, because it is not built.
# W0805 21:46:27.815675 139694638663552 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f0c20da2850>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7f0c20e79dd0>, because it is not built.
# W0805 21:46:27.815763 139694638663552 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7f0c20e79dd0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f0c20c1e7d0>, because it is not built.
# W0805 21:46:27.815863 139694638663552 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f0c20c1e7d0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f0c20c1e510>, because it is not built.
# W0805 21:46:27.815954 139694638663552 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f0c20c1e510>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7f0c20c1e550>, because it is not built.
# W0805 21:46:27.816032 139694638663552 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7f0c20c1e550>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f0c20c1e090>, because it is not built.
# W0805 21:46:27.816109 139694638663552 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f0c20c1e090>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f0c20e41b90>, because it is not built.
# W0805 21:46:27.816194 139694638663552 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f0c20e41b90>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7f0c20dc3050>, because it is not built.
# W0805 21:46:27.816271 139694638663552 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7f0c20dc3050>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f0c20c15fd0>, because it is not built.
# W0805 21:46:27.816348 139694638663552 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f0c20c15fd0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f0c20c15090>, because it is not built.
# W0805 21:46:27.816426 139694638663552 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f0c20c15090>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f0c3678fdd0>, because it is not built.
# W0805 21:46:27.816507 139694638663552 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f0c3678fdd0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f0c20bf9210>, because it is not built.
# W0805 21:46:27.816593 139694638663552 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f0c20bf9210>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f0c36436910>, because it is not built.
# W0805 21:46:27.816675 139694638663552 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f0c36436910>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f0c20bf98d0>, because it is not built.
# W0805 21:46:27.816753 139694638663552 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f0c20bf98d0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f0c20bf9d90>, because it is not built.
# W0805 21:46:27.816860 139694638663552 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f0c20bf9d90>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f0c20bf9a10>, because it is not built.
# W0805 21:46:27.816942 139694638663552 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f0c20bf9a10>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f0c20e31090>, because it is not built.
# W0805 21:46:27.817025 139694638663552 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f0c20e31090>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f0c20e6e410>, because it is not built.
# W0805 21:46:27.817125 139694638663552 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f0c20e6e410>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f0c3678ff50>, because it is not built.
# W0805 21:46:27.817204 139694638663552 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f0c3678ff50>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f0c20bb7510>, because it is not built.
# W0805 21:46:27.817281 139694638663552 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f0c20bb7510>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f0c20bb7190>, because it is not built.
# W0805 21:46:27.817357 139694638663552 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f0c20bb7190>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f0c20bb7d90>, because it is not built.
# W0805 21:46:27.817434 139694638663552 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f0c20bb7d90>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f0c20bb7f10>, because it is not built.
# W0805 21:46:27.817515 139694638663552 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f0c20bb7f10>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f0c20bb7990>, because it is not built.
# W0805 21:46:27.817590 139694638663552 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f0c20bb7990>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f0c364e54d0>, because it is not built.
# W0805 21:46:27.817669 139694638663552 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f0c364e54d0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f0c20bb7850>, because it is not built.
# W0805 21:46:27.817746 139694638663552 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f0c20bb7850>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f0c20f93850>, because it is not built.
# W0805 21:46:27.817830 139694638663552 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f0c20f93850>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f0c20d8ca90>, because it is not built.
# W0805 21:46:27.817908 139694638663552 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f0c20d8ca90>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f0c20d8c0d0>, because it is not built.
# W0805 21:46:27.817988 139694638663552 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f0c20d8c0d0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f0c20d9fd50>, because it is not built.
# W0805 21:46:27.818065 139694638663552 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f0c20d9fd50>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f0c3673d5d0>, because it is not built.
# W0805 21:46:27.818146 139694638663552 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f0c3673d5d0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f0c20d05fd0>, because it is not built.
# W0805 21:46:27.818223 139694638663552 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f0c20d05fd0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f0c20d211d0>, because it is not built.
# W0805 21:46:27.818299 139694638663552 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f0c20d211d0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f0c364a6590>, because it is not built.
# W0805 21:46:27.818452 139694638663552 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f0c364a6590>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f0c3678ff90>, because it is not built.
# W0805 21:46:27.818542 139694638663552 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f0c3678ff90>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f0c20bf4c50>, because it is not built.
# W0805 21:46:27.818644 139694638663552 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f0c20bf4c50>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f0c20d95350>, because it is not built.
# W0805 21:46:27.818727 139694638663552 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f0c20d95350>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f0c20bf4a90>, because it is not built.
# W0805 21:46:27.818825 139694638663552 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f0c20bf4a90>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f0c20ca4ad0>, because it is not built.
# W0805 21:46:27.818912 139694638663552 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f0c20ca4ad0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f0c20bbb8d0>, because it is not built.
# W0805 21:46:27.818995 139694638663552 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f0c20bbb8d0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f0c3658ac90>, because it is not built.
# W0805 21:46:27.892424 139694638663552 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f0c3658ac90>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f0c361aefd0>, because it is not built.
# W0805 21:46:27.892648 139694638663552 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f0c361aefd0>, because it is not built.
# W0805 21:46:46.911679 139694638663552 save.py:238] Found untraced functions such as WeightSharedConvolutionalBoxPredictor_layer_call_fn, WeightSharedConvolutionalBoxPredictor_layer_call_and_return_conditional_losses, WeightSharedConvolutionalBoxHead_layer_call_fn, WeightSharedConvolutionalBoxHead_layer_call_and_return_conditional_losses, WeightSharedConvolutionalClassHead_layer_call_fn while saving (showing 5 of 173). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Tensorflow/workspace/models/my_ssd_mobnet/export/saved_model/assets
# I0805 21:46:51.966188 139694638663552 builder_impl.py:780] Assets written to: Tensorflow/workspace/models/my_ssd_mobnet/export/saved_model/assets
# INFO:tensorflow:Writing pipeline config file to Tensorflow/workspace/models/my_ssd_mobnet/export/pipeline.config
# I0805 21:46:52.517581 139694638663552 config_util.py:254] Writing pipeline config file to Tensorflow/workspace/models/my_ssd_mobnet/export/pipeline.config

# %% [markdown]
# # 11. Conversion to TFLite

# %%
TFLITE_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'export_tflite_graph_tf2.py ')

# %%
command = "python {} --pipeline_config_path={} --trained_checkpoint_dir={} --output_directory={}".format(TFLITE_SCRIPT ,files['PIPELINE_CONFIG'], paths['CHECKPOINT_PATH'], paths['TFLITE_PATH'])

# %%
print(command)
# Out:
# python Tensorflow/models/research/object_detection/export_tflite_graph_tf2.py  --pipeline_config_path=Tensorflow/workspace/models/my_ssd_mobnet/pipeline.config --trained_checkpoint_dir=Tensorflow/workspace/models/my_ssd_mobnet --output_directory=Tensorflow/workspace/models/my_ssd_mobnet/tfliteexport

# %%
# !{command}
# Out:
# 2022-08-05 22:12:28.549812: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x7faac036e390>, because it is not built.
# W0805 22:12:41.611371 140373426579328 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x7faac036e390>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7faab03a9e50>, because it is not built.
# W0805 22:12:42.012646 140373426579328 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7faab03a9e50>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7faa2bab1550>, because it is not built.
# W0805 22:12:42.012915 140373426579328 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7faa2bab1550>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7faa2bab1f50>, because it is not built.
# W0805 22:12:42.013024 140373426579328 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7faa2bab1f50>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7faa2bab1450>, because it is not built.
# W0805 22:12:42.013111 140373426579328 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7faa2bab1450>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7faa2bac3650>, because it is not built.
# W0805 22:12:42.013195 140373426579328 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7faa2bac3650>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7faa2bac3610>, because it is not built.
# W0805 22:12:42.013275 140373426579328 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7faa2bac3610>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7faa2bac3c90>, because it is not built.
# W0805 22:12:42.013355 140373426579328 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7faa2bac3c90>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7faa2bac3890>, because it is not built.
# W0805 22:12:42.013432 140373426579328 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7faa2bac3890>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7faa2bab76d0>, because it is not built.
# W0805 22:12:42.013509 140373426579328 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7faa2bab76d0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7faa2bab7850>, because it is not built.
# W0805 22:12:42.013598 140373426579328 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7faa2bab7850>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7faa2bab7a10>, because it is not built.
# W0805 22:12:42.013679 140373426579328 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7faa2bab7a10>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7faa2bab7250>, because it is not built.
# W0805 22:12:42.013759 140373426579328 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7faa2bab7250>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7faab0331950>, because it is not built.
# W0805 22:12:42.013873 140373426579328 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7faab0331950>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7faa2bc13b90>, because it is not built.
# W0805 22:12:42.013967 140373426579328 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7faa2bc13b90>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7faa2bab7710>, because it is not built.
# W0805 22:12:42.014054 140373426579328 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7faa2bab7710>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7faa2bc13ad0>, because it is not built.
# W0805 22:12:42.014142 140373426579328 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7faa2bc13ad0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7faa2bc13190>, because it is not built.
# W0805 22:12:42.014230 140373426579328 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7faa2bc13190>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7faa2bc13d50>, because it is not built.
# W0805 22:12:42.014318 140373426579328 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7faa2bc13d50>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7faa2bc13e10>, because it is not built.
# W0805 22:12:42.014404 140373426579328 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7faa2bc13e10>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7faab0243190>, because it is not built.
# W0805 22:12:42.014491 140373426579328 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7faab0243190>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7faab0331990>, because it is not built.
# W0805 22:12:42.014578 140373426579328 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7faab0331990>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7faa42218f50>, because it is not built.
# W0805 22:12:42.014675 140373426579328 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7faa42218f50>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7faa2be01f50>, because it is not built.
# W0805 22:12:42.014761 140373426579328 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7faa2be01f50>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7faa42196c10>, because it is not built.
# W0805 22:12:42.014869 140373426579328 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7faa42196c10>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7faa2bf81fd0>, because it is not built.
# W0805 22:12:42.014959 140373426579328 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7faa2bf81fd0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7faa42150e90>, because it is not built.
# W0805 22:12:42.015051 140373426579328 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7faa42150e90>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7faa42150990>, because it is not built.
# W0805 22:12:42.015145 140373426579328 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7faa42150990>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7faa2bed9c10>, because it is not built.
# W0805 22:12:42.015223 140373426579328 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7faa2bed9c10>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7faa420863d0>, because it is not built.
# W0805 22:12:42.015299 140373426579328 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7faa420863d0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7faa2bb62310>, because it is not built.
# W0805 22:12:42.015374 140373426579328 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7faa2bb62310>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7faa2bbab290>, because it is not built.
# W0805 22:12:42.015449 140373426579328 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7faa2bbab290>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7faa2be70ed0>, because it is not built.
# W0805 22:12:42.015531 140373426579328 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7faa2be70ed0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7faa2be60f50>, because it is not built.
# W0805 22:12:42.015612 140373426579328 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7faa2be60f50>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7faa2be701d0>, because it is not built.
# W0805 22:12:42.015695 140373426579328 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7faa2be701d0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7faa420e8650>, because it is not built.
# W0805 22:12:42.015774 140373426579328 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7faa420e8650>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7faa2be53b10>, because it is not built.
# W0805 22:12:42.015872 140373426579328 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7faa2be53b10>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7faab03319d0>, because it is not built.
# W0805 22:12:42.015950 140373426579328 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7faab03319d0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7faa421224d0>, because it is not built.
# W0805 22:12:42.016025 140373426579328 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7faa421224d0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7faa42122c90>, because it is not built.
# W0805 22:12:42.016101 140373426579328 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7faa42122c90>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7faa42122310>, because it is not built.
# W0805 22:12:42.016180 140373426579328 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7faa42122310>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7faa42122910>, because it is not built.
# W0805 22:12:42.016254 140373426579328 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7faa42122910>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7faab01f3a10>, because it is not built.
# W0805 22:12:42.016329 140373426579328 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7faab01f3a10>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7faab01f3450>, because it is not built.
# W0805 22:12:42.016410 140373426579328 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7faab01f3450>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7faab01f3150>, because it is not built.
# W0805 22:12:42.034511 140373426579328 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7faab01f3150>, because it is not built.
# W0805 22:13:01.975572 140373426579328 save.py:238] Found untraced functions such as WeightSharedConvolutionalBoxPredictor_layer_call_fn, WeightSharedConvolutionalBoxPredictor_layer_call_and_return_conditional_losses, WeightSharedConvolutionalBoxHead_layer_call_fn, WeightSharedConvolutionalBoxHead_layer_call_and_return_conditional_losses, WeightSharedConvolutionalClassHead_layer_call_fn while saving (showing 5 of 173). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Tensorflow/workspace/models/my_ssd_mobnet/tfliteexport/saved_model/assets
# I0805 22:13:08.624431 140373426579328 builder_impl.py:780] Assets written to: Tensorflow/workspace/models/my_ssd_mobnet/tfliteexport/saved_model/assets

# %%
FROZEN_TFLITE_PATH = os.path.join(paths['TFLITE_PATH'], 'saved_model')
TFLITE_MODEL = os.path.join(paths['TFLITE_PATH'], 'saved_model', 'detect.tflite')

# %%
command = "tflite_convert \
--saved_model_dir={} \
--output_file={} \
--input_shapes=1,300,300,3 \
--input_arrays=normalized_input_image_tensor \
--output_arrays='TFLite_Detection_PostProcess','TFLite_Detection_PostProcess:1','TFLite_Detection_PostProcess:2','TFLite_Detection_PostProcess:3' \
--inference_type=FLOAT \
--allow_custom_ops".format(FROZEN_TFLITE_PATH, TFLITE_MODEL, )

# %%
print(command)
# Out:
# tflite_convert --saved_model_dir=Tensorflow/workspace/models/my_ssd_mobnet/tfliteexport/saved_model --output_file=Tensorflow/workspace/models/my_ssd_mobnet/tfliteexport/saved_model/detect.tflite --input_shapes=1,300,300,3 --input_arrays=normalized_input_image_tensor --output_arrays='TFLite_Detection_PostProcess','TFLite_Detection_PostProcess:1','TFLite_Detection_PostProcess:2','TFLite_Detection_PostProcess:3' --inference_type=FLOAT --allow_custom_ops

# %%
# !{command}
# Out:
# 2022-08-05 22:13:15.373520: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2022-08-05 22:13:26.893441: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:362] Ignored output_format.
# 2022-08-05 22:13:26.893496: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:365] Ignored drop_control_dependency.
# Estimated count of arithmetic ops: 1.706 G  ops, equivalently 0.853 G  MACs

# %% [markdown]
# # 12. Zip and Export Models

# %%
# !tar -czf models.tar.gz {paths['CHECKPOINT_PATH']}
