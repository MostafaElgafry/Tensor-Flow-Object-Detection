# %% [markdown]
# <a href="https://colab.research.google.com/github/MostafaElgafry/Tensor-Flow-Object-Detection/blob/main/Model%20Training_and_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 0. Setup Paths

# %%
import os

# %%
CUSTOM_MODEL_NAME = 'my_ssd_mobnet' 
PRETRAINED_MODEL_NAME = 'ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8'
PRETRAINED_MODEL_URL = 'http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz'
TF_RECORD_SCRIPT_NAME = 'generate_tfrecord.py'
LABEL_MAP_NAME = 'label_map.pbtxt'

# %%
paths = {
    'WORKSPACE_PATH': os.path.join('Tensorflow', 'workspace'),
    'SCRIPTS_PATH': os.path.join('Tensorflow','scripts'),
    'APIMODEL_PATH': os.path.join('Tensorflow','models'),
    'ANNOTATION_PATH': os.path.join('Tensorflow', 'workspace','annotations'),
    'IMAGE_PATH': os.path.join('Tensorflow', 'workspace','images'),
    'MODEL_PATH': os.path.join('Tensorflow', 'workspace','models'),
    'PRETRAINED_MODEL_PATH': os.path.join('Tensorflow', 'workspace','pre-trained-models'),
    'CHECKPOINT_PATH': os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME), 
    'OUTPUT_PATH': os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME, 'export'), 
    'TFJS_PATH':os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME, 'tfjsexport'), 
    'TFLITE_PATH':os.path.join('Tensorflow', 'workspace','models',CUSTOM_MODEL_NAME, 'tfliteexport'), 
    'PROTOC_PATH':os.path.join('Tensorflow','protoc')
 }

# %%
files = {
    'PIPELINE_CONFIG':os.path.join('Tensorflow', 'workspace','models', CUSTOM_MODEL_NAME, 'pipeline.config'),
    'TF_RECORD_SCRIPT': os.path.join(paths['SCRIPTS_PATH'], TF_RECORD_SCRIPT_NAME), 
    'LABELMAP': os.path.join(paths['ANNOTATION_PATH'], LABEL_MAP_NAME)
}

# %%
for path in paths.values():
    if not os.path.exists(path):
        if os.name == 'posix':
            # !mkdir -p {path}
        if os.name == 'nt':
            # !mkdir {path}

# %% [markdown]
# # 1. Download TF Models Pretrained Models from Tensorflow Model Zoo and Install TFOD

# %%
# https://www.tensorflow.org/install/source_windows

# %%
if os.name=='nt':
    # !pip install wget
    import wget

# %%
if not os.path.exists(os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection')):
    # !git clone https://github.com/tensorflow/models {paths['APIMODEL_PATH']}

# %%
# Install Tensorflow Object Detection 
if os.name=='posix':  
    # !apt-get install protobuf-compiler
    # !cd Tensorflow/models/research && protoc object_detection/protos/*.proto --python_out=. && cp object_detection/packages/tf2/setup.py . && python -m pip install . 
    
if os.name=='nt':
    url="https://github.com/protocolbuffers/protobuf/releases/download/v3.15.6/protoc-3.15.6-win64.zip"
    wget.download(url)
    # !move protoc-3.15.6-win64.zip {paths['PROTOC_PATH']}
    # !cd {paths['PROTOC_PATH']} && tar -xf protoc-3.15.6-win64.zip
    os.environ['PATH'] += os.pathsep + os.path.abspath(os.path.join(paths['PROTOC_PATH'], 'bin'))   
    # !cd Tensorflow/models/research && protoc object_detection/protos/*.proto --python_out=. && copy object_detection\\packages\\tf2\\setup.py setup.py && python setup.py build && python setup.py install
    # !cd Tensorflow/models/research/slim && pip install -e .
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# protobuf-compiler is already the newest version (3.0.0-9.1ubuntu1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 18 not upgraded.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Processing /content/Tensorflow/models/research
#   DEPRECATION: A future pip version will change local packages to be built in-place without first copying to a temporary directory. We recommend you use --use-feature=in-tree-build to test your packages with this new behavior before it becomes the default.
#    pip 21.3 will remove support for this functionality. You can find discussion regarding this at https://github.com/pypa/pip/issues/7555.
# Requirement already satisfied: avro-python3 in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (1.10.2)
# Requirement already satisfied: apache-beam in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (2.40.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (7.1.2)
# Requirement already satisfied: lxml in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (4.9.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (3.2.2)
# Requirement already satisfied: Cython in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (0.29.32)
# Requirement already satisfied: contextlib2 in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (0.5.5)
# Requirement already satisfied: tf-slim in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (1.1.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (1.15.0)
# Requirement already satisfied: pycocotools in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (2.0.4)
# Requirement already satisfied: lvis in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (0.5.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (1.7.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (1.3.5)
# Requirement already satisfied: tf-models-official>=2.5.1 in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (2.9.2)
# Requirement already satisfied: tensorflow_io in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (0.26.0)
# Requirement already satisfied: keras in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (2.9.0)
# Requirement already satisfied: pyparsing==2.4.7 in /usr/local/lib/python3.7/dist-packages (from object-detection==0.1) (2.4.7)
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.7/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (4.2.0.34)
# Requirement already satisfied: tensorflow-text~=2.9.0 in /usr/local/lib/python3.7/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (2.9.0)
# Requirement already satisfied: tensorflow-datasets in /usr/local/lib/python3.7/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (4.6.0)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.7/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (0.1.97)
# Requirement already satisfied: tensorflow-addons in /usr/local/lib/python3.7/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (0.17.1)
# Requirement already satisfied: google-api-python-client>=1.6.7 in /usr/local/lib/python3.7/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (1.12.11)
# Requirement already satisfied: tensorflow-hub>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (0.12.0)
# Requirement already satisfied: gin-config in /usr/local/lib/python3.7/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (0.5.0)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.7/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (1.21.6)
# Requirement already satisfied: pyyaml<6.0,>=5.1 in /usr/local/lib/python3.7/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (5.4.1)
# Requirement already satisfied: tensorflow-model-optimization>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (0.7.3)
# Requirement already satisfied: oauth2client in /usr/local/lib/python3.7/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (4.1.3)
# Requirement already satisfied: py-cpuinfo>=3.3.0 in /usr/local/lib/python3.7/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (8.0.0)
# Requirement already satisfied: kaggle>=1.3.9 in /usr/local/lib/python3.7/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (1.5.12)
# Requirement already satisfied: sacrebleu in /usr/local/lib/python3.7/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (2.2.0)
# Requirement already satisfied: seqeval in /usr/local/lib/python3.7/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (1.2.2)
# Requirement already satisfied: psutil>=5.4.3 in /usr/local/lib/python3.7/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (5.4.8)
# Requirement already satisfied: tensorflow~=2.9.0 in /usr/local/lib/python3.7/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (2.9.1)
# Requirement already satisfied: google-api-core<3dev,>=1.21.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (1.31.6)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (0.0.4)
# Requirement already satisfied: httplib2<1dev,>=0.15.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (0.17.4)
# Requirement already satisfied: google-auth<3dev,>=1.16.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (1.35.0)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (3.0.1)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (2.28.1)
# Requirement already satisfied: protobuf<4.0.0dev,>=3.12.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (3.19.4)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (1.56.4)
# Requirement already satisfied: packaging>=14.3 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (21.3)
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (2022.1)
# Requirement already satisfied: setuptools>=40.3.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (57.4.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3dev,>=1.16.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3dev,>=1.16.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3dev,>=1.16.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (4.9)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (4.64.0)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.7/dist-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (6.1.2)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (2.8.2)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (1.24.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (2022.6.15)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3dev,>=1.16.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (0.4.8)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<3dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (2.10)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<3dev,>=1.21.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (2.1.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.9.0->tf-models-official>=2.5.1->object-detection==0.1) (1.14.1)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.9.0->tf-models-official>=2.5.1->object-detection==0.1) (1.2.0)
# Requirement already satisfied: tensorboard<2.10,>=2.9 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.9.0->tf-models-official>=2.5.1->object-detection==0.1) (2.9.1)
# Requirement already satisfied: tensorflow-estimator<2.10.0,>=2.9.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.9.0->tf-models-official>=2.5.1->object-detection==0.1) (2.9.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.9.0->tf-models-official>=2.5.1->object-detection==0.1) (4.1.1)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.9.0->tf-models-official>=2.5.1->object-detection==0.1) (1.1.2)
# Requirement already satisfied: flatbuffers<2,>=1.12 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.9.0->tf-models-official>=2.5.1->object-detection==0.1) (1.12)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.9.0->tf-models-official>=2.5.1->object-detection==0.1) (0.4.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.9.0->tf-models-official>=2.5.1->object-detection==0.1) (1.1.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.9.0->tf-models-official>=2.5.1->object-detection==0.1) (0.2.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.9.0->tf-models-official>=2.5.1->object-detection==0.1) (0.26.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.9.0->tf-models-official>=2.5.1->object-detection==0.1) (14.0.6)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.9.0->tf-models-official>=2.5.1->object-detection==0.1) (3.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.9.0->tf-models-official>=2.5.1->object-detection==0.1) (1.6.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.9.0->tf-models-official>=2.5.1->object-detection==0.1) (1.47.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow~=2.9.0->tf-models-official>=2.5.1->object-detection==0.1) (3.3.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.7/dist-packages (from astunparse>=1.6.0->tensorflow~=2.9.0->tf-models-official>=2.5.1->object-detection==0.1) (0.37.1)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py>=2.9.0->tensorflow~=2.9.0->tf-models-official>=2.5.1->object-detection==0.1) (1.5.2)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.10,>=2.9->tensorflow~=2.9.0->tf-models-official>=2.5.1->object-detection==0.1) (0.4.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.10,>=2.9->tensorflow~=2.9.0->tf-models-official>=2.5.1->object-detection==0.1) (1.8.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.10,>=2.9->tensorflow~=2.9.0->tf-models-official>=2.5.1->object-detection==0.1) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.10,>=2.9->tensorflow~=2.9.0->tf-models-official>=2.5.1->object-detection==0.1) (0.6.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.10,>=2.9->tensorflow~=2.9.0->tf-models-official>=2.5.1->object-detection==0.1) (1.0.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow~=2.9.0->tf-models-official>=2.5.1->object-detection==0.1) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow~=2.9.0->tf-models-official>=2.5.1->object-detection==0.1) (4.12.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow~=2.9.0->tf-models-official>=2.5.1->object-detection==0.1) (3.8.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow~=2.9.0->tf-models-official>=2.5.1->object-detection==0.1) (3.2.0)
# Requirement already satisfied: dm-tree~=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow-model-optimization>=0.4.1->tf-models-official>=2.5.1->object-detection==0.1) (0.1.7)
# Requirement already satisfied: pydot<2,>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from apache-beam->object-detection==0.1) (1.3.0)
# Requirement already satisfied: pyarrow<8.0.0,>=0.15.1 in /usr/local/lib/python3.7/dist-packages (from apache-beam->object-detection==0.1) (6.0.1)
# Requirement already satisfied: proto-plus<2,>=1.7.1 in /usr/local/lib/python3.7/dist-packages (from apache-beam->object-detection==0.1) (1.22.0)
# Requirement already satisfied: pymongo<4.0.0,>=3.8.0 in /usr/local/lib/python3.7/dist-packages (from apache-beam->object-detection==0.1) (3.12.3)
# Requirement already satisfied: dill<0.3.2,>=0.3.1.1 in /usr/local/lib/python3.7/dist-packages (from apache-beam->object-detection==0.1) (0.3.1.1)
# Requirement already satisfied: hdfs<3.0.0,>=2.1.0 in /usr/local/lib/python3.7/dist-packages (from apache-beam->object-detection==0.1) (2.7.0)
# Requirement already satisfied: cloudpickle<3,>=2.1.0 in /usr/local/lib/python3.7/dist-packages (from apache-beam->object-detection==0.1) (2.1.0)
# Requirement already satisfied: fastavro<2,>=0.23.6 in /usr/local/lib/python3.7/dist-packages (from apache-beam->object-detection==0.1) (1.5.4)
# Requirement already satisfied: orjson<4.0 in /usr/local/lib/python3.7/dist-packages (from apache-beam->object-detection==0.1) (3.7.11)
# Requirement already satisfied: crcmod<2.0,>=1.7 in /usr/local/lib/python3.7/dist-packages (from apache-beam->object-detection==0.1) (1.7)
# Requirement already satisfied: docopt in /usr/local/lib/python3.7/dist-packages (from hdfs<3.0.0,>=2.1.0->apache-beam->object-detection==0.1) (0.6.2)
# Requirement already satisfied: kiwisolver>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from lvis->object-detection==0.1) (1.4.4)
# Requirement already satisfied: cycler>=0.10.0 in /usr/local/lib/python3.7/dist-packages (from lvis->object-detection==0.1) (0.11.0)
# Requirement already satisfied: opencv-python>=4.1.0.25 in /usr/local/lib/python3.7/dist-packages (from lvis->object-detection==0.1) (4.6.0.66)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.7/dist-packages (from python-slugify->kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (1.3)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.7/dist-packages (from sacrebleu->tf-models-official>=2.5.1->object-detection==0.1) (2.5.1)
# Requirement already satisfied: colorama in /usr/local/lib/python3.7/dist-packages (from sacrebleu->tf-models-official>=2.5.1->object-detection==0.1) (0.4.5)
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from sacrebleu->tf-models-official>=2.5.1->object-detection==0.1) (2022.6.2)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.7/dist-packages (from sacrebleu->tf-models-official>=2.5.1->object-detection==0.1) (0.8.10)
# Requirement already satisfied: scikit-learn>=0.21.3 in /usr/local/lib/python3.7/dist-packages (from seqeval->tf-models-official>=2.5.1->object-detection==0.1) (1.0.2)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.21.3->seqeval->tf-models-official>=2.5.1->object-detection==0.1) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.21.3->seqeval->tf-models-official>=2.5.1->object-detection==0.1) (3.1.0)
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.7/dist-packages (from tensorflow-addons->tf-models-official>=2.5.1->object-detection==0.1) (2.7.1)
# Requirement already satisfied: toml in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (0.10.2)
# Requirement already satisfied: promise in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (2.3)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (5.9.0)
# Requirement already satisfied: etils[epath] in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (0.7.1)
# Requirement already satisfied: tensorflow-metadata in /usr/local/lib/python3.7/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (1.9.0)
# Building wheels for collected packages: object-detection
#   Building wheel for object-detection (setup.py) ... done
#   Created wheel for object-detection: filename=object_detection-0.1-py3-none-any.whl size=1694955 sha256=14ab1663818e5932644b9f4a62831593e8cb3e50d76fa2a1a6a14adc0730f0f2
#   Stored in directory: /tmp/pip-ephem-wheel-cache-hvytd5ja/wheels/a9/26/bf/1cb2313ed4855917889b97658bf0a19999e3588e47867bdaee
# Successfully built object-detection
# Installing collected packages: object-detection
#   Attempting uninstall: object-detection
#     Found existing installation: object-detection 0.1
#     Uninstalling object-detection-0.1:
#       Successfully uninstalled object-detection-0.1
# Successfully installed object-detection-0.1

# %%
VERIFICATION_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'builders', 'model_builder_tf2_test.py')
# Verify Installation
# !python {VERIFICATION_SCRIPT}
# Out:
# Running tests under Python 3.7.13: /usr/bin/python3
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_deepmac
# 2022-08-13 23:30:50.543552: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# W0813 23:30:50.876717 139971913238400 model_builder.py:1102] Building experimental DeepMAC meta-arch. Some features may be omitted.
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_deepmac): 2.84s
# I0813 23:30:51.125371 139971913238400 test_util.py:2459] time(__main__.ModelBuilderTF2Test.test_create_center_net_deepmac): 2.84s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_deepmac
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)): 0.53s
# I0813 23:30:51.653578 139971913238400 test_util.py:2459] time(__main__.ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)): 0.53s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)): 0.25s
# I0813 23:30:51.907880 139971913238400 test_util.py:2459] time(__main__.ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)): 0.25s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model_from_keypoints
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model_from_keypoints): 0.23s
# I0813 23:30:52.141481 139971913238400 test_util.py:2459] time(__main__.ModelBuilderTF2Test.test_create_center_net_model_from_keypoints): 0.23s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model_from_keypoints
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model_mobilenet
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model_mobilenet): 1.79s
# I0813 23:30:53.930181 139971913238400 test_util.py:2459] time(__main__.ModelBuilderTF2Test.test_create_center_net_model_mobilenet): 1.79s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model_mobilenet
# [ RUN      ] ModelBuilderTF2Test.test_create_experimental_model
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_experimental_model): 0.0s
# I0813 23:30:53.931116 139971913238400 test_util.py:2459] time(__main__.ModelBuilderTF2Test.test_create_experimental_model): 0.0s
# [       OK ] ModelBuilderTF2Test.test_create_experimental_model
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)): 0.02s
# I0813 23:30:53.953566 139971913238400 test_util.py:2459] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)): 0.02s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)): 0.01s
# I0813 23:30:53.966930 139971913238400 test_util.py:2459] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)): 0.01s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner): 0.01s
# I0813 23:30:53.981786 139971913238400 test_util.py:2459] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner): 0.01s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul): 0.1s
# I0813 23:30:54.080088 139971913238400 test_util.py:2459] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul): 0.1s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul): 0.09s
# I0813 23:30:54.168800 139971913238400 test_util.py:2459] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul): 0.09s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul): 0.09s
# I0813 23:30:54.262817 139971913238400 test_util.py:2459] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul): 0.09s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul): 0.09s
# I0813 23:30:54.353785 139971913238400 test_util.py:2459] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul): 0.09s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_rfcn_model_from_config
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_rfcn_model_from_config): 0.09s
# I0813 23:30:54.444288 139971913238400 test_util.py:2459] time(__main__.ModelBuilderTF2Test.test_create_rfcn_model_from_config): 0.09s
# [       OK ] ModelBuilderTF2Test.test_create_rfcn_model_from_config
# [ RUN      ] ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config): 0.03s
# I0813 23:30:54.472011 139971913238400 test_util.py:2459] time(__main__.ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config): 0.03s
# [       OK ] ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config
# [ RUN      ] ModelBuilderTF2Test.test_create_ssd_models_from_config
# I0813 23:30:54.646497 139971913238400 ssd_efficientnet_bifpn_feature_extractor.py:146] EfficientDet EfficientNet backbone version: efficientnet-b0
# I0813 23:30:54.646631 139971913238400 ssd_efficientnet_bifpn_feature_extractor.py:147] EfficientDet BiFPN num filters: 64
# I0813 23:30:54.646701 139971913238400 ssd_efficientnet_bifpn_feature_extractor.py:149] EfficientDet BiFPN num iterations: 3
# I0813 23:30:54.648716 139971913238400 efficientnet_model.py:143] round_filter input=32 output=32
# I0813 23:30:54.665149 139971913238400 efficientnet_model.py:143] round_filter input=32 output=32
# I0813 23:30:54.665289 139971913238400 efficientnet_model.py:143] round_filter input=16 output=16
# I0813 23:30:54.722972 139971913238400 efficientnet_model.py:143] round_filter input=16 output=16
# I0813 23:30:54.723089 139971913238400 efficientnet_model.py:143] round_filter input=24 output=24
# I0813 23:30:54.873555 139971913238400 efficientnet_model.py:143] round_filter input=24 output=24
# I0813 23:30:54.873674 139971913238400 efficientnet_model.py:143] round_filter input=40 output=40
# I0813 23:30:55.030445 139971913238400 efficientnet_model.py:143] round_filter input=40 output=40
# I0813 23:30:55.030592 139971913238400 efficientnet_model.py:143] round_filter input=80 output=80
# I0813 23:30:55.261269 139971913238400 efficientnet_model.py:143] round_filter input=80 output=80
# I0813 23:30:55.261428 139971913238400 efficientnet_model.py:143] round_filter input=112 output=112
# I0813 23:30:55.638721 139971913238400 efficientnet_model.py:143] round_filter input=112 output=112
# I0813 23:30:55.638890 139971913238400 efficientnet_model.py:143] round_filter input=192 output=192
# I0813 23:30:55.941850 139971913238400 efficientnet_model.py:143] round_filter input=192 output=192
# I0813 23:30:55.942009 139971913238400 efficientnet_model.py:143] round_filter input=320 output=320
# I0813 23:30:56.014197 139971913238400 efficientnet_model.py:143] round_filter input=1280 output=1280
# I0813 23:30:56.050007 139971913238400 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.0, depth_coefficient=1.0, resolution=224, dropout_rate=0.2, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0813 23:30:56.097609 139971913238400 ssd_efficientnet_bifpn_feature_extractor.py:146] EfficientDet EfficientNet backbone version: efficientnet-b1
# I0813 23:30:56.097728 139971913238400 ssd_efficientnet_bifpn_feature_extractor.py:147] EfficientDet BiFPN num filters: 88
# I0813 23:30:56.097795 139971913238400 ssd_efficientnet_bifpn_feature_extractor.py:149] EfficientDet BiFPN num iterations: 4
# I0813 23:30:56.099227 139971913238400 efficientnet_model.py:143] round_filter input=32 output=32
# I0813 23:30:56.114100 139971913238400 efficientnet_model.py:143] round_filter input=32 output=32
# I0813 23:30:56.114205 139971913238400 efficientnet_model.py:143] round_filter input=16 output=16
# I0813 23:30:56.234511 139971913238400 efficientnet_model.py:143] round_filter input=16 output=16
# I0813 23:30:56.234634 139971913238400 efficientnet_model.py:143] round_filter input=24 output=24
# I0813 23:30:56.457593 139971913238400 efficientnet_model.py:143] round_filter input=24 output=24
# I0813 23:30:56.457730 139971913238400 efficientnet_model.py:143] round_filter input=40 output=40
# I0813 23:30:56.682675 139971913238400 efficientnet_model.py:143] round_filter input=40 output=40
# I0813 23:30:56.682820 139971913238400 efficientnet_model.py:143] round_filter input=80 output=80
# I0813 23:30:56.980355 139971913238400 efficientnet_model.py:143] round_filter input=80 output=80
# I0813 23:30:56.980531 139971913238400 efficientnet_model.py:143] round_filter input=112 output=112
# I0813 23:30:57.287911 139971913238400 efficientnet_model.py:143] round_filter input=112 output=112
# I0813 23:30:57.288063 139971913238400 efficientnet_model.py:143] round_filter input=192 output=192
# I0813 23:30:57.671272 139971913238400 efficientnet_model.py:143] round_filter input=192 output=192
# I0813 23:30:57.671443 139971913238400 efficientnet_model.py:143] round_filter input=320 output=320
# I0813 23:30:57.815596 139971913238400 efficientnet_model.py:143] round_filter input=1280 output=1280
# I0813 23:30:57.844480 139971913238400 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.0, depth_coefficient=1.1, resolution=240, dropout_rate=0.2, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0813 23:30:57.903620 139971913238400 ssd_efficientnet_bifpn_feature_extractor.py:146] EfficientDet EfficientNet backbone version: efficientnet-b2
# I0813 23:30:57.903737 139971913238400 ssd_efficientnet_bifpn_feature_extractor.py:147] EfficientDet BiFPN num filters: 112
# I0813 23:30:57.903814 139971913238400 ssd_efficientnet_bifpn_feature_extractor.py:149] EfficientDet BiFPN num iterations: 5
# I0813 23:30:57.905247 139971913238400 efficientnet_model.py:143] round_filter input=32 output=32
# I0813 23:30:57.919573 139971913238400 efficientnet_model.py:143] round_filter input=32 output=32
# I0813 23:30:57.919673 139971913238400 efficientnet_model.py:143] round_filter input=16 output=16
# I0813 23:30:58.037347 139971913238400 efficientnet_model.py:143] round_filter input=16 output=16
# I0813 23:30:58.037471 139971913238400 efficientnet_model.py:143] round_filter input=24 output=24
# I0813 23:30:58.278378 139971913238400 efficientnet_model.py:143] round_filter input=24 output=24
# I0813 23:30:58.278522 139971913238400 efficientnet_model.py:143] round_filter input=40 output=48
# I0813 23:30:58.501644 139971913238400 efficientnet_model.py:143] round_filter input=40 output=48
# I0813 23:30:58.501794 139971913238400 efficientnet_model.py:143] round_filter input=80 output=88
# I0813 23:30:58.802610 139971913238400 efficientnet_model.py:143] round_filter input=80 output=88
# I0813 23:30:58.802764 139971913238400 efficientnet_model.py:143] round_filter input=112 output=120
# I0813 23:30:59.113486 139971913238400 efficientnet_model.py:143] round_filter input=112 output=120
# I0813 23:30:59.113646 139971913238400 efficientnet_model.py:143] round_filter input=192 output=208
# I0813 23:30:59.490056 139971913238400 efficientnet_model.py:143] round_filter input=192 output=208
# I0813 23:30:59.490217 139971913238400 efficientnet_model.py:143] round_filter input=320 output=352
# I0813 23:30:59.637588 139971913238400 efficientnet_model.py:143] round_filter input=1280 output=1408
# I0813 23:30:59.665081 139971913238400 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.1, depth_coefficient=1.2, resolution=260, dropout_rate=0.3, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0813 23:30:59.722245 139971913238400 ssd_efficientnet_bifpn_feature_extractor.py:146] EfficientDet EfficientNet backbone version: efficientnet-b3
# I0813 23:30:59.722407 139971913238400 ssd_efficientnet_bifpn_feature_extractor.py:147] EfficientDet BiFPN num filters: 160
# I0813 23:30:59.722479 139971913238400 ssd_efficientnet_bifpn_feature_extractor.py:149] EfficientDet BiFPN num iterations: 6
# I0813 23:30:59.723939 139971913238400 efficientnet_model.py:143] round_filter input=32 output=40
# I0813 23:30:59.739371 139971913238400 efficientnet_model.py:143] round_filter input=32 output=40
# I0813 23:30:59.739475 139971913238400 efficientnet_model.py:143] round_filter input=16 output=24
# I0813 23:30:59.862514 139971913238400 efficientnet_model.py:143] round_filter input=16 output=24
# I0813 23:30:59.862635 139971913238400 efficientnet_model.py:143] round_filter input=24 output=32
# I0813 23:31:00.271892 139971913238400 efficientnet_model.py:143] round_filter input=24 output=32
# I0813 23:31:00.272058 139971913238400 efficientnet_model.py:143] round_filter input=40 output=48
# I0813 23:31:00.503656 139971913238400 efficientnet_model.py:143] round_filter input=40 output=48
# I0813 23:31:00.503817 139971913238400 efficientnet_model.py:143] round_filter input=80 output=96
# I0813 23:31:00.895759 139971913238400 efficientnet_model.py:143] round_filter input=80 output=96
# I0813 23:31:00.895950 139971913238400 efficientnet_model.py:143] round_filter input=112 output=136
# I0813 23:31:01.358394 139971913238400 efficientnet_model.py:143] round_filter input=112 output=136
# I0813 23:31:01.358552 139971913238400 efficientnet_model.py:143] round_filter input=192 output=232
# I0813 23:31:01.804268 139971913238400 efficientnet_model.py:143] round_filter input=192 output=232
# I0813 23:31:01.804462 139971913238400 efficientnet_model.py:143] round_filter input=320 output=384
# I0813 23:31:01.955252 139971913238400 efficientnet_model.py:143] round_filter input=1280 output=1536
# I0813 23:31:01.985370 139971913238400 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.2, depth_coefficient=1.4, resolution=300, dropout_rate=0.3, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0813 23:31:02.045685 139971913238400 ssd_efficientnet_bifpn_feature_extractor.py:146] EfficientDet EfficientNet backbone version: efficientnet-b4
# I0813 23:31:02.045811 139971913238400 ssd_efficientnet_bifpn_feature_extractor.py:147] EfficientDet BiFPN num filters: 224
# I0813 23:31:02.045885 139971913238400 ssd_efficientnet_bifpn_feature_extractor.py:149] EfficientDet BiFPN num iterations: 7
# I0813 23:31:02.047360 139971913238400 efficientnet_model.py:143] round_filter input=32 output=48
# I0813 23:31:02.063044 139971913238400 efficientnet_model.py:143] round_filter input=32 output=48
# I0813 23:31:02.063155 139971913238400 efficientnet_model.py:143] round_filter input=16 output=24
# I0813 23:31:02.189604 139971913238400 efficientnet_model.py:143] round_filter input=16 output=24
# I0813 23:31:02.189728 139971913238400 efficientnet_model.py:143] round_filter input=24 output=32
# I0813 23:31:02.493694 139971913238400 efficientnet_model.py:143] round_filter input=24 output=32
# I0813 23:31:02.493843 139971913238400 efficientnet_model.py:143] round_filter input=40 output=56
# I0813 23:31:02.790794 139971913238400 efficientnet_model.py:143] round_filter input=40 output=56
# I0813 23:31:02.790947 139971913238400 efficientnet_model.py:143] round_filter input=80 output=112
# I0813 23:31:03.245628 139971913238400 efficientnet_model.py:143] round_filter input=80 output=112
# I0813 23:31:03.245791 139971913238400 efficientnet_model.py:143] round_filter input=112 output=160
# I0813 23:31:03.695960 139971913238400 efficientnet_model.py:143] round_filter input=112 output=160
# I0813 23:31:03.696126 139971913238400 efficientnet_model.py:143] round_filter input=192 output=272
# I0813 23:31:04.307030 139971913238400 efficientnet_model.py:143] round_filter input=192 output=272
# I0813 23:31:04.307193 139971913238400 efficientnet_model.py:143] round_filter input=320 output=448
# I0813 23:31:04.453609 139971913238400 efficientnet_model.py:143] round_filter input=1280 output=1792
# I0813 23:31:04.482457 139971913238400 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.4, depth_coefficient=1.8, resolution=380, dropout_rate=0.4, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0813 23:31:04.552712 139971913238400 ssd_efficientnet_bifpn_feature_extractor.py:146] EfficientDet EfficientNet backbone version: efficientnet-b5
# I0813 23:31:04.552842 139971913238400 ssd_efficientnet_bifpn_feature_extractor.py:147] EfficientDet BiFPN num filters: 288
# I0813 23:31:04.552912 139971913238400 ssd_efficientnet_bifpn_feature_extractor.py:149] EfficientDet BiFPN num iterations: 7
# I0813 23:31:04.554393 139971913238400 efficientnet_model.py:143] round_filter input=32 output=48
# I0813 23:31:04.568940 139971913238400 efficientnet_model.py:143] round_filter input=32 output=48
# I0813 23:31:04.569045 139971913238400 efficientnet_model.py:143] round_filter input=16 output=24
# I0813 23:31:04.745965 139971913238400 efficientnet_model.py:143] round_filter input=16 output=24
# I0813 23:31:04.746096 139971913238400 efficientnet_model.py:143] round_filter input=24 output=40
# I0813 23:31:05.124403 139971913238400 efficientnet_model.py:143] round_filter input=24 output=40
# I0813 23:31:05.124555 139971913238400 efficientnet_model.py:143] round_filter input=40 output=64
# I0813 23:31:05.699278 139971913238400 efficientnet_model.py:143] round_filter input=40 output=64
# I0813 23:31:05.699455 139971913238400 efficientnet_model.py:143] round_filter input=80 output=128
# I0813 23:31:06.238893 139971913238400 efficientnet_model.py:143] round_filter input=80 output=128
# I0813 23:31:06.239057 139971913238400 efficientnet_model.py:143] round_filter input=112 output=176
# I0813 23:31:06.766561 139971913238400 efficientnet_model.py:143] round_filter input=112 output=176
# I0813 23:31:06.766723 139971913238400 efficientnet_model.py:143] round_filter input=192 output=304
# I0813 23:31:07.441027 139971913238400 efficientnet_model.py:143] round_filter input=192 output=304
# I0813 23:31:07.441191 139971913238400 efficientnet_model.py:143] round_filter input=320 output=512
# I0813 23:31:07.658984 139971913238400 efficientnet_model.py:143] round_filter input=1280 output=2048
# I0813 23:31:07.686097 139971913238400 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.6, depth_coefficient=2.2, resolution=456, dropout_rate=0.4, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0813 23:31:07.768156 139971913238400 ssd_efficientnet_bifpn_feature_extractor.py:146] EfficientDet EfficientNet backbone version: efficientnet-b6
# I0813 23:31:07.768290 139971913238400 ssd_efficientnet_bifpn_feature_extractor.py:147] EfficientDet BiFPN num filters: 384
# I0813 23:31:07.768367 139971913238400 ssd_efficientnet_bifpn_feature_extractor.py:149] EfficientDet BiFPN num iterations: 8
# I0813 23:31:07.769815 139971913238400 efficientnet_model.py:143] round_filter input=32 output=56
# I0813 23:31:07.784290 139971913238400 efficientnet_model.py:143] round_filter input=32 output=56
# I0813 23:31:07.784399 139971913238400 efficientnet_model.py:143] round_filter input=16 output=32
# I0813 23:31:07.961277 139971913238400 efficientnet_model.py:143] round_filter input=16 output=32
# I0813 23:31:07.961427 139971913238400 efficientnet_model.py:143] round_filter input=24 output=40
# I0813 23:31:08.420172 139971913238400 efficientnet_model.py:143] round_filter input=24 output=40
# I0813 23:31:08.420351 139971913238400 efficientnet_model.py:143] round_filter input=40 output=72
# I0813 23:31:08.898550 139971913238400 efficientnet_model.py:143] round_filter input=40 output=72
# I0813 23:31:08.898715 139971913238400 efficientnet_model.py:143] round_filter input=80 output=144
# I0813 23:31:09.505322 139971913238400 efficientnet_model.py:143] round_filter input=80 output=144
# I0813 23:31:09.505513 139971913238400 efficientnet_model.py:143] round_filter input=112 output=200
# I0813 23:31:10.095598 139971913238400 efficientnet_model.py:143] round_filter input=112 output=200
# I0813 23:31:10.095775 139971913238400 efficientnet_model.py:143] round_filter input=192 output=344
# I0813 23:31:10.933245 139971913238400 efficientnet_model.py:143] round_filter input=192 output=344
# I0813 23:31:10.933428 139971913238400 efficientnet_model.py:143] round_filter input=320 output=576
# I0813 23:31:11.155972 139971913238400 efficientnet_model.py:143] round_filter input=1280 output=2304
# I0813 23:31:11.183544 139971913238400 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.8, depth_coefficient=2.6, resolution=528, dropout_rate=0.5, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0813 23:31:11.485906 139971913238400 ssd_efficientnet_bifpn_feature_extractor.py:146] EfficientDet EfficientNet backbone version: efficientnet-b7
# I0813 23:31:11.486069 139971913238400 ssd_efficientnet_bifpn_feature_extractor.py:147] EfficientDet BiFPN num filters: 384
# I0813 23:31:11.486141 139971913238400 ssd_efficientnet_bifpn_feature_extractor.py:149] EfficientDet BiFPN num iterations: 8
# I0813 23:31:11.487656 139971913238400 efficientnet_model.py:143] round_filter input=32 output=64
# I0813 23:31:11.503585 139971913238400 efficientnet_model.py:143] round_filter input=32 output=64
# I0813 23:31:11.503714 139971913238400 efficientnet_model.py:143] round_filter input=16 output=32
# I0813 23:31:11.751021 139971913238400 efficientnet_model.py:143] round_filter input=16 output=32
# I0813 23:31:11.751168 139971913238400 efficientnet_model.py:143] round_filter input=24 output=48
# I0813 23:31:12.278912 139971913238400 efficientnet_model.py:143] round_filter input=24 output=48
# I0813 23:31:12.279073 139971913238400 efficientnet_model.py:143] round_filter input=40 output=80
# I0813 23:31:12.809284 139971913238400 efficientnet_model.py:143] round_filter input=40 output=80
# I0813 23:31:12.809459 139971913238400 efficientnet_model.py:143] round_filter input=80 output=160
# I0813 23:31:13.574897 139971913238400 efficientnet_model.py:143] round_filter input=80 output=160
# I0813 23:31:13.575100 139971913238400 efficientnet_model.py:143] round_filter input=112 output=224
# I0813 23:31:14.325181 139971913238400 efficientnet_model.py:143] round_filter input=112 output=224
# I0813 23:31:14.325374 139971913238400 efficientnet_model.py:143] round_filter input=192 output=384
# I0813 23:31:15.305645 139971913238400 efficientnet_model.py:143] round_filter input=192 output=384
# I0813 23:31:15.305824 139971913238400 efficientnet_model.py:143] round_filter input=320 output=640
# I0813 23:31:15.621917 139971913238400 efficientnet_model.py:143] round_filter input=1280 output=2560
# I0813 23:31:15.650274 139971913238400 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=2.0, depth_coefficient=3.1, resolution=600, dropout_rate=0.5, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_ssd_models_from_config): 21.29s
# I0813 23:31:15.759637 139971913238400 test_util.py:2459] time(__main__.ModelBuilderTF2Test.test_create_ssd_models_from_config): 21.29s
# [       OK ] ModelBuilderTF2Test.test_create_ssd_models_from_config
# [ RUN      ] ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update): 0.0s
# I0813 23:31:15.764966 139971913238400 test_util.py:2459] time(__main__.ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update
# [ RUN      ] ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold): 0.0s
# I0813 23:31:15.766525 139971913238400 test_util.py:2459] time(__main__.ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold
# [ RUN      ] ModelBuilderTF2Test.test_invalid_model_config_proto
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_model_config_proto): 0.0s
# I0813 23:31:15.767030 139971913238400 test_util.py:2459] time(__main__.ModelBuilderTF2Test.test_invalid_model_config_proto): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_model_config_proto
# [ RUN      ] ModelBuilderTF2Test.test_invalid_second_stage_batch_size
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_second_stage_batch_size): 0.0s
# I0813 23:31:15.768441 139971913238400 test_util.py:2459] time(__main__.ModelBuilderTF2Test.test_invalid_second_stage_batch_size): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_second_stage_batch_size
# [ RUN      ] ModelBuilderTF2Test.test_session
# [  SKIPPED ] ModelBuilderTF2Test.test_session
# [ RUN      ] ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor): 0.0s
# I0813 23:31:15.769713 139971913238400 test_util.py:2459] time(__main__.ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor
# [ RUN      ] ModelBuilderTF2Test.test_unknown_meta_architecture
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_meta_architecture): 0.0s
# I0813 23:31:15.770136 139971913238400 test_util.py:2459] time(__main__.ModelBuilderTF2Test.test_unknown_meta_architecture): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_meta_architecture
# [ RUN      ] ModelBuilderTF2Test.test_unknown_ssd_feature_extractor
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_ssd_feature_extractor): 0.0s
# I0813 23:31:15.771054 139971913238400 test_util.py:2459] time(__main__.ModelBuilderTF2Test.test_unknown_ssd_feature_extractor): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_ssd_feature_extractor
# ----------------------------------------------------------------------
# Ran 24 tests in 27.482s
#
# OK (skipped=1)

# %%
import object_detection

# %%
if os.name =='posix':
    # !wget {PRETRAINED_MODEL_URL}
    # !mv {PRETRAINED_MODEL_NAME+'.tar.gz'} {paths['PRETRAINED_MODEL_PATH']}
    # !cd {paths['PRETRAINED_MODEL_PATH']} && tar -zxvf {PRETRAINED_MODEL_NAME+'.tar.gz'}
if os.name == 'nt':
    wget.download(PRETRAINED_MODEL_URL)
    # !move {PRETRAINED_MODEL_NAME+'.tar.gz'} {paths['PRETRAINED_MODEL_PATH']}
    # !cd {paths['PRETRAINED_MODEL_PATH']} && tar -zxvf {PRETRAINED_MODEL_NAME+'.tar.gz'}
# Out:
# --2022-08-13 23:31:16--  http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz
# Resolving download.tensorflow.org (download.tensorflow.org)... 142.250.4.128, 2404:6800:4003:c04::80
# Connecting to download.tensorflow.org (download.tensorflow.org)|142.250.4.128|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 20515344 (20M) [application/x-tar]
# Saving to: ‘ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz’
#
# ssd_mobilenet_v2_fp 100%[===================>]  19.56M  --.-KB/s    in 0.08s
#
# 2022-08-13 23:31:17 (232 MB/s) - ‘ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8.tar.gz’ saved [20515344/20515344]
#
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/ckpt-0.data-00000-of-00001
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/checkpoint
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/checkpoint/ckpt-0.index
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/pipeline.config
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/saved_model.pb
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/variables/
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/variables/variables.data-00000-of-00001
# ssd_mobilenet_v2_fpnlite_320x320_coco17_tpu-8/saved_model/variables/variables.index

# %% [markdown]
# # 2. Create Label Map

# %%
labels = [{'name':'pollinated', 'id':1}, {'name':'ready', 'id':2}, {'name':'notready', 'id':3}]

with open(files['LABELMAP'], 'w') as f:
    for label in labels:
        f.write('item { \n')
        f.write('\tname:\'{}\'\n'.format(label['name']))
        f.write('\tid:{}\n'.format(label['id']))
        f.write('}\n')

# %% [markdown]
# # 3. Create TF records

# %%
# !apt-get install rar
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# rar is already the newest version (2:5.5.0-1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 18 not upgraded.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !unrar x -Y "/content/drive/MyDrive/dataset/images5.rar" "/content/Tensorflow/workspace/images/"
# Out:
# UNRAR 5.50 freeware      Copyright (c) 1993-2017 Alexander Roshal
#
#
# Extracting from /content/drive/MyDrive/dataset/images5.rar
#
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# All OK

# %%
if not os.path.exists(files['TF_RECORD_SCRIPT']):
    # !git clone https://github.com/nicknochnack/GenerateTFRecord {paths['SCRIPTS_PATH']}

# %%
# !python {files['TF_RECORD_SCRIPT']} -x {os.path.join(paths['IMAGE_PATH'], 'train')} -l {files['LABELMAP']} -o {os.path.join(paths['ANNOTATION_PATH'], 'train.record')} 
# !python {files['TF_RECORD_SCRIPT']} -x {os.path.join(paths['IMAGE_PATH'], 'test')} -l {files['LABELMAP']} -o {os.path.join(paths['ANNOTATION_PATH'], 'test.record')}
# Out:
# Successfully created the TFRecord file: Tensorflow/workspace/annotations/train.record
# Successfully created the TFRecord file: Tensorflow/workspace/annotations/test.record

# %% [markdown]
# # 4. Copy Model Config to Training Folder

# %%
if os.name =='posix':
    # !cp {os.path.join(paths['PRETRAINED_MODEL_PATH'], PRETRAINED_MODEL_NAME, 'pipeline.config')} {os.path.join(paths['CHECKPOINT_PATH'])}
if os.name == 'nt':
    # !copy {os.path.join(paths['PRETRAINED_MODEL_PATH'], PRETRAINED_MODEL_NAME, 'pipeline.config')} {os.path.join(paths['CHECKPOINT_PATH'])}

# %% [markdown]
# # 5. Update Config For Transfer Learning

# %%
import tensorflow as tf
from object_detection.utils import config_util
from object_detection.protos import pipeline_pb2
from google.protobuf import text_format

# %%
config = config_util.get_configs_from_pipeline_file(files['PIPELINE_CONFIG'])

# %%
config
# Out:
# {'eval_config': metrics_set: "coco_detection_metrics"
#  use_moving_averages: false,
#  'eval_input_config': label_map_path: "PATH_TO_BE_CONFIGURED"
#  shuffle: false
#  num_epochs: 1
#  tf_record_input_reader {
#    input_path: "PATH_TO_BE_CONFIGURED"
#  },
#  'eval_input_configs': [label_map_path: "PATH_TO_BE_CONFIGURED"
#  shuffle: false
#  num_epochs: 1
#  tf_record_input_reader {
#    input_path: "PATH_TO_BE_CONFIGURED"
#  }
#  ],
#  'model': ssd {
#    num_classes: 90
#    image_resizer {
#      fixed_shape_resizer {
#        height: 320
#        width: 320
#      }
#    }
#    feature_extractor {
#      type: "ssd_mobilenet_v2_fpn_keras"
#      depth_multiplier: 1.0
#      min_depth: 16
#      conv_hyperparams {
#        regularizer {
#          l2_regularizer {
#            weight: 3.9999998989515007e-05
#          }
#        }
#        initializer {
#          random_normal_initializer {
#            mean: 0.0
#            stddev: 0.009999999776482582
#          }
#        }
#        activation: RELU_6
#        batch_norm {
#          decay: 0.996999979019165
#          scale: true
#          epsilon: 0.0010000000474974513
#        }
#      }
#      use_depthwise: true
#      override_base_feature_extractor_hyperparams: true
#      fpn {
#        min_level: 3
#        max_level: 7
#        additional_layer_depth: 128
#      }
#    }
#    box_coder {
#      faster_rcnn_box_coder {
#        y_scale: 10.0
#        x_scale: 10.0
#        height_scale: 5.0
#        width_scale: 5.0
#      }
#    }
#    matcher {
#      argmax_matcher {
#        matched_threshold: 0.5
#        unmatched_threshold: 0.5
#        ignore_thresholds: false
#        negatives_lower_than_unmatched: true
#        force_match_for_each_row: true
#        use_matmul_gather: true
#      }
#    }
#    similarity_calculator {
#      iou_similarity {
#      }
#    }
#    box_predictor {
#      weight_shared_convolutional_box_predictor {
#        conv_hyperparams {
#          regularizer {
#            l2_regularizer {
#              weight: 3.9999998989515007e-05
#            }
#          }
#          initializer {
#            random_normal_initializer {
#              mean: 0.0
#              stddev: 0.009999999776482582
#            }
#          }
#          activation: RELU_6
#          batch_norm {
#            decay: 0.996999979019165
#            scale: true
#            epsilon: 0.0010000000474974513
#          }
#        }
#        depth: 128
#        num_layers_before_predictor: 4
#        kernel_size: 3
#        class_prediction_bias_init: -4.599999904632568
#        share_prediction_tower: true
#        use_depthwise: true
#      }
#    }
#    anchor_generator {
#      multiscale_anchor_generator {
#        min_level: 3
#        max_level: 7
#        anchor_scale: 4.0
#        aspect_ratios: 1.0
#        aspect_ratios: 2.0
#        aspect_ratios: 0.5
#        scales_per_octave: 2
#      }
#    }
#    post_processing {
#      batch_non_max_suppression {
#        score_threshold: 9.99999993922529e-09
#        iou_threshold: 0.6000000238418579
#        max_detections_per_class: 100
#        max_total_detections: 100
#        use_static_shapes: false
#      }
#      score_converter: SIGMOID
#    }
#    normalize_loss_by_num_matches: true
#    loss {
#      localization_loss {
#        weighted_smooth_l1 {
#        }
#      }
#      classification_loss {
#        weighted_sigmoid_focal {
#          gamma: 2.0
#          alpha: 0.25
#        }
#      }
#      classification_weight: 1.0
#      localization_weight: 1.0
#    }
#    encode_background_as_zeros: true
#    normalize_loc_loss_by_codesize: true
#    inplace_batchnorm_update: true
#    freeze_batchnorm: false
#  },
#  'train_config': batch_size: 128
#  data_augmentation_options {
#    random_horizontal_flip {
#    }
#  }
#  data_augmentation_options {
#    random_crop_image {
#      min_object_covered: 0.0
#      min_aspect_ratio: 0.75
#      max_aspect_ratio: 3.0
#      min_area: 0.75
#      max_area: 1.0
#      overlap_thresh: 0.0
#    }
#  }
#  sync_replicas: true
#  optimizer {
#    momentum_optimizer {
#      learning_rate {
#        cosine_decay_learning_rate {
#          learning_rate_base: 0.07999999821186066
#          total_steps: 50000
#          warmup_learning_rate: 0.026666000485420227
#          warmup_steps: 1000
#        }
#      }
#      momentum_optimizer_value: 0.8999999761581421
#    }
#    use_moving_average: false
#  }
#  fine_tune_checkpoint: "PATH_TO_BE_CONFIGURED"
#  num_steps: 50000
#  startup_delay_steps: 0.0
#  replicas_to_aggregate: 8
#  max_number_of_boxes: 100
#  unpad_groundtruth_tensors: false
#  fine_tune_checkpoint_type: "classification"
#  fine_tune_checkpoint_version: V2,
#  'train_input_config': label_map_path: "PATH_TO_BE_CONFIGURED"
#  tf_record_input_reader {
#    input_path: "PATH_TO_BE_CONFIGURED"
#  }}

# %%
pipeline_config = pipeline_pb2.TrainEvalPipelineConfig()
with tf.io.gfile.GFile(files['PIPELINE_CONFIG'], "r") as f:                                                                                                                                                                                                                     
    proto_str = f.read()                                                                                                                                                                                                                                          
    text_format.Merge(proto_str, pipeline_config)

# %%
pipeline_config.model.ssd.num_classes = len(labels)
pipeline_config.train_config.batch_size = 4
pipeline_config.train_config.fine_tune_checkpoint = os.path.join(paths['PRETRAINED_MODEL_PATH'], PRETRAINED_MODEL_NAME, 'checkpoint', 'ckpt-0')
pipeline_config.train_config.fine_tune_checkpoint_type = "detection"
pipeline_config.train_input_reader.label_map_path= files['LABELMAP']
pipeline_config.train_config.optimizer.momentum_optimizer.learning_rate.cosine_decay_learning_rate.learning_rate_base= 0.008
pipeline_config.train_config.optimizer.momentum_optimizer.learning_rate.cosine_decay_learning_rate.warmup_learning_rate=0.0026666
pipeline_config.train_input_reader.tf_record_input_reader.input_path[:] = [os.path.join(paths['ANNOTATION_PATH'], 'train.record')]
pipeline_config.eval_input_reader[0].label_map_path = files['LABELMAP']
pipeline_config.eval_input_reader[0].tf_record_input_reader.input_path[:] = [os.path.join(paths['ANNOTATION_PATH'], 'test.record')]

# %%
config_text = text_format.MessageToString(pipeline_config)                                                                                                                                                                                                        
with tf.io.gfile.GFile(files['PIPELINE_CONFIG'], "wb") as f:                                                                                                                                                                                                                     
    f.write(config_text)

# %% [markdown]
# # 6. Train the model

# %%
# !apt install --allow-change-held-packages libcudnn8=8.1.0.77-1+cuda11.2
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libcudnn8 is already the newest version (8.1.0.77-1+cuda11.2).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 17 not upgraded.

# %%
pip install "opencv-python-headless<4.3"
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting opencv-python-headless<4.3
#   Downloading opencv_python_headless-4.2.0.34-cp37-cp37m-manylinux1_x86_64.whl (21.6 MB)
#      |████████████████████████████████| 21.6 MB 1.2 MB/s
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from opencv-python-headless<4.3) (1.21.6)
# Installing collected packages: opencv-python-headless
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.6.0.66
#     Uninstalling opencv-python-headless-4.6.0.66:
#       Successfully uninstalled opencv-python-headless-4.6.0.66
# Successfully installed opencv-python-headless-4.2.0.34

# %%
TRAINING_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'model_main_tf2.py')

# %%
command = "python {} --model_dir={} --pipeline_config_path={} --num_train_steps=15000".format(TRAINING_SCRIPT, paths['CHECKPOINT_PATH'],files['PIPELINE_CONFIG'])

# %%
print(command)
# Out:
# python Tensorflow/models/research/object_detection/model_main_tf2.py --model_dir=Tensorflow/workspace/models/my_ssd_mobnet --pipeline_config_path=Tensorflow/workspace/models/my_ssd_mobnet/pipeline.config --num_train_steps=40000

# %%
# !{command}
# Out:
# 2022-08-13 23:34:10.516450: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# I0813 23:34:10.523865 140122632734592 mirrored_strategy.py:374] Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# INFO:tensorflow:Maybe overwriting train_steps: 40000
# I0813 23:34:10.527646 140122632734592 config_util.py:552] Maybe overwriting train_steps: 40000
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I0813 23:34:10.527806 140122632734592 config_util.py:552] Maybe overwriting use_bfloat16: False
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/object_detection/model_lib_v2.py:564: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# W0813 23:34:10.551659 140122632734592 deprecation.py:356] From /usr/local/lib/python3.7/dist-packages/object_detection/model_lib_v2.py:564: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# INFO:tensorflow:Reading unweighted datasets: ['Tensorflow/workspace/annotations/train.record']
# I0813 23:34:10.555957 140122632734592 dataset_builder.py:162] Reading unweighted datasets: ['Tensorflow/workspace/annotations/train.record']
# INFO:tensorflow:Reading record datasets for input file: ['Tensorflow/workspace/annotations/train.record']
# I0813 23:34:10.556132 140122632734592 dataset_builder.py:79] Reading record datasets for input file: ['Tensorflow/workspace/annotations/train.record']
# INFO:tensorflow:Number of filenames to read: 1
# I0813 23:34:10.556217 140122632734592 dataset_builder.py:80] Number of filenames to read: 1
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.
# W0813 23:34:10.556288 140122632734592 dataset_builder.py:87] num_readers has been reduced to 1 to match input file shards.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/object_detection/builders/dataset_builder.py:104: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# W0813 23:34:10.558495 140122632734592 deprecation.py:356] From /usr/local/lib/python3.7/dist-packages/object_detection/builders/dataset_builder.py:104: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/object_detection/builders/dataset_builder.py:236: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# W0813 23:34:10.577008 140122632734592 deprecation.py:356] From /usr/local/lib/python3.7/dist-packages/object_detection/builders/dataset_builder.py:236: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# W0813 23:34:17.301649 140122632734592 deprecation.py:356] From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# W0813 23:34:20.101446 140122632734592 deprecation.py:356] From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0813 23:34:21.502354 140122632734592 deprecation.py:356] From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# /usr/local/lib/python3.7/dist-packages/keras/backend.py:450: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn('`tf.keras.backend.set_learning_phase` is deprecated and '
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/deprecation.py:629: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# W0813 23:34:50.244160 140117746558720 deprecation.py:560] From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/deprecation.py:629: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# INFO:tensorflow:Step 5100 per-step time 0.647s
# I0813 23:35:54.649263 140122632734592 model_lib_v2.py:707] Step 5100 per-step time 0.647s
# INFO:tensorflow:{'Loss/classification_loss': 0.24511227,
#  'Loss/localization_loss': 0.1330675,
#  'Loss/regularization_loss': 0.15715198,
#  'Loss/total_loss': 0.5353318,
#  'learning_rate': 0.007862595}
# I0813 23:35:54.649662 140122632734592 model_lib_v2.py:708] {'Loss/classification_loss': 0.24511227,
#  'Loss/localization_loss': 0.1330675,
#  'Loss/regularization_loss': 0.15715198,
#  'Loss/total_loss': 0.5353318,
#  'learning_rate': 0.007862595}
# INFO:tensorflow:Step 5200 per-step time 0.279s
# I0813 23:36:22.564394 140122632734592 model_lib_v2.py:707] Step 5200 per-step time 0.279s
# INFO:tensorflow:{'Loss/classification_loss': 0.1788163,
#  'Loss/localization_loss': 0.13382334,
#  'Loss/regularization_loss': 0.15708259,
#  'Loss/total_loss': 0.46972224,
#  'learning_rate': 0.007855851}
# I0813 23:36:22.564859 140122632734592 model_lib_v2.py:708] {'Loss/classification_loss': 0.1788163,
#  'Loss/localization_loss': 0.13382334,
#  'Loss/regularization_loss': 0.15708259,
#  'Loss/total_loss': 0.46972224,
#  'learning_rate': 0.007855851}
# INFO:tensorflow:Step 5300 per-step time 0.313s
# I0813 23:36:53.809524 140122632734592 model_lib_v2.py:707] Step 5300 per-step time 0.313s
# INFO:tensorflow:{'Loss/classification_loss': 0.15119988,
#  'Loss/localization_loss': 0.07339571,
#  'Loss/regularization_loss': 0.15700802,
#  'Loss/total_loss': 0.3816036,
#  'learning_rate': 0.00784895}
# I0813 23:36:53.809865 140122632734592 model_lib_v2.py:708] {'Loss/classification_loss': 0.15119988,
#  'Loss/localization_loss': 0.07339571,
#  'Loss/regularization_loss': 0.15700802,
#  'Loss/total_loss': 0.3816036,
#  'learning_rate': 0.00784895}
# INFO:tensorflow:Step 5400 per-step time 0.296s
# I0813 23:37:23.396319 140122632734592 model_lib_v2.py:707] Step 5400 per-step time 0.296s
# INFO:tensorflow:{'Loss/classification_loss': 0.15101045,
#  'Loss/localization_loss': 0.05637747,
#  'Loss/regularization_loss': 0.15693463,
#  'Loss/total_loss': 0.36432254,
#  'learning_rate': 0.00784189}
# I0813 23:37:23.396727 140122632734592 model_lib_v2.py:708] {'Loss/classification_loss': 0.15101045,
#  'Loss/localization_loss': 0.05637747,
#  'Loss/regularization_loss': 0.15693463,
#  'Loss/total_loss': 0.36432254,
#  'learning_rate': 0.00784189}
# INFO:tensorflow:Step 5500 per-step time 0.302s
# I0813 23:37:53.591187 140122632734592 model_lib_v2.py:707] Step 5500 per-step time 0.302s
# INFO:tensorflow:{'Loss/classification_loss': 0.23165262,
#  'Loss/localization_loss': 0.19989532,
#  'Loss/regularization_loss': 0.15685758,
#  'Loss/total_loss': 0.5884055,
#  'learning_rate': 0.007834672}
# I0813 23:37:53.591548 140122632734592 model_lib_v2.py:708] {'Loss/classification_loss': 0.23165262,
#  'Loss/localization_loss': 0.19989532,
#  'Loss/regularization_loss': 0.15685758,
#  'Loss/total_loss': 0.5884055,
#  'learning_rate': 0.007834672}
# INFO:tensorflow:Step 5600 per-step time 0.291s
# I0813 23:38:22.720408 140122632734592 model_lib_v2.py:707] Step 5600 per-step time 0.291s
# INFO:tensorflow:{'Loss/classification_loss': 0.14654885,
#  'Loss/localization_loss': 0.07430142,
#  'Loss/regularization_loss': 0.1567803,
#  'Loss/total_loss': 0.3776306,
#  'learning_rate': 0.007827296}
# I0813 23:38:22.720873 140122632734592 model_lib_v2.py:708] {'Loss/classification_loss': 0.14654885,
#  'Loss/localization_loss': 0.07430142,
#  'Loss/regularization_loss': 0.1567803,
#  'Loss/total_loss': 0.3776306,
#  'learning_rate': 0.007827296}
# INFO:tensorflow:Step 5700 per-step time 0.317s
# I0813 23:38:54.416359 140122632734592 model_lib_v2.py:707] Step 5700 per-step time 0.317s
# INFO:tensorflow:{'Loss/classification_loss': 0.10949646,
#  'Loss/localization_loss': 0.06639245,
#  'Loss/regularization_loss': 0.15671822,
#  'Loss/total_loss': 0.33260715,
#  'learning_rate': 0.007819763}
# I0813 23:38:54.416809 140122632734592 model_lib_v2.py:708] {'Loss/classification_loss': 0.10949646,
#  'Loss/localization_loss': 0.06639245,
#  'Loss/regularization_loss': 0.15671822,
#  'Loss/total_loss': 0.33260715,
#  'learning_rate': 0.007819763}
# INFO:tensorflow:Step 5800 per-step time 0.293s
# I0813 23:39:23.735630 140122632734592 model_lib_v2.py:707] Step 5800 per-step time 0.293s
# INFO:tensorflow:{'Loss/classification_loss': 0.11234802,
#  'Loss/localization_loss': 0.042821106,
#  'Loss/regularization_loss': 0.15663986,
#  'Loss/total_loss': 0.311809,
#  'learning_rate': 0.007812073}
# I0813 23:39:23.736121 140122632734592 model_lib_v2.py:708] {'Loss/classification_loss': 0.11234802,
#  'Loss/localization_loss': 0.042821106,
#  'Loss/regularization_loss': 0.15663986,
#  'Loss/total_loss': 0.311809,
#  'learning_rate': 0.007812073}
# INFO:tensorflow:Step 5900 per-step time 0.299s
# I0813 23:39:53.621831 140122632734592 model_lib_v2.py:707] Step 5900 per-step time 0.299s
# INFO:tensorflow:{'Loss/classification_loss': 0.17464042,
#  'Loss/localization_loss': 0.09026602,
#  'Loss/regularization_loss': 0.1565721,
#  'Loss/total_loss': 0.42147854,
#  'learning_rate': 0.007804226}
# I0813 23:39:53.622250 140122632734592 model_lib_v2.py:708] {'Loss/classification_loss': 0.17464042,
#  'Loss/localization_loss': 0.09026602,
#  'Loss/regularization_loss': 0.1565721,
#  'Loss/total_loss': 0.42147854,
#  'learning_rate': 0.007804226}
# INFO:tensorflow:Step 6000 per-step time 0.311s
# I0813 23:40:24.745738 140122632734592 model_lib_v2.py:707] Step 6000 per-step time 0.311s
# INFO:tensorflow:{'Loss/classification_loss': 0.22452137,
#  'Loss/localization_loss': 0.16240945,
#  'Loss/regularization_loss': 0.15652308,
#  'Loss/total_loss': 0.54345393,
#  'learning_rate': 0.0077962233}
# I0813 23:40:24.746141 140122632734592 model_lib_v2.py:708] {'Loss/classification_loss': 0.22452137,
#  'Loss/localization_loss': 0.16240945,
#  'Loss/regularization_loss': 0.15652308,
#  'Loss/total_loss': 0.54345393,
#  'learning_rate': 0.0077962233}
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0813 23:40:25.131964 140122632734592 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0813 23:40:25.137474 140122632734592 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0813 23:40:25.146580 140122632734592 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0813 23:40:25.151227 140122632734592 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0813 23:40:25.160705 140122632734592 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0813 23:40:25.164065 140122632734592 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0813 23:40:25.169203 140122632734592 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0813 23:40:25.178074 140122632734592 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0813 23:40:25.180850 140122632734592 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0813 23:40:25.182053 140122632734592 cross_device_ops.py:618] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Step 6100 per-step time 0.291s
# I0813 23:40:53.867954 140122632734592 model_lib_v2.py:707] Step 6100 per-step time 0.291s
# INFO:tensorflow:{'Loss/classification_loss': 0.15340298,
#  'Loss/localization_loss': 0.07461502,
#  'Loss/regularization_loss': 0.15644321,
#  'Loss/total_loss': 0.38446122,
#  'learning_rate': 0.0077880644}
# I0813 23:40:53.868315 140122632734592 model_lib_v2.py:708] {'Loss/classification_loss': 0.15340298,
#  'Loss/localization_loss': 0.07461502,
#  'Loss/regularization_loss': 0.15644321,
#  'Loss/total_loss': 0.38446122,
#  'learning_rate': 0.0077880644}
# INFO:tensorflow:Step 6200 per-step time 0.317s
# I0813 23:41:25.537077 140122632734592 model_lib_v2.py:707] Step 6200 per-step time 0.317s
# INFO:tensorflow:{'Loss/classification_loss': 0.16927162,
#  'Loss/localization_loss': 0.049357813,
#  'Loss/regularization_loss': 0.1563739,
#  'Loss/total_loss': 0.37500334,
#  'learning_rate': 0.007779749}
# I0813 23:41:25.537571 140122632734592 model_lib_v2.py:708] {'Loss/classification_loss': 0.16927162,
#  'Loss/localization_loss': 0.049357813,
#  'Loss/regularization_loss': 0.1563739,
#  'Loss/total_loss': 0.37500334,
#  'learning_rate': 0.007779749}
# INFO:tensorflow:Step 6300 per-step time 0.297s
# I0813 23:41:55.243293 140122632734592 model_lib_v2.py:707] Step 6300 per-step time 0.297s
# INFO:tensorflow:{'Loss/classification_loss': 0.10609438,
#  'Loss/localization_loss': 0.087296255,
#  'Loss/regularization_loss': 0.15631089,
#  'Loss/total_loss': 0.34970152,
#  'learning_rate': 0.007771279}
# I0813 23:41:55.243701 140122632734592 model_lib_v2.py:708] {'Loss/classification_loss': 0.10609438,
#  'Loss/localization_loss': 0.087296255,
#  'Loss/regularization_loss': 0.15631089,
#  'Loss/total_loss': 0.34970152,
#  'learning_rate': 0.007771279}
# INFO:tensorflow:Step 6400 per-step time 0.285s
# I0813 23:42:23.719430 140122632734592 model_lib_v2.py:707] Step 6400 per-step time 0.285s
# INFO:tensorflow:{'Loss/classification_loss': 0.16333297,
#  'Loss/localization_loss': 0.06304664,
#  'Loss/regularization_loss': 0.15625331,
#  'Loss/total_loss': 0.3826329,
#  'learning_rate': 0.0077626538}
# I0813 23:42:23.719954 140122632734592 model_lib_v2.py:708] {'Loss/classification_loss': 0.16333297,
#  'Loss/localization_loss': 0.06304664,
#  'Loss/regularization_loss': 0.15625331,
#  'Loss/total_loss': 0.3826329,
#  'learning_rate': 0.0077626538}
# INFO:tensorflow:Step 6500 per-step time 0.302s
# I0813 23:42:53.939624 140122632734592 model_lib_v2.py:707] Step 6500 per-step time 0.302s
# INFO:tensorflow:{'Loss/classification_loss': 0.25697216,
#  'Loss/localization_loss': 0.20571971,
#  'Loss/regularization_loss': 0.15617906,
#  'Loss/total_loss': 0.6188709,
#  'learning_rate': 0.007753874}
# I0813 23:42:53.939975 140122632734592 model_lib_v2.py:708] {'Loss/classification_loss': 0.25697216,
#  'Loss/localization_loss': 0.20571971,
#  'Loss/regularization_loss': 0.15617906,
#  'Loss/total_loss': 0.6188709,
#  'learning_rate': 0.007753874}
# INFO:tensorflow:Step 6600 per-step time 0.294s
# I0813 23:43:23.304557 140122632734592 model_lib_v2.py:707] Step 6600 per-step time 0.294s
# INFO:tensorflow:{'Loss/classification_loss': 0.16005751,
#  'Loss/localization_loss': 0.06801722,
#  'Loss/regularization_loss': 0.1561019,
#  'Loss/total_loss': 0.3841766,
#  'learning_rate': 0.00774494}
# I0813 23:43:23.305013 140122632734592 model_lib_v2.py:708] {'Loss/classification_loss': 0.16005751,
#  'Loss/localization_loss': 0.06801722,
#  'Loss/regularization_loss': 0.1561019,
#  'Loss/total_loss': 0.3841766,
#  'learning_rate': 0.00774494}
# INFO:tensorflow:Step 6700 per-step time 0.311s
# I0813 23:43:54.358252 140122632734592 model_lib_v2.py:707] Step 6700 per-step time 0.311s
# INFO:tensorflow:{'Loss/classification_loss': 0.18945307,
#  'Loss/localization_loss': 0.16016738,
#  'Loss/regularization_loss': 0.15602797,
#  'Loss/total_loss': 0.50564843,
#  'learning_rate': 0.0077358517}
# I0813 23:43:54.358676 140122632734592 model_lib_v2.py:708] {'Loss/classification_loss': 0.18945307,
#  'Loss/localization_loss': 0.16016738,
#  'Loss/regularization_loss': 0.15602797,
#  'Loss/total_loss': 0.50564843,
#  'learning_rate': 0.0077358517}
# INFO:tensorflow:Step 6800 per-step time 0.289s
# I0813 23:44:23.253895 140122632734592 model_lib_v2.py:707] Step 6800 per-step time 0.289s
# INFO:tensorflow:{'Loss/classification_loss': 0.1730557,
#  'Loss/localization_loss': 0.039004665,
#  'Loss/regularization_loss': 0.15594827,
#  'Loss/total_loss': 0.3680086,
#  'learning_rate': 0.00772661}
# I0813 23:44:23.255025 140122632734592 model_lib_v2.py:708] {'Loss/classification_loss': 0.1730557,
#  'Loss/localization_loss': 0.039004665,
#  'Loss/regularization_loss': 0.15594827,
#  'Loss/total_loss': 0.3680086,
#  'learning_rate': 0.00772661}
# INFO:tensorflow:Step 6900 per-step time 0.313s
# I0813 23:44:54.575803 140122632734592 model_lib_v2.py:707] Step 6900 per-step time 0.313s
# INFO:tensorflow:{'Loss/classification_loss': 0.113191,
#  'Loss/localization_loss': 0.04018201,
#  'Loss/regularization_loss': 0.15587008,
#  'Loss/total_loss': 0.30924308,
#  'learning_rate': 0.007717215}
# I0813 23:44:54.576150 140122632734592 model_lib_v2.py:708] {'Loss/classification_loss': 0.113191,
#  'Loss/localization_loss': 0.04018201,
#  'Loss/regularization_loss': 0.15587008,
#  'Loss/total_loss': 0.30924308,
#  'learning_rate': 0.007717215}
# INFO:tensorflow:Step 7000 per-step time 0.292s
# I0813 23:45:23.814293 140122632734592 model_lib_v2.py:707] Step 7000 per-step time 0.292s
# INFO:tensorflow:{'Loss/classification_loss': 0.1476397,
#  'Loss/localization_loss': 0.1239057,
#  'Loss/regularization_loss': 0.15578978,
#  'Loss/total_loss': 0.4273352,
#  'learning_rate': 0.0077076675}
# I0813 23:45:23.814690 140122632734592 model_lib_v2.py:708] {'Loss/classification_loss': 0.1476397,
#  'Loss/localization_loss': 0.1239057,
#  'Loss/regularization_loss': 0.15578978,
#  'Loss/total_loss': 0.4273352,
#  'learning_rate': 0.0077076675}
# INFO:tensorflow:Step 7100 per-step time 0.295s
# I0813 23:45:53.332766 140122632734592 model_lib_v2.py:707] Step 7100 per-step time 0.295s
# INFO:tensorflow:{'Loss/classification_loss': 0.11608305,
#  'Loss/localization_loss': 0.05359041,
#  'Loss/regularization_loss': 0.15571366,
#  'Loss/total_loss': 0.32538712,
#  'learning_rate': 0.0076979673}
# I0813 23:45:53.333154 140122632734592 model_lib_v2.py:708] {'Loss/classification_loss': 0.11608305,
#  'Loss/localization_loss': 0.05359041,
#  'Loss/regularization_loss': 0.15571366,
#  'Loss/total_loss': 0.32538712,
#  'learning_rate': 0.0076979673}
# INFO:tensorflow:Step 7200 per-step time 0.300s
# I0813 23:46:23.349423 140122632734592 model_lib_v2.py:707] Step 7200 per-step time 0.300s
# INFO:tensorflow:{'Loss/classification_loss': 0.13288713,
#  'Loss/localization_loss': 0.05943443,
#  'Loss/regularization_loss': 0.15563507,
#  'Loss/total_loss': 0.34795663,
#  'learning_rate': 0.0076881154}
# I0813 23:46:23.349881 140122632734592 model_lib_v2.py:708] {'Loss/classification_loss': 0.13288713,
#  'Loss/localization_loss': 0.05943443,
#  'Loss/regularization_loss': 0.15563507,
#  'Loss/total_loss': 0.34795663,
#  'learning_rate': 0.0076881154}
# INFO:tensorflow:Step 7300 per-step time 0.293s
# I0813 23:46:52.688956 140122632734592 model_lib_v2.py:707] Step 7300 per-step time 0.293s
# INFO:tensorflow:{'Loss/classification_loss': 0.14603259,
#  'Loss/localization_loss': 0.17202915,
#  'Loss/regularization_loss': 0.15555085,
#  'Loss/total_loss': 0.4736126,
#  'learning_rate': 0.0076781115}
# I0813 23:46:52.689379 140122632734592 model_lib_v2.py:708] {'Loss/classification_loss': 0.14603259,
#  'Loss/localization_loss': 0.17202915,
#  'Loss/regularization_loss': 0.15555085,
#  'Loss/total_loss': 0.4736126,
#  'learning_rate': 0.0076781115}
# INFO:tensorflow:Step 7400 per-step time 0.315s
# I0813 23:47:24.222180 140122632734592 model_lib_v2.py:707] Step 7400 per-step time 0.315s
# INFO:tensorflow:{'Loss/classification_loss': 0.08991226,
#  'Loss/localization_loss': 0.041025367,
#  'Loss/regularization_loss': 0.15548183,
#  'Loss/total_loss': 0.28641945,
#  'learning_rate': 0.007667957}
# I0813 23:47:24.222554 140122632734592 model_lib_v2.py:708] {'Loss/classification_loss': 0.08991226,
#  'Loss/localization_loss': 0.041025367,
#  'Loss/regularization_loss': 0.15548183,
#  'Loss/total_loss': 0.28641945,
#  'learning_rate': 0.007667957}
# INFO:tensorflow:Step 7500 per-step time 0.294s
# I0813 23:47:53.618078 140122632734592 model_lib_v2.py:707] Step 7500 per-step time 0.294s
# INFO:tensorflow:{'Loss/classification_loss': 0.10070985,
#  'Loss/localization_loss': 0.022486899,
#  'Loss/regularization_loss': 0.15540275,
#  'Loss/total_loss': 0.2785995,
#  'learning_rate': 0.007657651}
# I0813 23:47:53.618453 140122632734592 model_lib_v2.py:708] {'Loss/classification_loss': 0.10070985,
#  'Loss/localization_loss': 0.022486899,
#  'Loss/regularization_loss': 0.15540275,
#  'Loss/total_loss': 0.2785995,
#  'learning_rate': 0.007657651}
# INFO:tensorflow:Step 7600 per-step time 0.289s
# I0813 23:48:22.529789 140122632734592 model_lib_v2.py:707] Step 7600 per-step time 0.289s
# INFO:tensorflow:{'Loss/classification_loss': 0.11392083,
#  'Loss/localization_loss': 0.06512458,
#  'Loss/regularization_loss': 0.15532313,
#  'Loss/total_loss': 0.33436853,
#  'learning_rate': 0.007647195}
# I0813 23:48:22.530188 140122632734592 model_lib_v2.py:708] {'Loss/classification_loss': 0.11392083,
#  'Loss/localization_loss': 0.06512458,
#  'Loss/regularization_loss': 0.15532313,
#  'Loss/total_loss': 0.33436853,
#  'learning_rate': 0.007647195}
# INFO:tensorflow:Step 7700 per-step time 0.310s
# I0813 23:48:53.563731 140122632734592 model_lib_v2.py:707] Step 7700 per-step time 0.310s
# INFO:tensorflow:{'Loss/classification_loss': 0.15411039,
#  'Loss/localization_loss': 0.048875276,
#  'Loss/regularization_loss': 0.15526971,
#  'Loss/total_loss': 0.3582554,
#  'learning_rate': 0.007636589}
# I0813 23:48:53.564067 140122632734592 model_lib_v2.py:708] {'Loss/classification_loss': 0.15411039,
#  'Loss/localization_loss': 0.048875276,
#  'Loss/regularization_loss': 0.15526971,
#  'Loss/total_loss': 0.3582554,
#  'learning_rate': 0.007636589}
# INFO:tensorflow:Step 7800 per-step time 0.288s
# I0813 23:49:22.324808 140122632734592 model_lib_v2.py:707] Step 7800 per-step time 0.288s
# INFO:tensorflow:{'Loss/classification_loss': 0.16297822,
#  'Loss/localization_loss': 0.059937514,
#  'Loss/regularization_loss': 0.15519142,
#  'Loss/total_loss': 0.37810716,
#  'learning_rate': 0.0076258336}
# I0813 23:49:22.325174 140122632734592 model_lib_v2.py:708] {'Loss/classification_loss': 0.16297822,
#  'Loss/localization_loss': 0.059937514,
#  'Loss/regularization_loss': 0.15519142,
#  'Loss/total_loss': 0.37810716,
#  'learning_rate': 0.0076258336}
# INFO:tensorflow:Step 7900 per-step time 0.306s
# I0813 23:49:52.928439 140122632734592 model_lib_v2.py:707] Step 7900 per-step time 0.306s
# INFO:tensorflow:{'Loss/classification_loss': 0.13009669,
#  'Loss/localization_loss': 0.08516115,
#  'Loss/regularization_loss': 0.15512131,
#  'Loss/total_loss': 0.37037915,
#  'learning_rate': 0.0076149288}
# I0813 23:49:52.928937 140122632734592 model_lib_v2.py:708] {'Loss/classification_loss': 0.13009669,
#  'Loss/localization_loss': 0.08516115,
#  'Loss/regularization_loss': 0.15512131,
#  'Loss/total_loss': 0.37037915,
#  'learning_rate': 0.0076149288}
# INFO:tensorflow:Step 8000 per-step time 0.309s
# I0813 23:50:23.807063 140122632734592 model_lib_v2.py:707] Step 8000 per-step time 0.309s
# INFO:tensorflow:{'Loss/classification_loss': 0.10964859,
#  'Loss/localization_loss': 0.052181024,
#  'Loss/regularization_loss': 0.15504378,
#  'Loss/total_loss': 0.3168734,
#  'learning_rate': 0.0076038754}
# I0813 23:50:23.807524 140122632734592 model_lib_v2.py:708] {'Loss/classification_loss': 0.10964859,
#  'Loss/localization_loss': 0.052181024,
#  'Loss/regularization_loss': 0.15504378,
#  'Loss/total_loss': 0.3168734,
#  'learning_rate': 0.0076038754}
# INFO:tensorflow:Step 8100 per-step time 0.308s
# I0813 23:50:54.632287 140122632734592 model_lib_v2.py:707] Step 8100 per-step time 0.308s
# INFO:tensorflow:{'Loss/classification_loss': 0.20644888,
#  'Loss/localization_loss': 0.09247646,
#  'Loss/regularization_loss': 0.1549648,
#  'Loss/total_loss': 0.45389014,
#  'learning_rate': 0.007592675}
# I0813 23:50:54.632804 140122632734592 model_lib_v2.py:708] {'Loss/classification_loss': 0.20644888,
#  'Loss/localization_loss': 0.09247646,
#  'Loss/regularization_loss': 0.1549648,
#  'Loss/total_loss': 0.45389014,
#  'learning_rate': 0.007592675}
# INFO:tensorflow:Step 8200 per-step time 0.294s
# I0813 23:51:24.059438 140122632734592 model_lib_v2.py:707] Step 8200 per-step time 0.294s
# INFO:tensorflow:{'Loss/classification_loss': 0.13360316,
#  'Loss/localization_loss': 0.08475959,
#  'Loss/regularization_loss': 0.15488788,
#  'Loss/total_loss': 0.37325063,
#  'learning_rate': 0.0075813257}
# I0813 23:51:24.059844 140122632734592 model_lib_v2.py:708] {'Loss/classification_loss': 0.13360316,
#  'Loss/localization_loss': 0.08475959,
#  'Loss/regularization_loss': 0.15488788,
#  'Loss/total_loss': 0.37325063,
#  'learning_rate': 0.0075813257}
# INFO:tensorflow:Step 8300 per-step time 0.272s
# I0813 23:51:51.262770 140122632734592 model_lib_v2.py:707] Step 8300 per-step time 0.272s
# INFO:tensorflow:{'Loss/classification_loss': 0.20168057,
#  'Loss/localization_loss': 0.104771264,
#  'Loss/regularization_loss': 0.1548046,
#  'Loss/total_loss': 0.46125644,
#  'learning_rate': 0.0075698295}
# I0813 23:51:51.263124 140122632734592 model_lib_v2.py:708] {'Loss/classification_loss': 0.20168057,
#  'Loss/localization_loss': 0.104771264,
#  'Loss/regularization_loss': 0.1548046,
#  'Loss/total_loss': 0.46125644,
#  'learning_rate': 0.0075698295}
# INFO:tensorflow:Step 8400 per-step time 0.310s
# I0813 23:52:22.218883 140122632734592 model_lib_v2.py:707] Step 8400 per-step time 0.310s
# INFO:tensorflow:{'Loss/classification_loss': 0.14744852,
#  'Loss/localization_loss': 0.055068325,
#  'Loss/regularization_loss': 0.15472348,
#  'Loss/total_loss': 0.35724032,
#  'learning_rate': 0.007558187}
# I0813 23:52:22.219298 140122632734592 model_lib_v2.py:708] {'Loss/classification_loss': 0.14744852,
#  'Loss/localization_loss': 0.055068325,
#  'Loss/regularization_loss': 0.15472348,
#  'Loss/total_loss': 0.35724032,
#  'learning_rate': 0.007558187}
# INFO:tensorflow:Step 8500 per-step time 0.303s
# I0813 23:52:52.539268 140122632734592 model_lib_v2.py:707] Step 8500 per-step time 0.303s
# INFO:tensorflow:{'Loss/classification_loss': 0.4168059,
#  'Loss/localization_loss': 0.29226133,
#  'Loss/regularization_loss': 0.15464279,
#  'Loss/total_loss': 0.86371005,
#  'learning_rate': 0.0075463974}
# I0813 23:52:52.539673 140122632734592 model_lib_v2.py:708] {'Loss/classification_loss': 0.4168059,
#  'Loss/localization_loss': 0.29226133,
#  'Loss/regularization_loss': 0.15464279,
#  'Loss/total_loss': 0.86371005,
#  'learning_rate': 0.0075463974}
# INFO:tensorflow:Step 8600 per-step time 0.325s
# I0813 23:53:25.081839 140122632734592 model_lib_v2.py:707] Step 8600 per-step time 0.325s
# INFO:tensorflow:{'Loss/classification_loss': 0.14632656,
#  'Loss/localization_loss': 0.042530313,
#  'Loss/regularization_loss': 0.15457775,
#  'Loss/total_loss': 0.34343463,
#  'learning_rate': 0.0075344625}
# I0813 23:53:25.082236 140122632734592 model_lib_v2.py:708] {'Loss/classification_loss': 0.14632656,
#  'Loss/localization_loss': 0.042530313,
#  'Loss/regularization_loss': 0.15457775,
#  'Loss/total_loss': 0.34343463,
#  'learning_rate': 0.0075344625}
# INFO:tensorflow:Step 8700 per-step time 0.297s
# I0813 23:53:54.756272 140122632734592 model_lib_v2.py:707] Step 8700 per-step time 0.297s
# INFO:tensorflow:{'Loss/classification_loss': 0.1402932,
#  'Loss/localization_loss': 0.059583604,
#  'Loss/regularization_loss': 0.1544964,
#  'Loss/total_loss': 0.35437322,
#  'learning_rate': 0.007522383}
# I0813 23:53:54.756651 140122632734592 model_lib_v2.py:708] {'Loss/classification_loss': 0.1402932,
#  'Loss/localization_loss': 0.059583604,
#  'Loss/regularization_loss': 0.1544964,
#  'Loss/total_loss': 0.35437322,
#  'learning_rate': 0.007522383}
# INFO:tensorflow:Step 8800 per-step time 0.299s
# I0813 23:54:24.642106 140122632734592 model_lib_v2.py:707] Step 8800 per-step time 0.299s
# INFO:tensorflow:{'Loss/classification_loss': 0.19257966,
#  'Loss/localization_loss': 0.046177037,
#  'Loss/regularization_loss': 0.15442215,
#  'Loss/total_loss': 0.39317882,
#  'learning_rate': 0.0075101573}
# I0813 23:54:24.642512 140122632734592 model_lib_v2.py:708] {'Loss/classification_loss': 0.19257966,
#  'Loss/localization_loss': 0.046177037,
#  'Loss/regularization_loss': 0.15442215,
#  'Loss/total_loss': 0.39317882,
#  'learning_rate': 0.0075101573}
# INFO:tensorflow:Step 8900 per-step time 0.309s
# I0813 23:54:55.541419 140122632734592 model_lib_v2.py:707] Step 8900 per-step time 0.309s
# INFO:tensorflow:{'Loss/classification_loss': 0.1871822,
#  'Loss/localization_loss': 0.13882197,
#  'Loss/regularization_loss': 0.15435138,
#  'Loss/total_loss': 0.48035556,
#  'learning_rate': 0.0074977884}
# I0813 23:54:55.541765 140122632734592 model_lib_v2.py:708] {'Loss/classification_loss': 0.1871822,
#  'Loss/localization_loss': 0.13882197,
#  'Loss/regularization_loss': 0.15435138,
#  'Loss/total_loss': 0.48035556,
#  'learning_rate': 0.0074977884}
# INFO:tensorflow:Step 9000 per-step time 0.276s
# I0813 23:55:23.107875 140122632734592 model_lib_v2.py:707] Step 9000 per-step time 0.276s
# INFO:tensorflow:{'Loss/classification_loss': 0.10424098,
#  'Loss/localization_loss': 0.04630198,
#  'Loss/regularization_loss': 0.1542863,
#  'Loss/total_loss': 0.30482924,
#  'learning_rate': 0.007485275}
# I0813 23:55:23.108272 140122632734592 model_lib_v2.py:708] {'Loss/classification_loss': 0.10424098,
#  'Loss/localization_loss': 0.04630198,
#  'Loss/regularization_loss': 0.1542863,
#  'Loss/total_loss': 0.30482924,
#  'learning_rate': 0.007485275}
# INFO:tensorflow:Step 9100 per-step time 0.327s
# I0813 23:55:55.851697 140122632734592 model_lib_v2.py:707] Step 9100 per-step time 0.327s
# INFO:tensorflow:{'Loss/classification_loss': 0.1320746,
#  'Loss/localization_loss': 0.033986725,
#  'Loss/regularization_loss': 0.154209,
#  'Loss/total_loss': 0.3202703,
#  'learning_rate': 0.007472619}
# I0813 23:55:55.852086 140122632734592 model_lib_v2.py:708] {'Loss/classification_loss': 0.1320746,
#  'Loss/localization_loss': 0.033986725,
#  'Loss/regularization_loss': 0.154209,
#  'Loss/total_loss': 0.3202703,
#  'learning_rate': 0.007472619}
# INFO:tensorflow:Step 9200 per-step time 0.294s
# I0813 23:56:25.226664 140122632734592 model_lib_v2.py:707] Step 9200 per-step time 0.294s
# INFO:tensorflow:{'Loss/classification_loss': 0.14302076,
#  'Loss/localization_loss': 0.09776366,
#  'Loss/regularization_loss': 0.15413113,
#  'Loss/total_loss': 0.39491555,
#  'learning_rate': 0.0074598202}
# I0813 23:56:25.227057 140122632734592 model_lib_v2.py:708] {'Loss/classification_loss': 0.14302076,
#  'Loss/localization_loss': 0.09776366,
#  'Loss/regularization_loss': 0.15413113,
#  'Loss/total_loss': 0.39491555,
#  'learning_rate': 0.0074598202}
# INFO:tensorflow:Step 9300 per-step time 0.324s
# I0813 23:56:57.674316 140122632734592 model_lib_v2.py:707] Step 9300 per-step time 0.324s
# INFO:tensorflow:{'Loss/classification_loss': 0.13697045,
#  'Loss/localization_loss': 0.16703394,
#  'Loss/regularization_loss': 0.15405647,
#  'Loss/total_loss': 0.45806086,
#  'learning_rate': 0.0074468786}
# I0813 23:56:57.674690 140122632734592 model_lib_v2.py:708] {'Loss/classification_loss': 0.13697045,
#  'Loss/localization_loss': 0.16703394,
#  'Loss/regularization_loss': 0.15405647,
#  'Loss/total_loss': 0.45806086,
#  'learning_rate': 0.0074468786}
# INFO:tensorflow:Step 9400 per-step time 0.311s
# I0813 23:57:28.791814 140122632734592 model_lib_v2.py:707] Step 9400 per-step time 0.311s
# INFO:tensorflow:{'Loss/classification_loss': 0.11132627,
#  'Loss/localization_loss': 0.050610542,
#  'Loss/regularization_loss': 0.15398097,
#  'Loss/total_loss': 0.3159178,
#  'learning_rate': 0.0074337954}
# I0813 23:57:28.792162 140122632734592 model_lib_v2.py:708] {'Loss/classification_loss': 0.11132627,
#  'Loss/localization_loss': 0.050610542,
#  'Loss/regularization_loss': 0.15398097,
#  'Loss/total_loss': 0.3159178,
#  'learning_rate': 0.0074337954}
# INFO:tensorflow:Step 9500 per-step time 0.305s
# I0813 23:57:59.270731 140122632734592 model_lib_v2.py:707] Step 9500 per-step time 0.305s
# INFO:tensorflow:{'Loss/classification_loss': 0.10132939,
#  'Loss/localization_loss': 0.06361134,
#  'Loss/regularization_loss': 0.15390429,
#  'Loss/total_loss': 0.31884503,
#  'learning_rate': 0.007420571}
# I0813 23:57:59.271106 140122632734592 model_lib_v2.py:708] {'Loss/classification_loss': 0.10132939,
#  'Loss/localization_loss': 0.06361134,
#  'Loss/regularization_loss': 0.15390429,
#  'Loss/total_loss': 0.31884503,
#  'learning_rate': 0.007420571}
# INFO:tensorflow:Step 9600 per-step time 0.303s
# I0813 23:58:29.569008 140122632734592 model_lib_v2.py:707] Step 9600 per-step time 0.303s
# INFO:tensorflow:{'Loss/classification_loss': 0.124910235,
#  'Loss/localization_loss': 0.05161468,
#  'Loss/regularization_loss': 0.15382722,
#  'Loss/total_loss': 0.33035213,
#  'learning_rate': 0.007407207}
# I0813 23:58:29.569439 140122632734592 model_lib_v2.py:708] {'Loss/classification_loss': 0.124910235,
#  'Loss/localization_loss': 0.05161468,
#  'Loss/regularization_loss': 0.15382722,
#  'Loss/total_loss': 0.33035213,
#  'learning_rate': 0.007407207}
# INFO:tensorflow:Step 9700 per-step time 0.294s
# I0813 23:58:58.940975 140122632734592 model_lib_v2.py:707] Step 9700 per-step time 0.294s
# INFO:tensorflow:{'Loss/classification_loss': 0.23913579,
#  'Loss/localization_loss': 0.13042976,
#  'Loss/regularization_loss': 0.15377496,
#  'Loss/total_loss': 0.5233405,
#  'learning_rate': 0.007393702}
# I0813 23:58:58.941457 140122632734592 model_lib_v2.py:708] {'Loss/classification_loss': 0.23913579,
#  'Loss/localization_loss': 0.13042976,
#  'Loss/regularization_loss': 0.15377496,
#  'Loss/total_loss': 0.5233405,
#  'learning_rate': 0.007393702}
# INFO:tensorflow:Step 9800 per-step time 0.317s
# I0813 23:59:30.662452 140122632734592 model_lib_v2.py:707] Step 9800 per-step time 0.317s
# INFO:tensorflow:{'Loss/classification_loss': 0.14915311,
#  'Loss/localization_loss': 0.052455842,
#  'Loss/regularization_loss': 0.15370823,
#  'Loss/total_loss': 0.35531718,
#  'learning_rate': 0.0073800576}
# I0813 23:59:30.662828 140122632734592 model_lib_v2.py:708] {'Loss/classification_loss': 0.14915311,
#  'Loss/localization_loss': 0.052455842,
#  'Loss/regularization_loss': 0.15370823,
#  'Loss/total_loss': 0.35531718,
#  'learning_rate': 0.0073800576}
# INFO:tensorflow:Step 9900 per-step time 0.294s
# I0814 00:00:00.076752 140122632734592 model_lib_v2.py:707] Step 9900 per-step time 0.294s
# INFO:tensorflow:{'Loss/classification_loss': 0.20112427,
#  'Loss/localization_loss': 0.17167886,
#  'Loss/regularization_loss': 0.15363038,
#  'Loss/total_loss': 0.52643347,
#  'learning_rate': 0.007366274}
# I0814 00:00:00.077136 140122632734592 model_lib_v2.py:708] {'Loss/classification_loss': 0.20112427,
#  'Loss/localization_loss': 0.17167886,
#  'Loss/regularization_loss': 0.15363038,
#  'Loss/total_loss': 0.52643347,
#  'learning_rate': 0.007366274}
# INFO:tensorflow:Step 10000 per-step time 0.318s
# I0814 00:00:31.892983 140122632734592 model_lib_v2.py:707] Step 10000 per-step time 0.318s
# INFO:tensorflow:{'Loss/classification_loss': 0.10856247,
#  'Loss/localization_loss': 0.040113226,
#  'Loss/regularization_loss': 0.15356159,
#  'Loss/total_loss': 0.30223727,
#  'learning_rate': 0.007352353}
# I0814 00:00:31.893513 140122632734592 model_lib_v2.py:708] {'Loss/classification_loss': 0.10856247,
#  'Loss/localization_loss': 0.040113226,
#  'Loss/regularization_loss': 0.15356159,
#  'Loss/total_loss': 0.30223727,
#  'learning_rate': 0.007352353}
# INFO:tensorflow:Step 10100 per-step time 0.309s
# I0814 00:01:02.836859 140122632734592 model_lib_v2.py:707] Step 10100 per-step time 0.309s
# INFO:tensorflow:{'Loss/classification_loss': 0.12911111,
#  'Loss/localization_loss': 0.063209176,
#  'Loss/regularization_loss': 0.15349242,
#  'Loss/total_loss': 0.3458127,
#  'learning_rate': 0.0073382934}
# I0814 00:01:02.837221 140122632734592 model_lib_v2.py:708] {'Loss/classification_loss': 0.12911111,
#  'Loss/localization_loss': 0.063209176,
#  'Loss/regularization_loss': 0.15349242,
#  'Loss/total_loss': 0.3458127,
#  'learning_rate': 0.0073382934}
# INFO:tensorflow:Step 10200 per-step time 0.306s
# I0814 00:01:33.425879 140122632734592 model_lib_v2.py:707] Step 10200 per-step time 0.306s
# INFO:tensorflow:{'Loss/classification_loss': 0.14659813,
#  'Loss/localization_loss': 0.06603047,
#  'Loss/regularization_loss': 0.15341516,
#  'Loss/total_loss': 0.36604375,
#  'learning_rate': 0.007324097}
# I0814 00:01:33.426239 140122632734592 model_lib_v2.py:708] {'Loss/classification_loss': 0.14659813,
#  'Loss/localization_loss': 0.06603047,
#  'Loss/regularization_loss': 0.15341516,
#  'Loss/total_loss': 0.36604375,
#  'learning_rate': 0.007324097}
# INFO:tensorflow:Step 10300 per-step time 0.294s
# I0814 00:02:02.868715 140122632734592 model_lib_v2.py:707] Step 10300 per-step time 0.294s
# INFO:tensorflow:{'Loss/classification_loss': 0.36577863,
#  'Loss/localization_loss': 0.12919864,
#  'Loss/regularization_loss': 0.15333657,
#  'Loss/total_loss': 0.6483138,
#  'learning_rate': 0.007309763}
# I0814 00:02:02.869085 140122632734592 model_lib_v2.py:708] {'Loss/classification_loss': 0.36577863,
#  'Loss/localization_loss': 0.12919864,
#  'Loss/regularization_loss': 0.15333657,
#  'Loss/total_loss': 0.6483138,
#  'learning_rate': 0.007309763}
# INFO:tensorflow:Step 10400 per-step time 0.291s
# I0814 00:02:31.950207 140122632734592 model_lib_v2.py:707] Step 10400 per-step time 0.291s
# INFO:tensorflow:{'Loss/classification_loss': 0.11639756,
#  'Loss/localization_loss': 0.05197685,
#  'Loss/regularization_loss': 0.153267,
#  'Loss/total_loss': 0.3216414,
#  'learning_rate': 0.007295294}
# I0814 00:02:31.950612 140122632734592 model_lib_v2.py:708] {'Loss/classification_loss': 0.11639756,
#  'Loss/localization_loss': 0.05197685,
#  'Loss/regularization_loss': 0.153267,
#  'Loss/total_loss': 0.3216414,
#  'learning_rate': 0.007295294}
# INFO:tensorflow:Step 10500 per-step time 0.314s
# I0814 00:03:03.300691 140122632734592 model_lib_v2.py:707] Step 10500 per-step time 0.314s
# INFO:tensorflow:{'Loss/classification_loss': 0.105851494,
#  'Loss/localization_loss': 0.06790181,
#  'Loss/regularization_loss': 0.15319625,
#  'Loss/total_loss': 0.32694954,
#  'learning_rate': 0.0072806897}
# I0814 00:03:03.301099 140122632734592 model_lib_v2.py:708] {'Loss/classification_loss': 0.105851494,
#  'Loss/localization_loss': 0.06790181,
#  'Loss/regularization_loss': 0.15319625,
#  'Loss/total_loss': 0.32694954,
#  'learning_rate': 0.0072806897}
# INFO:tensorflow:Step 10600 per-step time 0.312s
# I0814 00:03:34.539288 140122632734592 model_lib_v2.py:707] Step 10600 per-step time 0.312s
# INFO:tensorflow:{'Loss/classification_loss': 0.14329387,
#  'Loss/localization_loss': 0.038546626,
#  'Loss/regularization_loss': 0.15312709,
#  'Loss/total_loss': 0.33496758,
#  'learning_rate': 0.0072659496}
# I0814 00:03:34.539659 140122632734592 model_lib_v2.py:708] {'Loss/classification_loss': 0.14329387,
#  'Loss/localization_loss': 0.038546626,
#  'Loss/regularization_loss': 0.15312709,
#  'Loss/total_loss': 0.33496758,
#  'learning_rate': 0.0072659496}
# INFO:tensorflow:Step 10700 per-step time 0.309s
# I0814 00:04:05.461920 140122632734592 model_lib_v2.py:707] Step 10700 per-step time 0.309s
# INFO:tensorflow:{'Loss/classification_loss': 0.12522694,
#  'Loss/localization_loss': 0.09343178,
#  'Loss/regularization_loss': 0.1530519,
#  'Loss/total_loss': 0.3717106,
#  'learning_rate': 0.007251076}
# I0814 00:04:05.462327 140122632734592 model_lib_v2.py:708] {'Loss/classification_loss': 0.12522694,
#  'Loss/localization_loss': 0.09343178,
#  'Loss/regularization_loss': 0.1530519,
#  'Loss/total_loss': 0.3717106,
#  'learning_rate': 0.007251076}
# INFO:tensorflow:Step 10800 per-step time 0.300s
# I0814 00:04:35.477665 140122632734592 model_lib_v2.py:707] Step 10800 per-step time 0.300s
# INFO:tensorflow:{'Loss/classification_loss': 0.12102951,
#  'Loss/localization_loss': 0.09763721,
#  'Loss/regularization_loss': 0.1529805,
#  'Loss/total_loss': 0.37164724,
#  'learning_rate': 0.007236068}
# I0814 00:04:35.478042 140122632734592 model_lib_v2.py:708] {'Loss/classification_loss': 0.12102951,
#  'Loss/localization_loss': 0.09763721,
#  'Loss/regularization_loss': 0.1529805,
#  'Loss/total_loss': 0.37164724,
#  'learning_rate': 0.007236068}
# INFO:tensorflow:Step 10900 per-step time 0.313s
# I0814 00:05:06.750844 140122632734592 model_lib_v2.py:707] Step 10900 per-step time 0.313s
# INFO:tensorflow:{'Loss/classification_loss': 0.103546366,
#  'Loss/localization_loss': 0.052195873,
#  'Loss/regularization_loss': 0.15290785,
#  'Loss/total_loss': 0.30865008,
#  'learning_rate': 0.0072209276}
# I0814 00:05:06.751234 140122632734592 model_lib_v2.py:708] {'Loss/classification_loss': 0.103546366,
#  'Loss/localization_loss': 0.052195873,
#  'Loss/regularization_loss': 0.15290785,
#  'Loss/total_loss': 0.30865008,
#  'learning_rate': 0.0072209276}
# INFO:tensorflow:Step 11000 per-step time 0.305s
# I0814 00:05:37.263544 140122632734592 model_lib_v2.py:707] Step 11000 per-step time 0.305s
# INFO:tensorflow:{'Loss/classification_loss': 0.45659322,
#  'Loss/localization_loss': 0.31511027,
#  'Loss/regularization_loss': 0.15283287,
#  'Loss/total_loss': 0.92453635,
#  'learning_rate': 0.007205655}
# I0814 00:05:37.264273 140122632734592 model_lib_v2.py:708] {'Loss/classification_loss': 0.45659322,
#  'Loss/localization_loss': 0.31511027,
#  'Loss/regularization_loss': 0.15283287,
#  'Loss/total_loss': 0.92453635,
#  'learning_rate': 0.007205655}
# INFO:tensorflow:Step 11100 per-step time 0.322s
# I0814 00:06:09.436475 140122632734592 model_lib_v2.py:707] Step 11100 per-step time 0.322s
# INFO:tensorflow:{'Loss/classification_loss': 0.18215574,
#  'Loss/localization_loss': 0.05851942,
#  'Loss/regularization_loss': 0.15276171,
#  'Loss/total_loss': 0.39343688,
#  'learning_rate': 0.00719025}
# I0814 00:06:09.436914 140122632734592 model_lib_v2.py:708] {'Loss/classification_loss': 0.18215574,
#  'Loss/localization_loss': 0.05851942,
#  'Loss/regularization_loss': 0.15276171,
#  'Loss/total_loss': 0.39343688,
#  'learning_rate': 0.00719025}
# INFO:tensorflow:Step 11200 per-step time 0.291s
# I0814 00:06:38.481173 140122632734592 model_lib_v2.py:707] Step 11200 per-step time 0.291s
# INFO:tensorflow:{'Loss/classification_loss': 0.11889227,
#  'Loss/localization_loss': 0.11193771,
#  'Loss/regularization_loss': 0.15268748,
#  'Loss/total_loss': 0.38351744,
#  'learning_rate': 0.0071747145}
# I0814 00:06:38.481604 140122632734592 model_lib_v2.py:708] {'Loss/classification_loss': 0.11889227,
#  'Loss/localization_loss': 0.11193771,
#  'Loss/regularization_loss': 0.15268748,
#  'Loss/total_loss': 0.38351744,
#  'learning_rate': 0.0071747145}
# INFO:tensorflow:Step 11300 per-step time 0.298s
# I0814 00:07:08.280867 140122632734592 model_lib_v2.py:707] Step 11300 per-step time 0.298s
# INFO:tensorflow:{'Loss/classification_loss': 0.12993588,
#  'Loss/localization_loss': 0.042831976,
#  'Loss/regularization_loss': 0.15261436,
#  'Loss/total_loss': 0.3253822,
#  'learning_rate': 0.0071590478}
# I0814 00:07:08.281214 140122632734592 model_lib_v2.py:708] {'Loss/classification_loss': 0.12993588,
#  'Loss/localization_loss': 0.042831976,
#  'Loss/regularization_loss': 0.15261436,
#  'Loss/total_loss': 0.3253822,
#  'learning_rate': 0.0071590478}
# INFO:tensorflow:Step 11400 per-step time 0.306s
# I0814 00:07:38.930079 140122632734592 model_lib_v2.py:707] Step 11400 per-step time 0.306s
# INFO:tensorflow:{'Loss/classification_loss': 0.096298695,
#  'Loss/localization_loss': 0.047349185,
#  'Loss/regularization_loss': 0.15254001,
#  'Loss/total_loss': 0.29618788,
#  'learning_rate': 0.0071432516}
# I0814 00:07:38.930456 140122632734592 model_lib_v2.py:708] {'Loss/classification_loss': 0.096298695,
#  'Loss/localization_loss': 0.047349185,
#  'Loss/regularization_loss': 0.15254001,
#  'Loss/total_loss': 0.29618788,
#  'learning_rate': 0.0071432516}
# INFO:tensorflow:Step 11500 per-step time 0.298s
# I0814 00:08:08.732933 140122632734592 model_lib_v2.py:707] Step 11500 per-step time 0.298s
# INFO:tensorflow:{'Loss/classification_loss': 0.14163528,
#  'Loss/localization_loss': 0.07942034,
#  'Loss/regularization_loss': 0.15246353,
#  'Loss/total_loss': 0.37351915,
#  'learning_rate': 0.0071273264}
# I0814 00:08:08.733351 140122632734592 model_lib_v2.py:708] {'Loss/classification_loss': 0.14163528,
#  'Loss/localization_loss': 0.07942034,
#  'Loss/regularization_loss': 0.15246353,
#  'Loss/total_loss': 0.37351915,
#  'learning_rate': 0.0071273264}
# INFO:tensorflow:Step 11600 per-step time 0.310s
# I0814 00:08:39.741719 140122632734592 model_lib_v2.py:707] Step 11600 per-step time 0.310s
# ...
# I0814 00:48:51.299337 140122632734592 model_lib_v2.py:708] {'Loss/classification_loss': 0.09673408,
#  'Loss/localization_loss': 0.029575154,
#  'Loss/regularization_loss': 0.1471809,
#  'Loss/total_loss': 0.27349013,
#  'learning_rate': 0.005501068}
# INFO:tensorflow:Step 19600 per-step time 0.281s
# I0814 00:49:19.356442 140122632734592 model_lib_v2.py:707] Step 19600 per-step time 0.281s
# INFO:tensorflow:{'Loss/classification_loss': 0.098007426,
#  'Loss/localization_loss': 0.03138602,
#  'Loss/regularization_loss': 0.14712074,
#  'Loss/total_loss': 0.27651417,
#  'learning_rate': 0.005477266}
# I0814 00:49:19.356778 140122632734592 model_lib_v2.py:708] {'Loss/classification_loss': 0.098007426,
#  'Loss/localization_loss': 0.03138602,
#  'Loss/regularization_loss': 0.14712074,
#  'Loss/total_loss': 0.27651417,
#  'learning_rate': 0.005477266}
# INFO:tensorflow:Step 19700 per-step time 0.304s
# I0814 00:49:49.776257 140122632734592 model_lib_v2.py:707] Step 19700 per-step time 0.304s
# INFO:tensorflow:{'Loss/classification_loss': 0.04494281,
#  'Loss/localization_loss': 0.015134815,
#  'Loss/regularization_loss': 0.14706464,
#  'Loss/total_loss': 0.20714226,
#  'learning_rate': 0.005453403}
# I0814 00:49:49.776678 140122632734592 model_lib_v2.py:708] {'Loss/classification_loss': 0.04494281,
#  'Loss/localization_loss': 0.015134815,
#  'Loss/regularization_loss': 0.14706464,
#  'Loss/total_loss': 0.20714226,
#  'learning_rate': 0.005453403}
# INFO:tensorflow:Step 19800 per-step time 0.314s
# I0814 00:50:21.152118 140122632734592 model_lib_v2.py:707] Step 19800 per-step time 0.314s
# INFO:tensorflow:{'Loss/classification_loss': 0.12941499,
#  'Loss/localization_loss': 0.042317905,
#  'Loss/regularization_loss': 0.14700754,
#  'Loss/total_loss': 0.31874043,
#  'learning_rate': 0.00542948}
# I0814 00:50:21.152515 140122632734592 model_lib_v2.py:708] {'Loss/classification_loss': 0.12941499,
#  'Loss/localization_loss': 0.042317905,
#  'Loss/regularization_loss': 0.14700754,
#  'Loss/total_loss': 0.31874043,
#  'learning_rate': 0.00542948}
# INFO:tensorflow:Step 19900 per-step time 0.283s
# I0814 00:50:49.450488 140122632734592 model_lib_v2.py:707] Step 19900 per-step time 0.283s
# INFO:tensorflow:{'Loss/classification_loss': 0.097715,
#  'Loss/localization_loss': 0.044734452,
#  'Loss/regularization_loss': 0.14695032,
#  'Loss/total_loss': 0.28939977,
#  'learning_rate': 0.0054054996}
# I0814 00:50:49.450873 140122632734592 model_lib_v2.py:708] {'Loss/classification_loss': 0.097715,
#  'Loss/localization_loss': 0.044734452,
#  'Loss/regularization_loss': 0.14695032,
#  'Loss/total_loss': 0.28939977,
#  'learning_rate': 0.0054054996}
# INFO:tensorflow:Step 20000 per-step time 0.309s
# I0814 00:51:20.375908 140122632734592 model_lib_v2.py:707] Step 20000 per-step time 0.309s
# INFO:tensorflow:{'Loss/classification_loss': 0.11078118,
#  'Loss/localization_loss': 0.09265895,
#  'Loss/regularization_loss': 0.14689146,
#  'Loss/total_loss': 0.3503316,
#  'learning_rate': 0.0053814603}
# I0814 00:51:20.376269 140122632734592 model_lib_v2.py:708] {'Loss/classification_loss': 0.11078118,
#  'Loss/localization_loss': 0.09265895,
#  'Loss/regularization_loss': 0.14689146,
#  'Loss/total_loss': 0.3503316,
#  'learning_rate': 0.0053814603}
# INFO:tensorflow:Step 20100 per-step time 0.296s
# I0814 00:51:49.985416 140122632734592 model_lib_v2.py:707] Step 20100 per-step time 0.296s
# INFO:tensorflow:{'Loss/classification_loss': 0.09476604,
#  'Loss/localization_loss': 0.043312475,
#  'Loss/regularization_loss': 0.14683504,
#  'Loss/total_loss': 0.28491354,
#  'learning_rate': 0.0053573647}
# I0814 00:51:49.985818 140122632734592 model_lib_v2.py:708] {'Loss/classification_loss': 0.09476604,
#  'Loss/localization_loss': 0.043312475,
#  'Loss/regularization_loss': 0.14683504,
#  'Loss/total_loss': 0.28491354,
#  'learning_rate': 0.0053573647}
# INFO:tensorflow:Step 20200 per-step time 0.309s
# I0814 00:52:20.891712 140122632734592 model_lib_v2.py:707] Step 20200 per-step time 0.309s
# INFO:tensorflow:{'Loss/classification_loss': 0.14351276,
#  'Loss/localization_loss': 0.11508367,
#  'Loss/regularization_loss': 0.14677861,
#  'Loss/total_loss': 0.40537503,
#  'learning_rate': 0.0053332127}
# I0814 00:52:20.892183 140122632734592 model_lib_v2.py:708] {'Loss/classification_loss': 0.14351276,
#  'Loss/localization_loss': 0.11508367,
#  'Loss/regularization_loss': 0.14677861,
#  'Loss/total_loss': 0.40537503,
#  'learning_rate': 0.0053332127}
# INFO:tensorflow:Step 20300 per-step time 0.298s
# I0814 00:52:50.645979 140122632734592 model_lib_v2.py:707] Step 20300 per-step time 0.298s
# INFO:tensorflow:{'Loss/classification_loss': 0.10245578,
#  'Loss/localization_loss': 0.09313937,
#  'Loss/regularization_loss': 0.14672272,
#  'Loss/total_loss': 0.34231788,
#  'learning_rate': 0.0053090067}
# I0814 00:52:50.646310 140122632734592 model_lib_v2.py:708] {'Loss/classification_loss': 0.10245578,
#  'Loss/localization_loss': 0.09313937,
#  'Loss/regularization_loss': 0.14672272,
#  'Loss/total_loss': 0.34231788,
#  'learning_rate': 0.0053090067}
# INFO:tensorflow:Step 20400 per-step time 0.299s
# I0814 00:53:20.577832 140122632734592 model_lib_v2.py:707] Step 20400 per-step time 0.299s
# INFO:tensorflow:{'Loss/classification_loss': 0.14800641,
#  'Loss/localization_loss': 0.078135185,
#  'Loss/regularization_loss': 0.14666513,
#  'Loss/total_loss': 0.37280673,
#  'learning_rate': 0.0052847466}
# I0814 00:53:20.578185 140122632734592 model_lib_v2.py:708] {'Loss/classification_loss': 0.14800641,
#  'Loss/localization_loss': 0.078135185,
#  'Loss/regularization_loss': 0.14666513,
#  'Loss/total_loss': 0.37280673,
#  'learning_rate': 0.0052847466}
# INFO:tensorflow:Step 20500 per-step time 0.301s
# I0814 00:53:50.736455 140122632734592 model_lib_v2.py:707] Step 20500 per-step time 0.301s
# INFO:tensorflow:{'Loss/classification_loss': 0.3037407,
#  'Loss/localization_loss': 0.53427714,
#  'Loss/regularization_loss': 0.14660758,
#  'Loss/total_loss': 0.9846254,
#  'learning_rate': 0.005260433}
# I0814 00:53:50.736894 140122632734592 model_lib_v2.py:708] {'Loss/classification_loss': 0.3037407,
#  'Loss/localization_loss': 0.53427714,
#  'Loss/regularization_loss': 0.14660758,
#  'Loss/total_loss': 0.9846254,
#  'learning_rate': 0.005260433}
# INFO:tensorflow:Step 20600 per-step time 0.287s
# I0814 00:54:19.431999 140122632734592 model_lib_v2.py:707] Step 20600 per-step time 0.287s
# INFO:tensorflow:{'Loss/classification_loss': 0.105864435,
#  'Loss/localization_loss': 0.040445805,
#  'Loss/regularization_loss': 0.14655755,
#  'Loss/total_loss': 0.29286778,
#  'learning_rate': 0.005236068}
# I0814 00:54:19.432419 140122632734592 model_lib_v2.py:708] {'Loss/classification_loss': 0.105864435,
#  'Loss/localization_loss': 0.040445805,
#  'Loss/regularization_loss': 0.14655755,
#  'Loss/total_loss': 0.29286778,
#  'learning_rate': 0.005236068}
# INFO:tensorflow:Step 20700 per-step time 0.314s
# I0814 00:54:50.844280 140122632734592 model_lib_v2.py:707] Step 20700 per-step time 0.314s
# INFO:tensorflow:{'Loss/classification_loss': 0.07889852,
#  'Loss/localization_loss': 0.023265531,
#  'Loss/regularization_loss': 0.1465142,
#  'Loss/total_loss': 0.24867827,
#  'learning_rate': 0.0052116527}
# I0814 00:54:50.844697 140122632734592 model_lib_v2.py:708] {'Loss/classification_loss': 0.07889852,
#  'Loss/localization_loss': 0.023265531,
#  'Loss/regularization_loss': 0.1465142,
#  'Loss/total_loss': 0.24867827,
#  'learning_rate': 0.0052116527}
# INFO:tensorflow:Step 20800 per-step time 0.307s
# I0814 00:55:21.573179 140122632734592 model_lib_v2.py:707] Step 20800 per-step time 0.307s
# INFO:tensorflow:{'Loss/classification_loss': 0.10095235,
#  'Loss/localization_loss': 0.04938619,
#  'Loss/regularization_loss': 0.14645882,
#  'Loss/total_loss': 0.29679734,
#  'learning_rate': 0.0051871873}
# I0814 00:55:21.573544 140122632734592 model_lib_v2.py:708] {'Loss/classification_loss': 0.10095235,
#  'Loss/localization_loss': 0.04938619,
#  'Loss/regularization_loss': 0.14645882,
#  'Loss/total_loss': 0.29679734,
#  'learning_rate': 0.0051871873}
# INFO:tensorflow:Step 20900 per-step time 0.305s
# I0814 00:55:52.068175 140122632734592 model_lib_v2.py:707] Step 20900 per-step time 0.305s
# INFO:tensorflow:{'Loss/classification_loss': 0.10901058,
#  'Loss/localization_loss': 0.040102806,
#  'Loss/regularization_loss': 0.14640534,
#  'Loss/total_loss': 0.29551873,
#  'learning_rate': 0.0051626726}
# I0814 00:55:52.068554 140122632734592 model_lib_v2.py:708] {'Loss/classification_loss': 0.10901058,
#  'Loss/localization_loss': 0.040102806,
#  'Loss/regularization_loss': 0.14640534,
#  'Loss/total_loss': 0.29551873,
#  'learning_rate': 0.0051626726}
# INFO:tensorflow:Step 21000 per-step time 0.299s
# I0814 00:56:21.956275 140122632734592 model_lib_v2.py:707] Step 21000 per-step time 0.299s
# INFO:tensorflow:{'Loss/classification_loss': 0.091221586,
#  'Loss/localization_loss': 0.07400066,
#  'Loss/regularization_loss': 0.14635025,
#  'Loss/total_loss': 0.3115725,
#  'learning_rate': 0.0051381104}
# I0814 00:56:21.956735 140122632734592 model_lib_v2.py:708] {'Loss/classification_loss': 0.091221586,
#  'Loss/localization_loss': 0.07400066,
#  'Loss/regularization_loss': 0.14635025,
#  'Loss/total_loss': 0.3115725,
#  'learning_rate': 0.0051381104}
# INFO:tensorflow:Step 21100 per-step time 0.306s
# I0814 00:56:52.543752 140122632734592 model_lib_v2.py:707] Step 21100 per-step time 0.306s
# INFO:tensorflow:{'Loss/classification_loss': 0.15112337,
#  'Loss/localization_loss': 0.0696325,
#  'Loss/regularization_loss': 0.14629784,
#  'Loss/total_loss': 0.36705372,
#  'learning_rate': 0.0051135016}
# I0814 00:56:52.544131 140122632734592 model_lib_v2.py:708] {'Loss/classification_loss': 0.15112337,
#  'Loss/localization_loss': 0.0696325,
#  'Loss/regularization_loss': 0.14629784,
#  'Loss/total_loss': 0.36705372,
#  'learning_rate': 0.0051135016}
# INFO:tensorflow:Step 21200 per-step time 0.314s
# I0814 00:57:23.957856 140122632734592 model_lib_v2.py:707] Step 21200 per-step time 0.314s
# INFO:tensorflow:{'Loss/classification_loss': 0.05603914,
#  'Loss/localization_loss': 0.0329594,
#  'Loss/regularization_loss': 0.14624415,
#  'Loss/total_loss': 0.2352427,
#  'learning_rate': 0.005088847}
# I0814 00:57:23.958246 140122632734592 model_lib_v2.py:708] {'Loss/classification_loss': 0.05603914,
#  'Loss/localization_loss': 0.0329594,
#  'Loss/regularization_loss': 0.14624415,
#  'Loss/total_loss': 0.2352427,
#  'learning_rate': 0.005088847}
# INFO:tensorflow:Step 21300 per-step time 0.300s
# I0814 00:57:53.928827 140122632734592 model_lib_v2.py:707] Step 21300 per-step time 0.300s
# INFO:tensorflow:{'Loss/classification_loss': 0.087708935,
#  'Loss/localization_loss': 0.06688407,
#  'Loss/regularization_loss': 0.14619151,
#  'Loss/total_loss': 0.30078453,
#  'learning_rate': 0.005064147}
# I0814 00:57:53.929187 140122632734592 model_lib_v2.py:708] {'Loss/classification_loss': 0.087708935,
#  'Loss/localization_loss': 0.06688407,
#  'Loss/regularization_loss': 0.14619151,
#  'Loss/total_loss': 0.30078453,
#  'learning_rate': 0.005064147}
# INFO:tensorflow:Step 21400 per-step time 0.310s
# I0814 00:58:24.917055 140122632734592 model_lib_v2.py:707] Step 21400 per-step time 0.310s
# INFO:tensorflow:{'Loss/classification_loss': 0.09543532,
#  'Loss/localization_loss': 0.014284991,
#  'Loss/regularization_loss': 0.14613664,
#  'Loss/total_loss': 0.25585696,
#  'learning_rate': 0.005039404}
# I0814 00:58:24.917448 140122632734592 model_lib_v2.py:708] {'Loss/classification_loss': 0.09543532,
#  'Loss/localization_loss': 0.014284991,
#  'Loss/regularization_loss': 0.14613664,
#  'Loss/total_loss': 0.25585696,
#  'learning_rate': 0.005039404}
# INFO:tensorflow:Step 21500 per-step time 0.296s
# I0814 00:58:54.512754 140122632734592 model_lib_v2.py:707] Step 21500 per-step time 0.296s
# INFO:tensorflow:{'Loss/classification_loss': 0.064727604,
#  'Loss/localization_loss': 0.014077967,
#  'Loss/regularization_loss': 0.14608201,
#  'Loss/total_loss': 0.22488758,
#  'learning_rate': 0.005014618}
# I0814 00:58:54.513138 140122632734592 model_lib_v2.py:708] {'Loss/classification_loss': 0.064727604,
#  'Loss/localization_loss': 0.014077967,
#  'Loss/regularization_loss': 0.14608201,
#  'Loss/total_loss': 0.22488758,
#  'learning_rate': 0.005014618}
# INFO:tensorflow:Step 21600 per-step time 0.336s
# I0814 00:59:28.076555 140122632734592 model_lib_v2.py:707] Step 21600 per-step time 0.336s
# INFO:tensorflow:{'Loss/classification_loss': 0.14423448,
#  'Loss/localization_loss': 0.039201904,
#  'Loss/regularization_loss': 0.14603056,
#  'Loss/total_loss': 0.32946694,
#  'learning_rate': 0.004989791}
# I0814 00:59:28.076914 140122632734592 model_lib_v2.py:708] {'Loss/classification_loss': 0.14423448,
#  'Loss/localization_loss': 0.039201904,
#  'Loss/regularization_loss': 0.14603056,
#  'Loss/total_loss': 0.32946694,
#  'learning_rate': 0.004989791}
# INFO:tensorflow:Step 21700 per-step time 0.279s
# I0814 00:59:55.993004 140122632734592 model_lib_v2.py:707] Step 21700 per-step time 0.279s
# INFO:tensorflow:{'Loss/classification_loss': 0.0951535,
#  'Loss/localization_loss': 0.048612934,
#  'Loss/regularization_loss': 0.14597696,
#  'Loss/total_loss': 0.2897434,
#  'learning_rate': 0.0049649226}
# I0814 00:59:55.993553 140122632734592 model_lib_v2.py:708] {'Loss/classification_loss': 0.0951535,
#  'Loss/localization_loss': 0.048612934,
#  'Loss/regularization_loss': 0.14597696,
#  'Loss/total_loss': 0.2897434,
#  'learning_rate': 0.0049649226}
# INFO:tensorflow:Step 21800 per-step time 0.318s
# I0814 01:00:27.740850 140122632734592 model_lib_v2.py:707] Step 21800 per-step time 0.318s
# INFO:tensorflow:{'Loss/classification_loss': 0.10565311,
#  'Loss/localization_loss': 0.061383042,
#  'Loss/regularization_loss': 0.14592533,
#  'Loss/total_loss': 0.31296146,
#  'learning_rate': 0.004940015}
# I0814 01:00:27.741260 140122632734592 model_lib_v2.py:708] {'Loss/classification_loss': 0.10565311,
#  'Loss/localization_loss': 0.061383042,
#  'Loss/regularization_loss': 0.14592533,
#  'Loss/total_loss': 0.31296146,
#  'learning_rate': 0.004940015}
# INFO:tensorflow:Step 21900 per-step time 0.286s
# I0814 01:00:56.319505 140122632734592 model_lib_v2.py:707] Step 21900 per-step time 0.286s
# INFO:tensorflow:{'Loss/classification_loss': 0.10729434,
#  'Loss/localization_loss': 0.036853425,
#  'Loss/regularization_loss': 0.14587128,
#  'Loss/total_loss': 0.29001904,
#  'learning_rate': 0.004915068}
# I0814 01:00:56.319869 140122632734592 model_lib_v2.py:708] {'Loss/classification_loss': 0.10729434,
#  'Loss/localization_loss': 0.036853425,
#  'Loss/regularization_loss': 0.14587128,
#  'Loss/total_loss': 0.29001904,
#  'learning_rate': 0.004915068}
# INFO:tensorflow:Step 22000 per-step time 0.312s
# I0814 01:01:27.563553 140122632734592 model_lib_v2.py:707] Step 22000 per-step time 0.312s
# INFO:tensorflow:{'Loss/classification_loss': 0.13407838,
#  'Loss/localization_loss': 0.098213255,
#  'Loss/regularization_loss': 0.14581919,
#  'Loss/total_loss': 0.37811083,
#  'learning_rate': 0.004890084}
# I0814 01:01:27.564007 140122632734592 model_lib_v2.py:708] {'Loss/classification_loss': 0.13407838,
#  'Loss/localization_loss': 0.098213255,
#  'Loss/regularization_loss': 0.14581919,
#  'Loss/total_loss': 0.37811083,
#  'learning_rate': 0.004890084}
# INFO:tensorflow:Step 22100 per-step time 0.311s
# I0814 01:01:58.634660 140122632734592 model_lib_v2.py:707] Step 22100 per-step time 0.311s
# INFO:tensorflow:{'Loss/classification_loss': 0.22904946,
#  'Loss/localization_loss': 0.2129541,
#  'Loss/regularization_loss': 0.1457687,
#  'Loss/total_loss': 0.58777225,
#  'learning_rate': 0.004865063}
# I0814 01:01:58.635035 140122632734592 model_lib_v2.py:708] {'Loss/classification_loss': 0.22904946,
#  'Loss/localization_loss': 0.2129541,
#  'Loss/regularization_loss': 0.1457687,
#  'Loss/total_loss': 0.58777225,
#  'learning_rate': 0.004865063}
# INFO:tensorflow:Step 22200 per-step time 0.289s
# I0814 01:02:27.587453 140122632734592 model_lib_v2.py:707] Step 22200 per-step time 0.289s
# INFO:tensorflow:{'Loss/classification_loss': 0.107693166,
#  'Loss/localization_loss': 0.046475656,
#  'Loss/regularization_loss': 0.14571661,
#  'Loss/total_loss': 0.29988542,
#  'learning_rate': 0.004840007}
# I0814 01:02:27.587899 140122632734592 model_lib_v2.py:708] {'Loss/classification_loss': 0.107693166,
#  'Loss/localization_loss': 0.046475656,
#  'Loss/regularization_loss': 0.14571661,
#  'Loss/total_loss': 0.29988542,
#  'learning_rate': 0.004840007}

# %% [markdown]
# # 7. Evaluate the Model

# %%
command = "python {} --model_dir={} --pipeline_config_path={} --checkpoint_dir={}".format(TRAINING_SCRIPT, paths['CHECKPOINT_PATH'],files['PIPELINE_CONFIG'], paths['CHECKPOINT_PATH'])

# %%
print(command)
# Out:
# python Tensorflow/models/research/object_detection/model_main_tf2.py --model_dir=Tensorflow/workspace/models/my_ssd_mobnet --pipeline_config_path=Tensorflow/workspace/models/my_ssd_mobnet/pipeline.config --checkpoint_dir=Tensorflow/workspace/models/my_ssd_mobnet

# %%
pip install opencv-python==4.5.5.64
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting opencv-python==4.5.5.64
#   Downloading opencv_python-4.5.5.64-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (60.5 MB)
#      |████████████████████████████████| 60.5 MB 1.2 MB/s
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from opencv-python==4.5.5.64) (1.21.6)
# Installing collected packages: opencv-python
#   Attempting uninstall: opencv-python
#     Found existing installation: opencv-python 4.6.0.66
#     Uninstalling opencv-python-4.6.0.66:
#       Successfully uninstalled opencv-python-4.6.0.66
# Successfully installed opencv-python-4.5.5.64

# %%
pip install opencv-python-headless==4.5.2.52
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting opencv-python-headless==4.5.2.52
#   Downloading opencv_python_headless-4.5.2.52-cp37-cp37m-manylinux2014_x86_64.whl (38.2 MB)
#      |████████████████████████████████| 38.2 MB 115 kB/s
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from opencv-python-headless==4.5.2.52) (1.21.6)
# Installing collected packages: opencv-python-headless
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.2.0.34
#     Uninstalling opencv-python-headless-4.2.0.34:
#       Successfully uninstalled opencv-python-headless-4.2.0.34
# Successfully installed opencv-python-headless-4.5.2.52

# %%
# !{command}

# %%
# !pwd
# Out:
# /content

# %%
# !cd Tensorflow/workspace/models/my_ssd_mobnet && cd eval

# %%
# %load_ext tensorboard
# %tensorboard --logdir=.

# %% [markdown]
# # 8. Load Train Model From Checkpoint

# %%
import os
import tensorflow as tf
from object_detection.utils import label_map_util
from object_detection.utils import visualization_utils as viz_utils
from object_detection.builders import model_builder
from object_detection.utils import config_util

# %%
# Load pipeline config and build a detection model
configs = config_util.get_configs_from_pipeline_file(files['PIPELINE_CONFIG'])
detection_model = model_builder.build(model_config=configs['model'], is_training=False)

# Restore checkpoint
ckpt = tf.compat.v2.train.Checkpoint(model=detection_model)
ckpt.restore(os.path.join(paths['CHECKPOINT_PATH'], 'ckpt-3')).expect_partial()

@tf.function
def detect_fn(image):
    image, shapes = detection_model.preprocess(image)
    prediction_dict = detection_model.predict(image, shapes)
    detections = detection_model.postprocess(prediction_dict, shapes)
    return detections

# %% [markdown]
# # 9. Detect from an Image

# %%
import cv2 
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
category_index = label_map_util.create_category_index_from_labelmap(files['LABELMAP'])

# %%
IMAGE_PATH = os.path.join(paths['IMAGE_PATH'], 'test', 'IMG_5110.jpg')

# %%
img = cv2.imread(IMAGE_PATH)
image_np = np.array(img)

input_tensor = tf.convert_to_tensor(np.expand_dims(image_np, 0), dtype=tf.float32)
detections = detect_fn(input_tensor)

num_detections = int(detections.pop('num_detections'))
detections = {key: value[0, :num_detections].numpy()
              for key, value in detections.items()}
detections['num_detections'] = num_detections

# detection_classes should be ints.
detections['detection_classes'] = detections['detection_classes'].astype(np.int64)

label_id_offset = 1
image_np_with_detections = image_np.copy()

viz_utils.visualize_boxes_and_labels_on_image_array(
            image_np_with_detections,
            detections['detection_boxes'],
            detections['detection_classes']+label_id_offset,
            detections['detection_scores'],
            category_index,
            use_normalized_coordinates=True,
            max_boxes_to_draw=100,
            min_score_thresh=.6,
            agnostic_mode=False)

plt.imshow(cv2.cvtColor(image_np_with_detections, cv2.COLOR_BGR2RGB))
f = plt.figure()
f.set_figwidth(150)
f.set_figheight(150)
plt.show()

# %% [markdown]
# # 10. Freezing the Graph

# %%
FREEZE_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'exporter_main_v2.py ')

# %%
command = "python {} --input_type=image_tensor --pipeline_config_path={} --trained_checkpoint_dir={} --output_directory={}".format(FREEZE_SCRIPT ,files['PIPELINE_CONFIG'], paths['CHECKPOINT_PATH'], paths['OUTPUT_PATH'])

# %%
print(command)
# Out:
# python Tensorflow/models/research/object_detection/exporter_main_v2.py  --input_type=image_tensor --pipeline_config_path=Tensorflow/workspace/models/my_ssd_mobnet/pipeline.config --trained_checkpoint_dir=Tensorflow/workspace/models/my_ssd_mobnet --output_directory=Tensorflow/workspace/models/my_ssd_mobnet/export

# %%
# !{command}
# Out:
# 2022-08-05 21:46:06.982433: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/autograph/impl/api.py:458: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with back_prop=False is deprecated and will be removed in a future version.
# Instructions for updating:
# back_prop=False is deprecated. Consider using tf.stop_gradient instead.
# Instead of:
# results = tf.map_fn(fn, elems, back_prop=False)
# Use:
# results = tf.nest.map_structure(tf.stop_gradient, tf.map_fn(fn, elems))
# W0805 21:46:07.138707 139694638663552 deprecation.py:628] From /usr/local/lib/python3.7/dist-packages/tensorflow/python/autograph/impl/api.py:458: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with back_prop=False is deprecated and will be removed in a future version.
# Instructions for updating:
# back_prop=False is deprecated. Consider using tf.stop_gradient instead.
# Instead of:
# results = tf.map_fn(fn, elems, back_prop=False)
# Use:
# results = tf.nest.map_structure(tf.stop_gradient, tf.map_fn(fn, elems))
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x7f0ca0102f90>, because it is not built.
# W0805 21:46:27.368417 139694638663552 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x7f0ca0102f90>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7f0c36497990>, because it is not built.
# W0805 21:46:27.815339 139694638663552 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7f0c36497990>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f0c20c45ed0>, because it is not built.
# W0805 21:46:27.815566 139694638663552 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f0c20c45ed0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f0c20da2850>, because it is not built.
# W0805 21:46:27.815675 139694638663552 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f0c20da2850>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7f0c20e79dd0>, because it is not built.
# W0805 21:46:27.815763 139694638663552 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7f0c20e79dd0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f0c20c1e7d0>, because it is not built.
# W0805 21:46:27.815863 139694638663552 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f0c20c1e7d0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f0c20c1e510>, because it is not built.
# W0805 21:46:27.815954 139694638663552 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f0c20c1e510>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7f0c20c1e550>, because it is not built.
# W0805 21:46:27.816032 139694638663552 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7f0c20c1e550>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f0c20c1e090>, because it is not built.
# W0805 21:46:27.816109 139694638663552 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f0c20c1e090>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f0c20e41b90>, because it is not built.
# W0805 21:46:27.816194 139694638663552 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f0c20e41b90>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7f0c20dc3050>, because it is not built.
# W0805 21:46:27.816271 139694638663552 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7f0c20dc3050>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f0c20c15fd0>, because it is not built.
# W0805 21:46:27.816348 139694638663552 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f0c20c15fd0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f0c20c15090>, because it is not built.
# W0805 21:46:27.816426 139694638663552 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f0c20c15090>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f0c3678fdd0>, because it is not built.
# W0805 21:46:27.816507 139694638663552 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f0c3678fdd0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f0c20bf9210>, because it is not built.
# W0805 21:46:27.816593 139694638663552 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f0c20bf9210>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f0c36436910>, because it is not built.
# W0805 21:46:27.816675 139694638663552 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f0c36436910>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f0c20bf98d0>, because it is not built.
# W0805 21:46:27.816753 139694638663552 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f0c20bf98d0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f0c20bf9d90>, because it is not built.
# W0805 21:46:27.816860 139694638663552 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f0c20bf9d90>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f0c20bf9a10>, because it is not built.
# W0805 21:46:27.816942 139694638663552 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f0c20bf9a10>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f0c20e31090>, because it is not built.
# W0805 21:46:27.817025 139694638663552 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f0c20e31090>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f0c20e6e410>, because it is not built.
# W0805 21:46:27.817125 139694638663552 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f0c20e6e410>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f0c3678ff50>, because it is not built.
# W0805 21:46:27.817204 139694638663552 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f0c3678ff50>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f0c20bb7510>, because it is not built.
# W0805 21:46:27.817281 139694638663552 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f0c20bb7510>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f0c20bb7190>, because it is not built.
# W0805 21:46:27.817357 139694638663552 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f0c20bb7190>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f0c20bb7d90>, because it is not built.
# W0805 21:46:27.817434 139694638663552 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f0c20bb7d90>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f0c20bb7f10>, because it is not built.
# W0805 21:46:27.817515 139694638663552 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f0c20bb7f10>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f0c20bb7990>, because it is not built.
# W0805 21:46:27.817590 139694638663552 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f0c20bb7990>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f0c364e54d0>, because it is not built.
# W0805 21:46:27.817669 139694638663552 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f0c364e54d0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f0c20bb7850>, because it is not built.
# W0805 21:46:27.817746 139694638663552 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f0c20bb7850>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f0c20f93850>, because it is not built.
# W0805 21:46:27.817830 139694638663552 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f0c20f93850>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f0c20d8ca90>, because it is not built.
# W0805 21:46:27.817908 139694638663552 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f0c20d8ca90>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f0c20d8c0d0>, because it is not built.
# W0805 21:46:27.817988 139694638663552 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f0c20d8c0d0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f0c20d9fd50>, because it is not built.
# W0805 21:46:27.818065 139694638663552 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f0c20d9fd50>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f0c3673d5d0>, because it is not built.
# W0805 21:46:27.818146 139694638663552 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f0c3673d5d0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f0c20d05fd0>, because it is not built.
# W0805 21:46:27.818223 139694638663552 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f0c20d05fd0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f0c20d211d0>, because it is not built.
# W0805 21:46:27.818299 139694638663552 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f0c20d211d0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f0c364a6590>, because it is not built.
# W0805 21:46:27.818452 139694638663552 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f0c364a6590>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f0c3678ff90>, because it is not built.
# W0805 21:46:27.818542 139694638663552 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f0c3678ff90>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f0c20bf4c50>, because it is not built.
# W0805 21:46:27.818644 139694638663552 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f0c20bf4c50>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f0c20d95350>, because it is not built.
# W0805 21:46:27.818727 139694638663552 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f0c20d95350>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f0c20bf4a90>, because it is not built.
# W0805 21:46:27.818825 139694638663552 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f0c20bf4a90>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f0c20ca4ad0>, because it is not built.
# W0805 21:46:27.818912 139694638663552 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f0c20ca4ad0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f0c20bbb8d0>, because it is not built.
# W0805 21:46:27.818995 139694638663552 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f0c20bbb8d0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f0c3658ac90>, because it is not built.
# W0805 21:46:27.892424 139694638663552 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7f0c3658ac90>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f0c361aefd0>, because it is not built.
# W0805 21:46:27.892648 139694638663552 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7f0c361aefd0>, because it is not built.
# W0805 21:46:46.911679 139694638663552 save.py:238] Found untraced functions such as WeightSharedConvolutionalBoxPredictor_layer_call_fn, WeightSharedConvolutionalBoxPredictor_layer_call_and_return_conditional_losses, WeightSharedConvolutionalBoxHead_layer_call_fn, WeightSharedConvolutionalBoxHead_layer_call_and_return_conditional_losses, WeightSharedConvolutionalClassHead_layer_call_fn while saving (showing 5 of 173). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Tensorflow/workspace/models/my_ssd_mobnet/export/saved_model/assets
# I0805 21:46:51.966188 139694638663552 builder_impl.py:780] Assets written to: Tensorflow/workspace/models/my_ssd_mobnet/export/saved_model/assets
# INFO:tensorflow:Writing pipeline config file to Tensorflow/workspace/models/my_ssd_mobnet/export/pipeline.config
# I0805 21:46:52.517581 139694638663552 config_util.py:254] Writing pipeline config file to Tensorflow/workspace/models/my_ssd_mobnet/export/pipeline.config

# %% [markdown]
# # 11. Conversion to TFLite

# %%
TFLITE_SCRIPT = os.path.join(paths['APIMODEL_PATH'], 'research', 'object_detection', 'export_tflite_graph_tf2.py ')

# %%
command = "python {} --pipeline_config_path={} --trained_checkpoint_dir={} --output_directory={}".format(TFLITE_SCRIPT ,files['PIPELINE_CONFIG'], paths['CHECKPOINT_PATH'], paths['TFLITE_PATH'])

# %%
print(command)
# Out:
# python Tensorflow/models/research/object_detection/export_tflite_graph_tf2.py  --pipeline_config_path=Tensorflow/workspace/models/my_ssd_mobnet/pipeline.config --trained_checkpoint_dir=Tensorflow/workspace/models/my_ssd_mobnet --output_directory=Tensorflow/workspace/models/my_ssd_mobnet/tfliteexport

# %%
# !{command}
# Out:
# 2022-08-05 22:12:28.549812: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x7faac036e390>, because it is not built.
# W0805 22:12:41.611371 140373426579328 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x7faac036e390>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7faab03a9e50>, because it is not built.
# W0805 22:12:42.012646 140373426579328 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7faab03a9e50>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7faa2bab1550>, because it is not built.
# W0805 22:12:42.012915 140373426579328 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7faa2bab1550>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7faa2bab1f50>, because it is not built.
# W0805 22:12:42.013024 140373426579328 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7faa2bab1f50>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7faa2bab1450>, because it is not built.
# W0805 22:12:42.013111 140373426579328 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7faa2bab1450>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7faa2bac3650>, because it is not built.
# W0805 22:12:42.013195 140373426579328 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7faa2bac3650>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7faa2bac3610>, because it is not built.
# W0805 22:12:42.013275 140373426579328 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7faa2bac3610>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7faa2bac3c90>, because it is not built.
# W0805 22:12:42.013355 140373426579328 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7faa2bac3c90>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7faa2bac3890>, because it is not built.
# W0805 22:12:42.013432 140373426579328 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7faa2bac3890>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7faa2bab76d0>, because it is not built.
# W0805 22:12:42.013509 140373426579328 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7faa2bab76d0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7faa2bab7850>, because it is not built.
# W0805 22:12:42.013598 140373426579328 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.convolutional.separable_conv2d.SeparableConv2D object at 0x7faa2bab7850>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7faa2bab7a10>, because it is not built.
# W0805 22:12:42.013679 140373426579328 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7faa2bab7a10>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7faa2bab7250>, because it is not built.
# W0805 22:12:42.013759 140373426579328 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7faa2bab7250>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7faab0331950>, because it is not built.
# W0805 22:12:42.013873 140373426579328 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7faab0331950>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7faa2bc13b90>, because it is not built.
# W0805 22:12:42.013967 140373426579328 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7faa2bc13b90>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7faa2bab7710>, because it is not built.
# W0805 22:12:42.014054 140373426579328 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7faa2bab7710>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7faa2bc13ad0>, because it is not built.
# W0805 22:12:42.014142 140373426579328 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7faa2bc13ad0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7faa2bc13190>, because it is not built.
# W0805 22:12:42.014230 140373426579328 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7faa2bc13190>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7faa2bc13d50>, because it is not built.
# W0805 22:12:42.014318 140373426579328 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7faa2bc13d50>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7faa2bc13e10>, because it is not built.
# W0805 22:12:42.014404 140373426579328 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7faa2bc13e10>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7faab0243190>, because it is not built.
# W0805 22:12:42.014491 140373426579328 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7faab0243190>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7faab0331990>, because it is not built.
# W0805 22:12:42.014578 140373426579328 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7faab0331990>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7faa42218f50>, because it is not built.
# W0805 22:12:42.014675 140373426579328 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7faa42218f50>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7faa2be01f50>, because it is not built.
# W0805 22:12:42.014761 140373426579328 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7faa2be01f50>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7faa42196c10>, because it is not built.
# W0805 22:12:42.014869 140373426579328 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7faa42196c10>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7faa2bf81fd0>, because it is not built.
# W0805 22:12:42.014959 140373426579328 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7faa2bf81fd0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7faa42150e90>, because it is not built.
# W0805 22:12:42.015051 140373426579328 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7faa42150e90>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7faa42150990>, because it is not built.
# W0805 22:12:42.015145 140373426579328 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7faa42150990>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7faa2bed9c10>, because it is not built.
# W0805 22:12:42.015223 140373426579328 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7faa2bed9c10>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7faa420863d0>, because it is not built.
# W0805 22:12:42.015299 140373426579328 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7faa420863d0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7faa2bb62310>, because it is not built.
# W0805 22:12:42.015374 140373426579328 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7faa2bb62310>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7faa2bbab290>, because it is not built.
# W0805 22:12:42.015449 140373426579328 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7faa2bbab290>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7faa2be70ed0>, because it is not built.
# W0805 22:12:42.015531 140373426579328 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7faa2be70ed0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7faa2be60f50>, because it is not built.
# W0805 22:12:42.015612 140373426579328 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7faa2be60f50>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7faa2be701d0>, because it is not built.
# W0805 22:12:42.015695 140373426579328 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7faa2be701d0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7faa420e8650>, because it is not built.
# W0805 22:12:42.015774 140373426579328 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7faa420e8650>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7faa2be53b10>, because it is not built.
# W0805 22:12:42.015872 140373426579328 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7faa2be53b10>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7faab03319d0>, because it is not built.
# W0805 22:12:42.015950 140373426579328 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7faab03319d0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7faa421224d0>, because it is not built.
# W0805 22:12:42.016025 140373426579328 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7faa421224d0>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7faa42122c90>, because it is not built.
# W0805 22:12:42.016101 140373426579328 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7faa42122c90>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7faa42122310>, because it is not built.
# W0805 22:12:42.016180 140373426579328 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7faa42122310>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7faa42122910>, because it is not built.
# W0805 22:12:42.016254 140373426579328 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7faa42122910>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7faab01f3a10>, because it is not built.
# W0805 22:12:42.016329 140373426579328 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7faab01f3a10>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7faab01f3450>, because it is not built.
# W0805 22:12:42.016410 140373426579328 save_impl.py:72] Skipping full serialization of Keras layer <object_detection.core.freezable_batch_norm.FreezableBatchNorm object at 0x7faab01f3450>, because it is not built.
# WARNING:tensorflow:Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7faab01f3150>, because it is not built.
# W0805 22:12:42.034511 140373426579328 save_impl.py:72] Skipping full serialization of Keras layer <keras.layers.core.lambda_layer.Lambda object at 0x7faab01f3150>, because it is not built.
# W0805 22:13:01.975572 140373426579328 save.py:238] Found untraced functions such as WeightSharedConvolutionalBoxPredictor_layer_call_fn, WeightSharedConvolutionalBoxPredictor_layer_call_and_return_conditional_losses, WeightSharedConvolutionalBoxHead_layer_call_fn, WeightSharedConvolutionalBoxHead_layer_call_and_return_conditional_losses, WeightSharedConvolutionalClassHead_layer_call_fn while saving (showing 5 of 173). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: Tensorflow/workspace/models/my_ssd_mobnet/tfliteexport/saved_model/assets
# I0805 22:13:08.624431 140373426579328 builder_impl.py:780] Assets written to: Tensorflow/workspace/models/my_ssd_mobnet/tfliteexport/saved_model/assets

# %%
FROZEN_TFLITE_PATH = os.path.join(paths['TFLITE_PATH'], 'saved_model')
TFLITE_MODEL = os.path.join(paths['TFLITE_PATH'], 'saved_model', 'detect.tflite')

# %%
command = "tflite_convert \
--saved_model_dir={} \
--output_file={} \
--input_shapes=1,300,300,3 \
--input_arrays=normalized_input_image_tensor \
--output_arrays='TFLite_Detection_PostProcess','TFLite_Detection_PostProcess:1','TFLite_Detection_PostProcess:2','TFLite_Detection_PostProcess:3' \
--inference_type=FLOAT \
--allow_custom_ops".format(FROZEN_TFLITE_PATH, TFLITE_MODEL, )

# %%
print(command)
# Out:
# tflite_convert --saved_model_dir=Tensorflow/workspace/models/my_ssd_mobnet/tfliteexport/saved_model --output_file=Tensorflow/workspace/models/my_ssd_mobnet/tfliteexport/saved_model/detect.tflite --input_shapes=1,300,300,3 --input_arrays=normalized_input_image_tensor --output_arrays='TFLite_Detection_PostProcess','TFLite_Detection_PostProcess:1','TFLite_Detection_PostProcess:2','TFLite_Detection_PostProcess:3' --inference_type=FLOAT --allow_custom_ops

# %%
# !{command}
# Out:
# 2022-08-05 22:13:15.373520: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2022-08-05 22:13:26.893441: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:362] Ignored output_format.
# 2022-08-05 22:13:26.893496: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:365] Ignored drop_control_dependency.
# Estimated count of arithmetic ops: 1.706 G  ops, equivalently 0.853 G  MACs

# %% [markdown]
# # 12. Zip and Export Models

# %%
# !tar -czf models.tar.gz {paths['CHECKPOINT_PATH']}
